# %% [markdown]
# # Starter pack library

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import datetime
import string
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# # Loading data

# %%
emotions_df = pd.read_csv("../london-emotions/data/emotion_data.csv")

# %%
emotions_df['Emotion'].value_counts()
# Out:
# anger      15872
# joy        14168
# worry      11786
# neutral    10212
# sad         9233
# Name: Emotion, dtype: int64

# %% [markdown]
# # Cleaning function

# %%
def clean_data(data):
    """
    clean and preprocess data
    """

    # Lowercase text
    data['clean_text'] = data['Text'].apply(
        lambda x: x.lower()
        )
    # Strip whitespace
    data['clean_text'] = data['clean_text'].apply(
        lambda x: x.strip()
        )
    # Remove numbers
    data['clean_text'] = data['clean_text'].apply(
        lambda x: ''.join(let for let in x if not let.isdigit())
        )
    # Remove punctuation
    data['clean_text'] = data['clean_text'].apply(
        lambda x: ''.join(let for let in x if not let in string.punctuation)
        )
    # Tokenization with nltk
    data['clean_text'] = data['clean_text'].apply(
        lambda x: word_tokenize(x)
    )
    # Remove stopwords
    # stop_words = set(stopwords.words('english'))
    # data['clean_text'] = data['clean_text'].apply(
    #     lambda x: [word for word in x if word not in stop_words]
    #     )
    #Lemmatizing with nltk
    lemmatizer = WordNetLemmatizer()
    data['clean_text'] = data['clean_text'].apply(
        lambda x: ' '.join(lemmatizer.lemmatize(word) for word in x)
        )

    # Return data
    return data

# %%
clean_data(emotions_df)
# Out:
#        Emotion                                               Text  \
# 0          sad  Layin n bed with a headache  ughhhh...waitin o...
# 1          sad                Funeral ceremony...gloomy friday...
# 2          joy               wants to hang out with friends SOON!
# 3        worry  Re-pinging @ghostridah14: why didn't you go to...
# 4          sad  I should be sleep, but im not! thinking about ...
# 5        worry               Hmmm. http://www.djhero.com/ is down
# 6          sad            @charviray Charlene my love. I miss you
# 7          sad         @kelcouch I'm sorry  at least it's Friday?
# 8        worry                            Choked on her retainers
# 9          sad  Ugh! I have to beat this stupid song to get to...
# 10         sad  @BrodyJenner if u watch the hills in london u ...
# 11         sad      The storm is here and the electricity is gone
# 12         joy                               @annarosekerr agreed
# 13         sad  So sleepy again and it's not even that late. I...
# 14       worry  @PerezHilton lady gaga tweeted about not being...
# 15         sad  How are YOU convinced that I have always wante...
# 16       worry  @raaaaaaek oh too bad! I hope it gets better. ...
# 17         joy  Wondering why I'm awake at 7am,writing a new s...
# 18       worry  I ate Something I don't know what it is... Why...
# 19         sad  so tired and i think i'm definitely going to g...
# 20       worry  On my way home n having 2 deal w underage girl...
# 21         sad  @IsaacMascote  i'm sorry people are so rude to...
# 22       worry  Damm servers still down  i need to hit 80 befo...
# 23         sad  Fudge.... Just BS'd that whole paper.... So ti...
# 24       worry      I HATE CANCER. I HATE IT I HATE IT I HATE IT.
# 25       anger  It is so annoying when she starts typing on he...
# 26         sad  @ether_radio yeah :S i feel all funny cause i ...
# 27       worry                             I need skott right now
# 28         joy  mmm much better day... so far! it's still quit...
# 29         joy  @DavidArchie &lt;3 your gonna be the first  tw...
# ...        ...                                                ...
# 61241  neutral            He's a little sick under the weather .
# 61242  neutral                                  He has the flu .
# 61243  neutral                 Tell him I was asking about him .
# 61244  neutral                                          I will .
# 61245  neutral            Maybe you should talk to the teacher .
# 61246  neutral                                No , it's no use .
# 61247  neutral                   You never know unless you try .
# 61248  neutral              I know . She won't change my grade .
# 61249  neutral           well , I finished my last final today .
# 61250  neutral           do you want to attend the convocation ?
# 61251  neutral   certainly . After years of hard work , I woul...
# 61252  neutral   do you want to have them made or do you want ...
# 61253  neutral   oh , I think they're provided by the school f...
# 61254  neutral     no . those you have to provide for yourself .
# 61255  neutral                 what do most of the students do ?
# 61256  neutral   well , most of them only need a cap and gown ...
# 61257  neutral           then , I might as well have them made .
# 61258  neutral     hold it a second . I want to fix my hairpin .
# 61259  neutral                it doesn't matter . Say'cheese ' .
# 61260  neutral     here's Lisa . May I take a picture with her ?
# 61261  neutral                        Certainly . Ok , got you .
# 61262  neutral             Do you mind if I ask you a question ?
# 61263  neutral                      No , not at all . Go ahead .
# 61264  neutral   What do you do in order to improve your Engli...
# 61265  neutral   I go to movies ; I go to lectures ; I listen ...
# 61266  neutral   It ’ s a good idea to have a radio , isn ’ t ...
# 61267  neutral   Sure . It ’ s like understanding on the telep...
# 61268  neutral   It takes a long time to learn a language , do...
# 61269  neutral   It certainly does . But if you practice speak...
# 61270  neutral                              Good morning , Sue .
#
#                                               clean_text
# 0      layin n bed with a headache ughhhhwaitin on yo...
# 1                          funeral ceremonygloomy friday
# 2                      want to hang out with friend soon
# 3      repinging ghostridah why didnt you go to prom ...
# 4      i should be sleep but im not thinking about an...
# 5                          hmmm httpwwwdjherocom is down
# 6                  charviray charlene my love i miss you
# 7                   kelcouch im sorry at least it friday
# 8                                 choked on her retainer
# 9      ugh i have to beat this stupid song to get to ...
# 10     brodyjenner if u watch the hill in london u wi...
# 11         the storm is here and the electricity is gone
# 12                                   annarosekerr agreed
# 13     so sleepy again and it not even that late i fa...
# 14     perezhilton lady gaga tweeted about not being ...
# 15     how are you convinced that i have always wante...
# 16     raaaaaaek oh too bad i hope it get better ive ...
# 17     wondering why im awake at amwriting a new song...
# 18     i ate something i dont know what it is why do ...
# 19     so tired and i think im definitely going to ge...
# 20     on my way home n having deal w underage girl d...
# 21     isaacmascote im sorry people are so rude to yo...
# 22     damm server still down i need to hit before al...
# 23     fudge just bsd that whole paper so tired ugh i...
# 24           i hate cancer i hate it i hate it i hate it
# 25     it is so annoying when she start typing on her...
# 26     etherradio yeah s i feel all funny cause i hav...
# 27                                i need skott right now
# 28     mmm much better day so far it still quite earl...
# 29     davidarchie lt your gon na be the first twitte...
# ...                                                  ...
# 61241                 he a little sick under the weather
# 61242                                      he ha the flu
# 61243                     tell him i wa asking about him
# 61244                                             i will
# 61245               maybe you should talk to the teacher
# 61246                                       no it no use
# 61247                      you never know unless you try
# 61248                    i know she wont change my grade
# 61249                well i finished my last final today
# 61250              do you want to attend the convocation
# 61251  certainly after year of hard work i wouldnt mi...
# 61252  do you want to have them made or do you want t...
# 61253  oh i think theyre provided by the school for t...
# 61254          no those you have to provide for yourself
# 61255                     what do most of the student do
# 61256  well most of them only need a cap and gown for...
# 61257                 then i might a well have them made
# 61258          hold it a second i want to fix my hairpin
# 61259                         it doesnt matter saycheese
# 61260            here lisa may i take a picture with her
# 61261                               certainly ok got you
# 61262                do you mind if i ask you a question
# 61263                             no not at all go ahead
# 61264    what do you do in order to improve your english
# 61265  i go to movie i go to lecture i listen to the ...
# 61266      it ’ s a good idea to have a radio isn ’ t it
# 61267  sure it ’ s like understanding on the telephon...
# 61268  it take a long time to learn a language doesn ...
# 61269  it certainly doe but if you practice speaking ...
# 61270                                   good morning sue
#
# [61271 rows x 3 columns]

# %% [markdown]
# # library for NN

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Split dataset

# %%
# Train Test Split Function
def split_train_test(df, test_size=0.3):
    X_train, X_test, y_train, y_test = train_test_split(df['clean_text'], 
                                                        df['Emotion'], 
                                                        test_size=test_size, 
                                                        random_state=15)
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = split_train_test(emotions_df, test_size=0.3)

# %% [markdown]
# # Vectorizing X_train & X_test

# %%
from gensim.models import Word2Vec
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

def convert_sentences(X):
    return [sentence.split(' ') for sentence in X]

def embed_sentence(word2vec, sentence):
    embedded_sentence = []
    for word in sentence:
        if word in word2vec.wv:
            embedded_sentence.append(word2vec.wv[word])
        
    return np.array(embedded_sentence)

def embedding(word2vec, sentences):
    embed = []
    
    for sentence in sentences:
        embedded_sentence = embed_sentence(word2vec, sentence)
        embed.append(embedded_sentence)
        
    return embed

def embedding_pipeline(word2vec, X):
    # Step #2: List of words to list of vectors
    X = convert_sentences(X)
    
    # Step #3: Sentences to list of words
    X = embedding(word2vec, X)
    
    # Step #4: Pad the inputs
    X = pad_sequences(X, dtype='float32', padding='post', value= -1000)
    
    return X

# %%
# Step #1: Train a word2vec - with possible hyperparameters
word2vec = Word2Vec(sentences=X_train_token, size=60, min_count=10, window=10)

# %%
X_train_pad = embedding_pipeline(word2vec, X_train)

# %%
X_test_pad = embedding_pipeline(word2vec, X_test)

# %%
X_train_pad.shape
# Out:
# (42889, 215, 60)

# %%
X_test_pad.shape
# Out:
# (18382, 151, 60)

# %%
word2vec.wv.vocab
# Out:
# {'yeah': <gensim.models.keyedvectors.Vocab at 0x131702910>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x1317029d0>,
#  '’': <gensim.models.keyedvectors.Vocab at 0x131702a10>,
#  's': <gensim.models.keyedvectors.Vocab at 0x131702950>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x131702b50>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x131706e90>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x131706310>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x131706050>,
#  'mine': <gensim.models.keyedvectors.Vocab at 0x131702d90>,
#  'thomasfiss': <gensim.models.keyedvectors.Vocab at 0x131706bd0>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x131706b50>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x131706f50>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x131706b90>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x131706c90>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x131706f90>,
#  'wa': <gensim.models.keyedvectors.Vocab at 0x131706d50>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x131706a10>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x131706ed0>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x131706e10>,
#  'seeing': <gensim.models.keyedvectors.Vocab at 0x131706fd0>,
#  'ive': <gensim.models.keyedvectors.Vocab at 0x131706d10>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x131706dd0>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x131706950>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x131706a50>,
#  'hate': <gensim.models.keyedvectors.Vocab at 0x131706b10>,
#  'wen': <gensim.models.keyedvectors.Vocab at 0x131706190>,
#  'cant': <gensim.models.keyedvectors.Vocab at 0x131706350>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x13170e510>,
#  'gary': <gensim.models.keyedvectors.Vocab at 0x13170ea90>,
#  'nap': <gensim.models.keyedvectors.Vocab at 0x13170e790>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x13170eb90>,
#  'mite': <gensim.models.keyedvectors.Vocab at 0x13170efd0>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x13170ed90>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x13170ed50>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x13170ec10>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x13170e850>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x13170e590>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x13170ef50>,
#  'talking': <gensim.models.keyedvectors.Vocab at 0x13170ec50>,
#  'sometimes': <gensim.models.keyedvectors.Vocab at 0x13170ea10>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x13170e7d0>,
#  'll': <gensim.models.keyedvectors.Vocab at 0x13170e5d0>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x13170ee90>,
#  'forget': <gensim.models.keyedvectors.Vocab at 0x13170e150>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x13170ee10>,
#  'happened': <gensim.models.keyedvectors.Vocab at 0x13170eb10>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x13170e090>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x13170e950>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x13170e890>,
#  'guilty': <gensim.models.keyedvectors.Vocab at 0x13170e650>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x13170e0d0>,
#  'dirty': <gensim.models.keyedvectors.Vocab at 0x13170e6d0>,
#  'humiliated': <gensim.models.keyedvectors.Vocab at 0x13170ef10>,
#  'bitter': <gensim.models.keyedvectors.Vocab at 0x13170e9d0>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x13170e750>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x13170e550>,
#  'hollyoaks': <gensim.models.keyedvectors.Vocab at 0x13170e390>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x13170ead0>,
#  'cv': <gensim.models.keyedvectors.Vocab at 0x13170e8d0>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x13170e810>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x12b748350>,
#  'paid': <gensim.models.keyedvectors.Vocab at 0x131708090>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x1317080d0>,
#  'chip': <gensim.models.keyedvectors.Vocab at 0x131708110>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x131708150>,
#  'dancing': <gensim.models.keyedvectors.Vocab at 0x131708190>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x1317081d0>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x131708210>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x131708050>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x131708250>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x131708290>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x1317082d0>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x131708350>,
#  'interested': <gensim.models.keyedvectors.Vocab at 0x131708310>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x1317083d0>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x131708390>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x131708410>,
#  'took': <gensim.models.keyedvectors.Vocab at 0x131708450>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x131708490>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x1317084d0>,
#  'angry': <gensim.models.keyedvectors.Vocab at 0x131708550>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x131708590>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x1317085d0>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x131708610>,
#  'response': <gensim.models.keyedvectors.Vocab at 0x131708650>,
#  'prom': <gensim.models.keyedvectors.Vocab at 0x131708690>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x1317086d0>,
#  'katie': <gensim.models.keyedvectors.Vocab at 0x131708710>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x131708750>,
#  'fishing': <gensim.models.keyedvectors.Vocab at 0x131708790>,
#  'boat': <gensim.models.keyedvectors.Vocab at 0x1317087d0>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x131708810>,
#  'ran': <gensim.models.keyedvectors.Vocab at 0x131708850>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x131708890>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x1317088d0>,
#  'weather': <gensim.models.keyedvectors.Vocab at 0x131708910>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x131708950>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x131708990>,
#  'dont': <gensim.models.keyedvectors.Vocab at 0x1317089d0>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x131708a10>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x131708a50>,
#  'shy': <gensim.models.keyedvectors.Vocab at 0x131708a90>,
#  'lucy': <gensim.models.keyedvectors.Vocab at 0x131708ad0>,
#  'excellent': <gensim.models.keyedvectors.Vocab at 0x131708b10>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x131708b50>,
#  'definitely': <gensim.models.keyedvectors.Vocab at 0x131708b90>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x131708bd0>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x131708c10>,
#  'vacation': <gensim.models.keyedvectors.Vocab at 0x131708c50>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x131708c90>,
#  'thanks': <gensim.models.keyedvectors.Vocab at 0x131708cd0>,
#  'info': <gensim.models.keyedvectors.Vocab at 0x131708d10>,
#  'sitting': <gensim.models.keyedvectors.Vocab at 0x131708d50>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x131708d90>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x131708dd0>,
#  'quiet': <gensim.models.keyedvectors.Vocab at 0x131708e10>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x131708e50>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x131708e90>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x131708ed0>,
#  'ill': <gensim.models.keyedvectors.Vocab at 0x131708f10>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x131708f50>,
#  'cherish': <gensim.models.keyedvectors.Vocab at 0x131708f90>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x131708fd0>,
#  'ha': <gensim.models.keyedvectors.Vocab at 0x13170a050>,
#  'surprisingly': <gensim.models.keyedvectors.Vocab at 0x13170a090>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x13170a0d0>,
#  'considering': <gensim.models.keyedvectors.Vocab at 0x13170a110>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x13170a150>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x13170a190>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x13170a1d0>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x13170a210>,
#  'mountain': <gensim.models.keyedvectors.Vocab at 0x13170a250>,
#  'oh': <gensim.models.keyedvectors.Vocab at 0x13170a290>,
#  'wonderful': <gensim.models.keyedvectors.Vocab at 0x13170a2d0>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x13170a310>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x13170a350>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x13170a390>,
#  'campus': <gensim.models.keyedvectors.Vocab at 0x13170a3d0>,
#  'crush': <gensim.models.keyedvectors.Vocab at 0x13170a410>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x13170a450>,
#  'handsome': <gensim.models.keyedvectors.Vocab at 0x13170a490>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x13170a4d0>,
#  'im': <gensim.models.keyedvectors.Vocab at 0x13170a510>,
#  'sowwy': <gensim.models.keyedvectors.Vocab at 0x13170a550>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x13170a590>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x13170a5d0>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x13170a610>,
#  'wan': <gensim.models.keyedvectors.Vocab at 0x13170a650>,
#  'idiot': <gensim.models.keyedvectors.Vocab at 0x13170a690>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x13170a6d0>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x13170a710>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x13170a750>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x13170a790>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x13170a7d0>,
#  'break': <gensim.models.keyedvectors.Vocab at 0x13170a810>,
#  'ur': <gensim.models.keyedvectors.Vocab at 0x13170a850>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x13170a890>,
#  'coffee': <gensim.models.keyedvectors.Vocab at 0x13170a8d0>,
#  'depends': <gensim.models.keyedvectors.Vocab at 0x13170a910>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x13170a950>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x13170a990>,
#  'drinking': <gensim.models.keyedvectors.Vocab at 0x13170a9d0>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x13170aa10>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x13170aa50>,
#  'joke': <gensim.models.keyedvectors.Vocab at 0x13170aa90>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x13170aad0>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x13170ab10>,
#  'waiting': <gensim.models.keyedvectors.Vocab at 0x1594ccc50>,
#  'bathroom': <gensim.models.keyedvectors.Vocab at 0x16dbe1790>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x13170ecd0>,
#  'taken': <gensim.models.keyedvectors.Vocab at 0x13170e290>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x13170e710>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x13170e910>,
#  'mommy': <gensim.models.keyedvectors.Vocab at 0x13170ef90>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x13170ed10>,
#  'wit': <gensim.models.keyedvectors.Vocab at 0x13170e690>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x13170e410>,
#  'fool': <gensim.models.keyedvectors.Vocab at 0x13170e190>,
#  'college': <gensim.models.keyedvectors.Vocab at 0x13170ec90>,
#  'hill': <gensim.models.keyedvectors.Vocab at 0x13170e210>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x13170eed0>,
#  'link': <gensim.models.keyedvectors.Vocab at 0x13170e450>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x13170e110>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x13170e350>,
#  'customer': <gensim.models.keyedvectors.Vocab at 0x13170e610>,
#  'download': <gensim.models.keyedvectors.Vocab at 0x13170ee50>,
#  'recession': <gensim.models.keyedvectors.Vocab at 0x13170ea50>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x13170edd0>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x13170e990>,
#  'quit': <gensim.models.keyedvectors.Vocab at 0x13170e4d0>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x13170ebd0>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x13170e1d0>,
#  'shame': <gensim.models.keyedvectors.Vocab at 0x13170e310>,
#  'worked': <gensim.models.keyedvectors.Vocab at 0x13170e250>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x12cc7c250>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x13123dfd0>,
#  'preparing': <gensim.models.keyedvectors.Vocab at 0x13123ddd0>,
#  'tip': <gensim.models.keyedvectors.Vocab at 0x13123de50>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x13123d7d0>,
#  'eagle': <gensim.models.keyedvectors.Vocab at 0x13123df10>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x13123dd10>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x13123d810>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x13123de10>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x13123dc10>,
#  'wish': <gensim.models.keyedvectors.Vocab at 0x13123d910>,
#  'park': <gensim.models.keyedvectors.Vocab at 0x13123d990>,
#  'swing': <gensim.models.keyedvectors.Vocab at 0x13123da90>,
#  'victory': <gensim.models.keyedvectors.Vocab at 0x13123da10>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x13123d950>,
#  'congratulation': <gensim.models.keyedvectors.Vocab at 0x13123df90>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x13123d890>,
#  'glad': <gensim.models.keyedvectors.Vocab at 0x1314a1050>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x1314a1410>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x1314a17d0>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x1314a1fd0>,
#  'easier': <gensim.models.keyedvectors.Vocab at 0x1314a1d90>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x1314a1990>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x1314a1a90>,
#  'grateful': <gensim.models.keyedvectors.Vocab at 0x1314a1850>,
#  'ok': <gensim.models.keyedvectors.Vocab at 0x1314a1310>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x1314a1a10>,
#  'office': <gensim.models.keyedvectors.Vocab at 0x1314a15d0>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x1314a12d0>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x1314a14d0>,
#  'weekend': <gensim.models.keyedvectors.Vocab at 0x1314a1290>,
#  'awesome': <gensim.models.keyedvectors.Vocab at 0x1314a1690>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x1314a1590>,
#  'sight': <gensim.models.keyedvectors.Vocab at 0x1314a1cd0>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x1314a1250>,
#  'magic': <gensim.models.keyedvectors.Vocab at 0x1314a1b90>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x1314a1c50>,
#  'jordanknight': <gensim.models.keyedvectors.Vocab at 0x12cbfa810>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x13170ab50>,
#  'wife': <gensim.models.keyedvectors.Vocab at 0x13170ab90>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x13170abd0>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x13170ac10>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x13170ac50>,
#  'spoil': <gensim.models.keyedvectors.Vocab at 0x13170ac90>,
#  'loving': <gensim.models.keyedvectors.Vocab at 0x13170acd0>,
#  'dreambears': <gensim.models.keyedvectors.Vocab at 0x13170ad10>,
#  'britain': <gensim.models.keyedvectors.Vocab at 0x13170ad50>,
#  'talent': <gensim.models.keyedvectors.Vocab at 0x13170ad90>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x13170add0>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x13170ae10>,
#  'thats': <gensim.models.keyedvectors.Vocab at 0x13170ae50>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x13170ae90>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x13170aed0>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x13170af10>,
#  'bell': <gensim.models.keyedvectors.Vocab at 0x13170af50>,
#  'doesnt': <gensim.models.keyedvectors.Vocab at 0x13170af90>,
#  'sink': <gensim.models.keyedvectors.Vocab at 0x13170afd0>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x13170c250>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x13170c0d0>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x13170c050>,
#  'building': <gensim.models.keyedvectors.Vocab at 0x13170c190>,
#  'falling': <gensim.models.keyedvectors.Vocab at 0x13170c210>,
#  'apart': <gensim.models.keyedvectors.Vocab at 0x13170c110>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x13170c090>,
#  'regret': <gensim.models.keyedvectors.Vocab at 0x13170c1d0>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x13170c2d0>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x13170c150>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x13170c350>,
#  'mi': <gensim.models.keyedvectors.Vocab at 0x13170c290>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x13170c3d0>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x13170c310>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x13170c450>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x13170c490>,
#  'bbc': <gensim.models.keyedvectors.Vocab at 0x13170cb90>,
#  'america': <gensim.models.keyedvectors.Vocab at 0x13170c510>,
#  'y': <gensim.models.keyedvectors.Vocab at 0x13170c610>,
#  'doe': <gensim.models.keyedvectors.Vocab at 0x13170c590>,
#  'hurt': <gensim.models.keyedvectors.Vocab at 0x13170c6d0>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x13170c650>,
#  'chew': <gensim.models.keyedvectors.Vocab at 0x13170c790>,
#  'gum': <gensim.models.keyedvectors.Vocab at 0x13170c710>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x13170c850>,
#  'weight': <gensim.models.keyedvectors.Vocab at 0x13170c7d0>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x13170c910>,
#  'eat': <gensim.models.keyedvectors.Vocab at 0x13170c890>,
#  'dollar': <gensim.models.keyedvectors.Vocab at 0x13170c9d0>,
#  'lose': <gensim.models.keyedvectors.Vocab at 0x13170c950>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x13170ca90>,
#  'telegram': <gensim.models.keyedvectors.Vocab at 0x13170ca10>,
#  'telling': <gensim.models.keyedvectors.Vocab at 0x13170c8d0>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x13170cad0>,
#  'selected': <gensim.models.keyedvectors.Vocab at 0x13170c990>,
#  'ba': <gensim.models.keyedvectors.Vocab at 0x13170cb50>,
#  'unza': <gensim.models.keyedvectors.Vocab at 0x13170ca50>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x13170c750>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x13170cb10>,
#  'stupid': <gensim.models.keyedvectors.Vocab at 0x13170c5d0>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x13170c550>,
#  'flop': <gensim.models.keyedvectors.Vocab at 0x13170c410>,
#  'nut': <gensim.models.keyedvectors.Vocab at 0x13170cc50>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x13170cbd0>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x13170cd10>,
#  'pair': <gensim.models.keyedvectors.Vocab at 0x13170cc90>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x13170cdd0>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x13170cd50>,
#  'birthday': <gensim.models.keyedvectors.Vocab at 0x13170ce90>,
#  'kate': <gensim.models.keyedvectors.Vocab at 0x13170ce10>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x13170cf50>,
#  'staying': <gensim.models.keyedvectors.Vocab at 0x13170ced0>,
#  'room': <gensim.models.keyedvectors.Vocab at 0x13170ccd0>,
#  'fantastic': <gensim.models.keyedvectors.Vocab at 0x13170cf90>,
#  'listening': <gensim.models.keyedvectors.Vocab at 0x13170cd90>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x13170ce50>,
#  'bank': <gensim.models.keyedvectors.Vocab at 0x13170cfd0>,
#  'holiday': <gensim.models.keyedvectors.Vocab at 0x13170c390>,
#  'monday': <gensim.models.keyedvectors.Vocab at 0x13170cf10>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x13170c690>,
#  'bbq': <gensim.models.keyedvectors.Vocab at 0x13170c810>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x13170cc10>,
#  'welcome': <gensim.models.keyedvectors.Vocab at 0x13170c4d0>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x131710550>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x1317100d0>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x131710190>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x131710250>,
#  'helpful': <gensim.models.keyedvectors.Vocab at 0x131710310>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x131710450>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x1317103d0>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x131710290>,
#  'examn': <gensim.models.keyedvectors.Vocab at 0x131710490>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x131710350>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x131710510>,
#  'suck': <gensim.models.keyedvectors.Vocab at 0x131710410>,
#  'hardcore': <gensim.models.keyedvectors.Vocab at 0x131710110>,
#  'hang': <gensim.models.keyedvectors.Vocab at 0x1317104d0>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x131710050>,
#  'ultimate': <gensim.models.keyedvectors.Vocab at 0x1317101d0>,
#  'training': <gensim.models.keyedvectors.Vocab at 0x131710210>,
#  'forward': <gensim.models.keyedvectors.Vocab at 0x131710390>,
#  'sunset': <gensim.models.keyedvectors.Vocab at 0x131710090>,
#  'hi': <gensim.models.keyedvectors.Vocab at 0x1317102d0>,
#  'lin': <gensim.models.keyedvectors.Vocab at 0x1317105d0>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x131710150>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x131710650>,
#  'p': <gensim.models.keyedvectors.Vocab at 0x131710590>,
#  'punished': <gensim.models.keyedvectors.Vocab at 0x1317106d0>,
#  'homework': <gensim.models.keyedvectors.Vocab at 0x131710610>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x131710750>,
#  'allowed': <gensim.models.keyedvectors.Vocab at 0x131710690>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x1317107d0>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x131710710>,
#  'slipped': <gensim.models.keyedvectors.Vocab at 0x131710850>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x131710790>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x1317108d0>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x131710810>,
#  'worry': <gensim.models.keyedvectors.Vocab at 0x131710950>,
#  'cup': <gensim.models.keyedvectors.Vocab at 0x131710890>,
#  'tea': <gensim.models.keyedvectors.Vocab at 0x1317109d0>,
#  'hoping': <gensim.models.keyedvectors.Vocab at 0x131710910>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x131710a50>,
#  'bb': <gensim.models.keyedvectors.Vocab at 0x131710990>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x131710ad0>,
#  'didnt': <gensim.models.keyedvectors.Vocab at 0x131710b10>,
#  'metro': <gensim.models.keyedvectors.Vocab at 0x131710b90>,
#  'exam': <gensim.models.keyedvectors.Vocab at 0x131710c10>,
#  'worst': <gensim.models.keyedvectors.Vocab at 0x131710cd0>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x131710d90>,
#  'thee': <gensim.models.keyedvectors.Vocab at 0x131710e50>,
#  'hospital': <gensim.models.keyedvectors.Vocab at 0x131710f10>,
#  'shall': <gensim.models.keyedvectors.Vocab at 0x131710c50>,
#  'restaurant': <gensim.models.keyedvectors.Vocab at 0x131710bd0>,
#  'celebrate': <gensim.models.keyedvectors.Vocab at 0x131710b50>,
#  'buzz': <gensim.models.keyedvectors.Vocab at 0x131710c90>,
#  'saying': <gensim.models.keyedvectors.Vocab at 0x131710e90>,
#  'bye': <gensim.models.keyedvectors.Vocab at 0x131710dd0>,
#  'difficult': <gensim.models.keyedvectors.Vocab at 0x131710a90>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x131710ed0>,
#  'safe': <gensim.models.keyedvectors.Vocab at 0x131710f90>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x131710d10>,
#  'na': <gensim.models.keyedvectors.Vocab at 0x131710fd0>,
#  'extra': <gensim.models.keyedvectors.Vocab at 0x131710d50>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x131710a10>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x131710e10>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x131710f50>,
#  'convenient': <gensim.models.keyedvectors.Vocab at 0x131712050>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x131712090>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x1317120d0>,
#  'comp': <gensim.models.keyedvectors.Vocab at 0x131712110>,
#  'facebook': <gensim.models.keyedvectors.Vocab at 0x131712150>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x131712190>,
#  'bitch': <gensim.models.keyedvectors.Vocab at 0x1317121d0>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x131712210>,
#  'university': <gensim.models.keyedvectors.Vocab at 0x131712250>,
#  'medicine': <gensim.models.keyedvectors.Vocab at 0x131712290>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x1317122d0>,
#  'wasnt': <gensim.models.keyedvectors.Vocab at 0x131712310>,
#  'myself': <gensim.models.keyedvectors.Vocab at 0x131712350>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x131712390>,
#  'enjoy': <gensim.models.keyedvectors.Vocab at 0x1317123d0>,
#  'themselves': <gensim.models.keyedvectors.Vocab at 0x131712410>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x131712450>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x131712490>,
#  'twitter': <gensim.models.keyedvectors.Vocab at 0x1317124d0>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x131712510>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x131712550>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x131712590>,
#  'boyfriend': <gensim.models.keyedvectors.Vocab at 0x1317125d0>,
#  'returned': <gensim.models.keyedvectors.Vocab at 0x131712610>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x131712650>,
#  'absence': <gensim.models.keyedvectors.Vocab at 0x131712690>,
#  'ant': <gensim.models.keyedvectors.Vocab at 0x1317126d0>,
#  'kingdom': <gensim.models.keyedvectors.Vocab at 0x131712710>,
#  'perfect': <gensim.models.keyedvectors.Vocab at 0x131712750>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x131712790>,
#  'colorful': <gensim.models.keyedvectors.Vocab at 0x1317127d0>,
#  'tale': <gensim.models.keyedvectors.Vocab at 0x131712810>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x131712850>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x131712890>,
#  'fresh': <gensim.models.keyedvectors.Vocab at 0x1317128d0>,
#  'colleague': <gensim.models.keyedvectors.Vocab at 0x131712910>,
#  'met': <gensim.models.keyedvectors.Vocab at 0x131712950>,
#  'elderly': <gensim.models.keyedvectors.Vocab at 0x131712990>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x1317129d0>,
#  'drunk': <gensim.models.keyedvectors.Vocab at 0x131712a10>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x131712a50>,
#  'approached': <gensim.models.keyedvectors.Vocab at 0x131712a90>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x131712ad0>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x131712b10>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x131712b50>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x131712b90>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x131712bd0>,
#  'turn': <gensim.models.keyedvectors.Vocab at 0x131712c10>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x131712c50>,
#  'ta': <gensim.models.keyedvectors.Vocab at 0x131712c90>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x131712cd0>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x131712d10>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x131712d50>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x131712d90>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x131712dd0>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x131712e10>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x131712e50>,
#  'lunch': <gensim.models.keyedvectors.Vocab at 0x131712e90>,
#  'eleven': <gensim.models.keyedvectors.Vocab at 0x131712ed0>,
#  'thirty': <gensim.models.keyedvectors.Vocab at 0x131712f10>,
#  'afterwards': <gensim.models.keyedvectors.Vocab at 0x131712f50>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x131712f90>,
#  'valerie': <gensim.models.keyedvectors.Vocab at 0x131712fd0>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x1317140d0>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x131714090>,
#  'choice': <gensim.models.keyedvectors.Vocab at 0x131714150>,
#  'favorite': <gensim.models.keyedvectors.Vocab at 0x131714050>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x1317141d0>,
#  'release': <gensim.models.keyedvectors.Vocab at 0x131714110>,
#  'jon': <gensim.models.keyedvectors.Vocab at 0x131714250>,
#  'ton': <gensim.models.keyedvectors.Vocab at 0x131714190>,
#  'sweat': <gensim.models.keyedvectors.Vocab at 0x1317142d0>,
#  'bruise': <gensim.models.keyedvectors.Vocab at 0x131714210>,
#  'team': <gensim.models.keyedvectors.Vocab at 0x131714350>,
#  'missed': <gensim.models.keyedvectors.Vocab at 0x131714290>,
#  'picked': <gensim.models.keyedvectors.Vocab at 0x1317143d0>,
#  'stuff': <gensim.models.keyedvectors.Vocab at 0x131714310>,
#  'nd': <gensim.models.keyedvectors.Vocab at 0x131714450>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x131714390>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x1317144d0>,
#  'leaving': <gensim.models.keyedvectors.Vocab at 0x131714410>,
#  'tomorrow': <gensim.models.keyedvectors.Vocab at 0x131714550>,
#  'lol': <gensim.models.keyedvectors.Vocab at 0x131714490>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x1317145d0>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x131714510>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x131714650>,
#  'doll': <gensim.models.keyedvectors.Vocab at 0x131714690>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x131714f10>,
#  'en': <gensim.models.keyedvectors.Vocab at 0x131714710>,
#  'el': <gensim.models.keyedvectors.Vocab at 0x131714810>,
#  'con': <gensim.models.keyedvectors.Vocab at 0x131714790>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x1317148d0>,
#  'upload': <gensim.models.keyedvectors.Vocab at 0x131714850>,
#  'photo': <gensim.models.keyedvectors.Vocab at 0x131714990>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x131714910>,
#  'leader': <gensim.models.keyedvectors.Vocab at 0x131714a50>,
#  'told': <gensim.models.keyedvectors.Vocab at 0x1317149d0>,
#  'chosen': <gensim.models.keyedvectors.Vocab at 0x131714b10>,
#  'english': <gensim.models.keyedvectors.Vocab at 0x131714a90>,
#  'lecture': <gensim.models.keyedvectors.Vocab at 0x131714bd0>,
#  'bet': <gensim.models.keyedvectors.Vocab at 0x131714b50>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x131714c90>,
#  'ate': <gensim.models.keyedvectors.Vocab at 0x131714c10>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x131714d50>,
#  'chat': <gensim.models.keyedvectors.Vocab at 0x131714cd0>,
#  'pea': <gensim.models.keyedvectors.Vocab at 0x131714e10>,
#  'plant': <gensim.models.keyedvectors.Vocab at 0x131714d90>,
#  'mr': <gensim.models.keyedvectors.Vocab at 0x131714c50>,
#  'mom': <gensim.models.keyedvectors.Vocab at 0x131714e50>,
#  'appreciate': <gensim.models.keyedvectors.Vocab at 0x131714d10>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x131714ed0>,
#  'dad': <gensim.models.keyedvectors.Vocab at 0x131714dd0>,
#  'respect': <gensim.models.keyedvectors.Vocab at 0x131714ad0>,
#  'batman': <gensim.models.keyedvectors.Vocab at 0x131714e90>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x131714950>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x131714b90>,
#  'sadness': <gensim.models.keyedvectors.Vocab at 0x1317147d0>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x131714a10>,
#  'ball': <gensim.models.keyedvectors.Vocab at 0x1317146d0>,
#  'pocket': <gensim.models.keyedvectors.Vocab at 0x131714890>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x131714590>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x131714750>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x131714f90>,
#  'rabbit': <gensim.models.keyedvectors.Vocab at 0x131714610>,
#  'gon': <gensim.models.keyedvectors.Vocab at 0x131714f50>,
#  'tan': <gensim.models.keyedvectors.Vocab at 0x131714fd0>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x131716250>,
#  'youre': <gensim.models.keyedvectors.Vocab at 0x1317160d0>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x131716110>,
#  'demi': <gensim.models.keyedvectors.Vocab at 0x1317161d0>,
#  'lovato': <gensim.models.keyedvectors.Vocab at 0x131716050>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x131716150>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x131716290>,
#  'airport': <gensim.models.keyedvectors.Vocab at 0x131716310>,
#  'lil': <gensim.models.keyedvectors.Vocab at 0x131716390>,
#  'starbucks': <gensim.models.keyedvectors.Vocab at 0x131716a90>,
#  'hehe': <gensim.models.keyedvectors.Vocab at 0x131716090>,
#  'needed': <gensim.models.keyedvectors.Vocab at 0x131716410>,
#  'reminder': <gensim.models.keyedvectors.Vocab at 0x131716350>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x131716510>,
#  'paul': <gensim.models.keyedvectors.Vocab at 0x131716490>,
#  'finally': <gensim.models.keyedvectors.Vocab at 0x1317165d0>,
#  'doctor': <gensim.models.keyedvectors.Vocab at 0x131716550>,
#  'grow': <gensim.models.keyedvectors.Vocab at 0x131716690>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x131716610>,
#  'sick': <gensim.models.keyedvectors.Vocab at 0x131716750>,
#  'doc': <gensim.models.keyedvectors.Vocab at 0x1317166d0>,
#  'website': <gensim.models.keyedvectors.Vocab at 0x131716810>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x131716790>,
#  'ticket': <gensim.models.keyedvectors.Vocab at 0x1317168d0>,
#  'booking': <gensim.models.keyedvectors.Vocab at 0x131716850>,
#  'service': <gensim.models.keyedvectors.Vocab at 0x131716990>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x131716910>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x1317167d0>,
#  'hangin': <gensim.models.keyedvectors.Vocab at 0x1317169d0>,
#  'loved': <gensim.models.keyedvectors.Vocab at 0x131716890>,
#  'tonight': <gensim.models.keyedvectors.Vocab at 0x131716a50>,
#  'divorced': <gensim.models.keyedvectors.Vocab at 0x131716950>,
#  'parent': <gensim.models.keyedvectors.Vocab at 0x131716650>,
#  'separated': <gensim.models.keyedvectors.Vocab at 0x131716a10>,
#  'behind': <gensim.models.keyedvectors.Vocab at 0x1317164d0>,
#  'father': <gensim.models.keyedvectors.Vocab at 0x131716710>,
#  'wanted': <gensim.models.keyedvectors.Vocab at 0x1317162d0>,
#  'sister': <gensim.models.keyedvectors.Vocab at 0x131716590>,
#  'broke': <gensim.models.keyedvectors.Vocab at 0x131716210>,
#  'china': <gensim.models.keyedvectors.Vocab at 0x1317163d0>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x131716ad0>,
#  'heading': <gensim.models.keyedvectors.Vocab at 0x131716190>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x131716b50>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x131716450>,
#  'breaking': <gensim.models.keyedvectors.Vocab at 0x131716bd0>,
#  'dawn': <gensim.models.keyedvectors.Vocab at 0x131716b10>,
#  'pt': <gensim.models.keyedvectors.Vocab at 0x131716c50>,
#  'whats': <gensim.models.keyedvectors.Vocab at 0x131716b90>,
#  'enjoyed': <gensim.models.keyedvectors.Vocab at 0x131716cd0>,
#  'meeting': <gensim.models.keyedvectors.Vocab at 0x131716c10>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x131716d50>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x131716c90>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x131716dd0>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x131716d10>,
#  'friendly': <gensim.models.keyedvectors.Vocab at 0x131716e50>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x131716e90>,
#  'grade': <gensim.models.keyedvectors.Vocab at 0x131716f10>,
#  'lived': <gensim.models.keyedvectors.Vocab at 0x131716f90>,
#  'moved': <gensim.models.keyedvectors.Vocab at 0x131716ed0>,
#  'changed': <gensim.models.keyedvectors.Vocab at 0x131716fd0>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x131716e10>,
#  'pic': <gensim.models.keyedvectors.Vocab at 0x131716d90>,
#  'car': <gensim.models.keyedvectors.Vocab at 0x131716f50>,
#  'looked': <gensim.models.keyedvectors.Vocab at 0x131719050>,
#  'clean': <gensim.models.keyedvectors.Vocab at 0x1317190d0>,
#  'fuckin': <gensim.models.keyedvectors.Vocab at 0x131719190>,
#  'raining': <gensim.models.keyedvectors.Vocab at 0x131719250>,
#  'rain': <gensim.models.keyedvectors.Vocab at 0x1317196d0>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x131719090>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x131719210>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x1317191d0>,
#  'concert': <gensim.models.keyedvectors.Vocab at 0x131719410>,
#  'yeh': <gensim.models.keyedvectors.Vocab at 0x131719350>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x1317194d0>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x131719450>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x131719590>,
#  'write': <gensim.models.keyedvectors.Vocab at 0x131719510>,
#  'paper': <gensim.models.keyedvectors.Vocab at 0x131719650>,
#  'purse': <gensim.models.keyedvectors.Vocab at 0x1317195d0>,
#  'belonged': <gensim.models.keyedvectors.Vocab at 0x131719710>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x131719690>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x1317197d0>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x131719750>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x131719890>,
#  'tweet': <gensim.models.keyedvectors.Vocab at 0x131719490>,
#  'omg': <gensim.models.keyedvectors.Vocab at 0x131719610>,
#  'arent': <gensim.models.keyedvectors.Vocab at 0x131719290>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x131719550>,
#  'shock': <gensim.models.keyedvectors.Vocab at 0x1317192d0>,
#  'horror': <gensim.models.keyedvectors.Vocab at 0x1317193d0>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x131719310>,
#  'bothered': <gensim.models.keyedvectors.Vocab at 0x131719150>,
#  'welcoming': <gensim.models.keyedvectors.Vocab at 0x131719790>,
#  'visit': <gensim.models.keyedvectors.Vocab at 0x131719390>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x131719850>,
#  'sigh': <gensim.models.keyedvectors.Vocab at 0x131719110>,
#  'exasperation': <gensim.models.keyedvectors.Vocab at 0x131719910>,
#  'foot': <gensim.models.keyedvectors.Vocab at 0x131719810>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x131719990>,
#  'talked': <gensim.models.keyedvectors.Vocab at 0x1317198d0>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x131719a10>,
#  'haha': <gensim.models.keyedvectors.Vocab at 0x131719950>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x131719a90>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x1317199d0>,
#  'shes': <gensim.models.keyedvectors.Vocab at 0x131719b10>,
#  'highly': <gensim.models.keyedvectors.Vocab at 0x131719b50>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x131719bd0>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x131719cd0>,
#  'plane': <gensim.models.keyedvectors.Vocab at 0x131719c50>,
#  'learned': <gensim.models.keyedvectors.Vocab at 0x131719d90>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x131719d10>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x131719e50>,
#  'dying': <gensim.models.keyedvectors.Vocab at 0x131719dd0>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x131719f10>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x131719e90>,
#  'doing': <gensim.models.keyedvectors.Vocab at 0x131719fd0>,
#  'bob': <gensim.models.keyedvectors.Vocab at 0x131719f50>,
#  'chapter': <gensim.models.keyedvectors.Vocab at 0x131719d50>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x131719e10>,
#  'finished': <gensim.models.keyedvectors.Vocab at 0x131719ed0>,
#  'walking': <gensim.models.keyedvectors.Vocab at 0x131719f90>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x131719c90>,
#  'street': <gensim.models.keyedvectors.Vocab at 0x131719ad0>,
#  'showed': <gensim.models.keyedvectors.Vocab at 0x131719c10>,
#  'knife': <gensim.models.keyedvectors.Vocab at 0x131719b90>,
#  'stole': <gensim.models.keyedvectors.Vocab at 0x131719a50>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x13171b1d0>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x13171b050>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x13171b090>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x13171b150>,
#  'somebody': <gensim.models.keyedvectors.Vocab at 0x13171b210>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x13171b2d0>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x13171b390>,
#  'flag': <gensim.models.keyedvectors.Vocab at 0x13171b450>,
#  'football': <gensim.models.keyedvectors.Vocab at 0x13171b510>,
#  'grab': <gensim.models.keyedvectors.Vocab at 0x13171b310>,
#  'carrier': <gensim.models.keyedvectors.Vocab at 0x13171b250>,
#  'wearing': <gensim.models.keyedvectors.Vocab at 0x13171b410>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x13171b290>,
#  'relative': <gensim.models.keyedvectors.Vocab at 0x13171b490>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x13171b610>,
#  'danger': <gensim.models.keyedvectors.Vocab at 0x13171b710>,
#  'lake': <gensim.models.keyedvectors.Vocab at 0x13171b7d0>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x13171b890>,
#  'da': <gensim.models.keyedvectors.Vocab at 0x13171b9d0>,
#  'bus': <gensim.models.keyedvectors.Vocab at 0x13171bc90>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x13171b910>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x13171b850>,
#  'uncle': <gensim.models.keyedvectors.Vocab at 0x13171b110>,
#  'therapy': <gensim.models.keyedvectors.Vocab at 0x13171b3d0>,
#  'damn': <gensim.models.keyedvectors.Vocab at 0x13171b5d0>,
#  'somewhere': <gensim.models.keyedvectors.Vocab at 0x13171b190>,
#  'wow': <gensim.models.keyedvectors.Vocab at 0x13171b650>,
#  'joined': <gensim.models.keyedvectors.Vocab at 0x13171b8d0>,
#  'photography': <gensim.models.keyedvectors.Vocab at 0x13171b750>,
#  'scene': <gensim.models.keyedvectors.Vocab at 0x13171ba10>,
#  'recently': <gensim.models.keyedvectors.Vocab at 0x13171b950>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x13171bad0>,
#  'hurting': <gensim.models.keyedvectors.Vocab at 0x13171ba50>,
#  'town': <gensim.models.keyedvectors.Vocab at 0x13171bb90>,
#  'party': <gensim.models.keyedvectors.Vocab at 0x13171bb10>,
#  'shoe': <gensim.models.keyedvectors.Vocab at 0x13171b990>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x13171bbd0>,
#  'wheres': <gensim.models.keyedvectors.Vocab at 0x13171ba90>,
#  'o': <gensim.models.keyedvectors.Vocab at 0x13171bc50>,
#  'thousand': <gensim.models.keyedvectors.Vocab at 0x13171bb50>,
#  'scary': <gensim.models.keyedvectors.Vocab at 0x13171b350>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x13171bc10>,
#  'request': <gensim.models.keyedvectors.Vocab at 0x13171b6d0>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x13171b810>,
#  'married': <gensim.models.keyedvectors.Vocab at 0x13171b550>,
#  'yr': <gensim.models.keyedvectors.Vocab at 0x13171b590>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x13171b4d0>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x13171b790>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x13171bd10>,
#  'blah': <gensim.models.keyedvectors.Vocab at 0x13171bd90>,
#  'teach': <gensim.models.keyedvectors.Vocab at 0x13171be50>,
#  'attitude': <gensim.models.keyedvectors.Vocab at 0x13171bf10>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x13171bcd0>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x13171b690>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x13171b0d0>,
#  'cute': <gensim.models.keyedvectors.Vocab at 0x13171bf50>,
#  'manchester': <gensim.models.keyedvectors.Vocab at 0x13171bd50>,
#  'united': <gensim.models.keyedvectors.Vocab at 0x13171bf90>,
#  'suit': <gensim.models.keyedvectors.Vocab at 0x13171be90>,
#  'jacket': <gensim.models.keyedvectors.Vocab at 0x13171bfd0>,
#  'youll': <gensim.models.keyedvectors.Vocab at 0x13171bed0>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x13171bdd0>,
#  'suspicious': <gensim.models.keyedvectors.Vocab at 0x13171be10>,
#  'character': <gensim.models.keyedvectors.Vocab at 0x13171d2d0>,
#  'towards': <gensim.models.keyedvectors.Vocab at 0x13171d050>,
#  'anyone': <gensim.models.keyedvectors.Vocab at 0x13171d110>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x13171d1d0>,
#  'train': <gensim.models.keyedvectors.Vocab at 0x13171d290>,
#  'national': <gensim.models.keyedvectors.Vocab at 0x13171d350>,
#  'comment': <gensim.models.keyedvectors.Vocab at 0x13171d150>,
#  'adventure': <gensim.models.keyedvectors.Vocab at 0x13171d210>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x13171d090>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x13171d490>,
#  'wear': <gensim.models.keyedvectors.Vocab at 0x13171d250>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x13171d3d0>,
#  'tried': <gensim.models.keyedvectors.Vocab at 0x13171d0d0>,
#  'died': <gensim.models.keyedvectors.Vocab at 0x13171d310>,
#  'sentence': <gensim.models.keyedvectors.Vocab at 0x13171d410>,
#  'id': <gensim.models.keyedvectors.Vocab at 0x13171d190>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x13171d4d0>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x13171d390>,
#  'playing': <gensim.models.keyedvectors.Vocab at 0x13171d550>,
#  'seattle': <gensim.models.keyedvectors.Vocab at 0x13171d450>,
#  'yay': <gensim.models.keyedvectors.Vocab at 0x13171d5d0>,
#  'boo': <gensim.models.keyedvectors.Vocab at 0x13171d510>,
#  'matt': <gensim.models.keyedvectors.Vocab at 0x13171d650>,
#  'begin': <gensim.models.keyedvectors.Vocab at 0x13171d590>,
#  'journey': <gensim.models.keyedvectors.Vocab at 0x13171d6d0>,
#  'acquaintance': <gensim.models.keyedvectors.Vocab at 0x13171d610>,
#  'table': <gensim.models.keyedvectors.Vocab at 0x13171d750>,
#  'r': <gensim.models.keyedvectors.Vocab at 0x13171d790>,
#  'insult': <gensim.models.keyedvectors.Vocab at 0x13171d810>,
#  'cleaning': <gensim.models.keyedvectors.Vocab at 0x13171d890>,
#  'rest': <gensim.models.keyedvectors.Vocab at 0x13171d950>,
#  'brother': <gensim.models.keyedvectors.Vocab at 0x13171da10>,
#  'zealand': <gensim.models.keyedvectors.Vocab at 0x13171dad0>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x13171db90>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x13171dc10>,
#  'none': <gensim.models.keyedvectors.Vocab at 0x13171df10>,
#  'previously': <gensim.models.keyedvectors.Vocab at 0x13171db50>,
#  'accompany': <gensim.models.keyedvectors.Vocab at 0x13171d9d0>,
#  'choose': <gensim.models.keyedvectors.Vocab at 0x13171da90>,
#  'pattern': <gensim.models.keyedvectors.Vocab at 0x13171d690>,
#  'shirt': <gensim.models.keyedvectors.Vocab at 0x13171d710>,
#  'sushi': <gensim.models.keyedvectors.Vocab at 0x13171dbd0>,
#  'row': <gensim.models.keyedvectors.Vocab at 0x13171da50>,
#  'isnt': <gensim.models.keyedvectors.Vocab at 0x13171dd10>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x13171dc50>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x13171ddd0>,
#  'headache': <gensim.models.keyedvectors.Vocab at 0x13171dd50>,
#  'dropped': <gensim.models.keyedvectors.Vocab at 0x13171de90>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x13171de10>,
#  'becoming': <gensim.models.keyedvectors.Vocab at 0x13171df50>,
#  'pressure': <gensim.models.keyedvectors.Vocab at 0x13171ded0>,
#  'marry': <gensim.models.keyedvectors.Vocab at 0x13171dc90>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x13171df90>,
#  'thatll': <gensim.models.keyedvectors.Vocab at 0x13171dd90>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x13171de50>,
#  'period': <gensim.models.keyedvectors.Vocab at 0x13171d7d0>,
#  'ouch': <gensim.models.keyedvectors.Vocab at 0x13171db10>,
#  'acid': <gensim.models.keyedvectors.Vocab at 0x13171d8d0>,
#  'dare': <gensim.models.keyedvectors.Vocab at 0x13171d910>,
#  'speak': <gensim.models.keyedvectors.Vocab at 0x13171dcd0>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x13171d850>,
#  'busy': <gensim.models.keyedvectors.Vocab at 0x13171d990>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x13171dfd0>,
#  'hello': <gensim.models.keyedvectors.Vocab at 0x13171f090>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x13171f110>,
#  'woot': <gensim.models.keyedvectors.Vocab at 0x13171f050>,
#  'freaking': <gensim.models.keyedvectors.Vocab at 0x13171f190>,
#  'hoo': <gensim.models.keyedvectors.Vocab at 0x13171f1d0>,
#  'tho': <gensim.models.keyedvectors.Vocab at 0x13171f250>,
#  'mad': <gensim.models.keyedvectors.Vocab at 0x13171f2d0>,
#  'itunes': <gensim.models.keyedvectors.Vocab at 0x13171f390>,
#  'chart': <gensim.models.keyedvectors.Vocab at 0x13171f450>,
#  'embarrassed': <gensim.models.keyedvectors.Vocab at 0x13171f510>,
#  'italy': <gensim.models.keyedvectors.Vocab at 0x13171f5d0>,
#  'lady': <gensim.models.keyedvectors.Vocab at 0x13171f650>,
#  'cafe': <gensim.models.keyedvectors.Vocab at 0x13171f590>,
#  'kiss': <gensim.models.keyedvectors.Vocab at 0x13171f4d0>,
#  'wine': <gensim.models.keyedvectors.Vocab at 0x13171f150>,
#  'weve': <gensim.models.keyedvectors.Vocab at 0x13171f490>,
#  'double': <gensim.models.keyedvectors.Vocab at 0x13171f690>,
#  'bath': <gensim.models.keyedvectors.Vocab at 0x13171f790>,
#  'shower': <gensim.models.keyedvectors.Vocab at 0x13171f850>,
#  'jonas': <gensim.models.keyedvectors.Vocab at 0x13171f910>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x13171f990>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x13171fe50>,
#  'land': <gensim.models.keyedvectors.Vocab at 0x13171f8d0>,
#  'studying': <gensim.models.keyedvectors.Vocab at 0x13171f750>,
#  'sat': <gensim.models.keyedvectors.Vocab at 0x13171f810>,
#  'wo': <gensim.models.keyedvectors.Vocab at 0x13171f310>,
#  'blackberry': <gensim.models.keyedvectors.Vocab at 0x13171f290>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x13171f410>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x13171f0d0>,
#  'rude': <gensim.models.keyedvectors.Vocab at 0x13171f890>,
#  'jonasbrothers': <gensim.models.keyedvectors.Vocab at 0x13171f710>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x13171fa10>,
#  'paranoid': <gensim.models.keyedvectors.Vocab at 0x13171f950>,
#  'amazing': <gensim.models.keyedvectors.Vocab at 0x13171fb10>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x13171fa90>,
#  'silly': <gensim.models.keyedvectors.Vocab at 0x13171fbd0>,
#  'tweetdeck': <gensim.models.keyedvectors.Vocab at 0x13171fb50>,
#  'teacher': <gensim.models.keyedvectors.Vocab at 0x13171fc90>,
#  'asked': <gensim.models.keyedvectors.Vocab at 0x13171fc10>,
#  'scolded': <gensim.models.keyedvectors.Vocab at 0x13171fd50>,
#  'immediately': <gensim.models.keyedvectors.Vocab at 0x13171fcd0>,
#  'billion': <gensim.models.keyedvectors.Vocab at 0x13171fb90>,
#  'classic': <gensim.models.keyedvectors.Vocab at 0x13171fd90>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x13171fc50>,
#  'cold': <gensim.models.keyedvectors.Vocab at 0x13171fe10>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x13171fd10>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x13171f9d0>,
#  'palace': <gensim.models.keyedvectors.Vocab at 0x13171fdd0>,
#  'arranged': <gensim.models.keyedvectors.Vocab at 0x13171f3d0>,
#  'drawing': <gensim.models.keyedvectors.Vocab at 0x13171fad0>,
#  'removed': <gensim.models.keyedvectors.Vocab at 0x13171f210>,
#  'doubt': <gensim.models.keyedvectors.Vocab at 0x13171f7d0>,
#  'delighted': <gensim.models.keyedvectors.Vocab at 0x13171f550>,
#  'rid': <gensim.models.keyedvectors.Vocab at 0x13171f610>,
#  'page': <gensim.models.keyedvectors.Vocab at 0x13171fa50>,
#  'ft': <gensim.models.keyedvectors.Vocab at 0x13171f350>,
#  'ahhh': <gensim.models.keyedvectors.Vocab at 0x13171fed0>,
#  'song': <gensim.models.keyedvectors.Vocab at 0x13171ff10>,
#  'season': <gensim.models.keyedvectors.Vocab at 0x13171ff90>,
#  'listen': <gensim.models.keyedvectors.Vocab at 0x13171f6d0>,
#  'nature': <gensim.models.keyedvectors.Vocab at 0x13171fe90>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x13171ff50>,
#  'goodnight': <gensim.models.keyedvectors.Vocab at 0x13171ffd0>,
#  'yea': <gensim.models.keyedvectors.Vocab at 0x131723050>,
#  'tough': <gensim.models.keyedvectors.Vocab at 0x131723110>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x131723810>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x131723250>,
#  'lens': <gensim.models.keyedvectors.Vocab at 0x1317230d0>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x1317231d0>,
#  'fee': <gensim.models.keyedvectors.Vocab at 0x1317232d0>,
#  'hn': <gensim.models.keyedvectors.Vocab at 0x131723410>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x131723390>,
#  'girlfriend': <gensim.models.keyedvectors.Vocab at 0x1317234d0>,
#  'lonely': <gensim.models.keyedvectors.Vocab at 0x131723450>,
#  'heartbroken': <gensim.models.keyedvectors.Vocab at 0x131723590>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x131723510>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x131723650>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x1317235d0>,
#  'anyway': <gensim.models.keyedvectors.Vocab at 0x131723710>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x131723690>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x131723550>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x131723750>,
#  'retirement': <gensim.models.keyedvectors.Vocab at 0x131723610>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x1317237d0>,
#  'mud': <gensim.models.keyedvectors.Vocab at 0x131723490>,
#  'district': <gensim.models.keyedvectors.Vocab at 0x131723e90>,
#  'managed': <gensim.models.keyedvectors.Vocab at 0x131723310>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x131723350>,
#  'km': <gensim.models.keyedvectors.Vocab at 0x131723090>,
#  'ski': <gensim.models.keyedvectors.Vocab at 0x131723850>,
#  'fairly': <gensim.models.keyedvectors.Vocab at 0x131723290>,
#  'terrible': <gensim.models.keyedvectors.Vocab at 0x131723910>,
#  'beast': <gensim.models.keyedvectors.Vocab at 0x131723890>,
#  'garden': <gensim.models.keyedvectors.Vocab at 0x1317239d0>,
#  'collect': <gensim.models.keyedvectors.Vocab at 0x131723950>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x131723a90>,
#  'bc': <gensim.models.keyedvectors.Vocab at 0x131723a10>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x131723b50>,
#  'coat': <gensim.models.keyedvectors.Vocab at 0x131723ad0>,
#  'yellow': <gensim.models.keyedvectors.Vocab at 0x131723c10>,
#  'lt': <gensim.models.keyedvectors.Vocab at 0x131723b90>,
#  'doin': <gensim.models.keyedvectors.Vocab at 0x131723cd0>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x131723c50>,
#  'wont': <gensim.models.keyedvectors.Vocab at 0x131723d90>,
#  'bag': <gensim.models.keyedvectors.Vocab at 0x131723d10>,
#  'stranger': <gensim.models.keyedvectors.Vocab at 0x131723bd0>,
#  'passed': <gensim.models.keyedvectors.Vocab at 0x131723dd0>,
#  'gave': <gensim.models.keyedvectors.Vocab at 0x131723c90>,
#  'ashamed': <gensim.models.keyedvectors.Vocab at 0x131723e50>,
#  'fail': <gensim.models.keyedvectors.Vocab at 0x131723b10>,
#  'screaming': <gensim.models.keyedvectors.Vocab at 0x131723990>,
#  'scream': <gensim.models.keyedvectors.Vocab at 0x131723150>,
#  'sooo': <gensim.models.keyedvectors.Vocab at 0x1317233d0>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x131723ed0>,
#  'chair': <gensim.models.keyedvectors.Vocab at 0x131723f90>,
#  'laughing': <gensim.models.keyedvectors.Vocab at 0x1317236d0>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x131723210>,
#  'fired': <gensim.models.keyedvectors.Vocab at 0x131723a50>,
#  'discount': <gensim.models.keyedvectors.Vocab at 0x131723e10>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x131723d50>,
#  'sunshine': <gensim.models.keyedvectors.Vocab at 0x131723f50>,
#  'missing': <gensim.models.keyedvectors.Vocab at 0x1317238d0>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x131723190>,
#  'xxxx': <gensim.models.keyedvectors.Vocab at 0x131723790>,
#  'david': <gensim.models.keyedvectors.Vocab at 0x131723f10>,
#  'yey': <gensim.models.keyedvectors.Vocab at 0x131723fd0>,
#  'jack': <gensim.models.keyedvectors.Vocab at 0x131726050>,
#  'match': <gensim.models.keyedvectors.Vocab at 0x131726190>,
#  'barbara': <gensim.models.keyedvectors.Vocab at 0x131726090>,
#  'barb': <gensim.models.keyedvectors.Vocab at 0x131726110>,
#  'serial': <gensim.models.keyedvectors.Vocab at 0x1317261d0>,
#  'explanation': <gensim.models.keyedvectors.Vocab at 0x131726250>,
#  'baby': <gensim.models.keyedvectors.Vocab at 0x131726310>,
#  'handy': <gensim.models.keyedvectors.Vocab at 0x1317263d0>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x131726490>,
#  'junior': <gensim.models.keyedvectors.Vocab at 0x131726550>,
#  'investment': <gensim.models.keyedvectors.Vocab at 0x131726610>,
#  'fortune': <gensim.models.keyedvectors.Vocab at 0x1317266d0>,
#  'career': <gensim.models.keyedvectors.Vocab at 0x1317264d0>,
#  'path': <gensim.models.keyedvectors.Vocab at 0x131726950>,
#  'ahead': <gensim.models.keyedvectors.Vocab at 0x131726410>,
#  'aww': <gensim.models.keyedvectors.Vocab at 0x131726350>,
#  'noooo': <gensim.models.keyedvectors.Vocab at 0x131726450>,
#  'iphone': <gensim.models.keyedvectors.Vocab at 0x131726510>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x1317260d0>,
#  'credit': <gensim.models.keyedvectors.Vocab at 0x131726150>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x131726650>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x1317262d0>,
#  'cell': <gensim.models.keyedvectors.Vocab at 0x1317267d0>,
#  'mass': <gensim.models.keyedvectors.Vocab at 0x131726710>,
#  'fruit': <gensim.models.keyedvectors.Vocab at 0x1317268d0>,
#  'sugar': <gensim.models.keyedvectors.Vocab at 0x131726850>,
#  'covered': <gensim.models.keyedvectors.Vocab at 0x131726990>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x131726910>,
#  'tummy': <gensim.models.keyedvectors.Vocab at 0x131726a50>,
#  'honey': <gensim.models.keyedvectors.Vocab at 0x1317269d0>,
#  'forgot': <gensim.models.keyedvectors.Vocab at 0x131726b10>,
#  'anniversary': <gensim.models.keyedvectors.Vocab at 0x131726a90>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x131726bd0>,
#  'sunday': <gensim.models.keyedvectors.Vocab at 0x131726590>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x131726390>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x1317265d0>,
#  'blast': <gensim.models.keyedvectors.Vocab at 0x131726750>,
#  'havent': <gensim.models.keyedvectors.Vocab at 0x131726a10>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x131726b90>,
#  'tooo': <gensim.models.keyedvectors.Vocab at 0x131726c90>,
#  'fly': <gensim.models.keyedvectors.Vocab at 0x131726d50>,
#  'mark': <gensim.models.keyedvectors.Vocab at 0x131726e10>,
#  'tv': <gensim.models.keyedvectors.Vocab at 0x131726ed0>,
#  'anger': <gensim.models.keyedvectors.Vocab at 0x131726c10>,
#  'regretted': <gensim.models.keyedvectors.Vocab at 0x131726ad0>,
#  'terribly': <gensim.models.keyedvectors.Vocab at 0x131726810>,
#  'dannywood': <gensim.models.keyedvectors.Vocab at 0x131726c50>,
#  'btw': <gensim.models.keyedvectors.Vocab at 0x131726790>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x131726d90>,
#  'screamed': <gensim.models.keyedvectors.Vocab at 0x131726f90>,
#  'pc': <gensim.models.keyedvectors.Vocab at 0x131726f10>,
#  'nobody': <gensim.models.keyedvectors.Vocab at 0x131726890>,
#  'thailand': <gensim.models.keyedvectors.Vocab at 0x131726690>,
#  'excited': <gensim.models.keyedvectors.Vocab at 0x131726b50>,
#  'chicken': <gensim.models.keyedvectors.Vocab at 0x131726e50>,
#  'opened': <gensim.models.keyedvectors.Vocab at 0x131726cd0>,
#  'internal': <gensim.models.keyedvectors.Vocab at 0x131726dd0>,
#  'discovered': <gensim.models.keyedvectors.Vocab at 0x131726fd0>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x131726e90>,
#  'soup': <gensim.models.keyedvectors.Vocab at 0x131726f50>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x131726290>,
#  'panda': <gensim.models.keyedvectors.Vocab at 0x131726d10>,
#  'cheer': <gensim.models.keyedvectors.Vocab at 0x131726210>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x131729050>,
#  'officially': <gensim.models.keyedvectors.Vocab at 0x1317290d0>,
#  'depressed': <gensim.models.keyedvectors.Vocab at 0x131729110>,
#  'gone': <gensim.models.keyedvectors.Vocab at 0x131729190>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x1317291d0>,
#  'ups': <gensim.models.keyedvectors.Vocab at 0x131729250>,
#  'cable': <gensim.models.keyedvectors.Vocab at 0x1317292d0>,
#  'til': <gensim.models.keyedvectors.Vocab at 0x131729390>,
#  'till': <gensim.models.keyedvectors.Vocab at 0x131729450>,
#  'shud': <gensim.models.keyedvectors.Vocab at 0x1317294d0>,
#  'cycling': <gensim.models.keyedvectors.Vocab at 0x131729ad0>,
#  'thatd': <gensim.models.keyedvectors.Vocab at 0x131729410>,
#  'k': <gensim.models.keyedvectors.Vocab at 0x131729310>,
#  'curl': <gensim.models.keyedvectors.Vocab at 0x131729350>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x131729510>,
#  'dvd': <gensim.models.keyedvectors.Vocab at 0x1317293d0>,
#  'cure': <gensim.models.keyedvectors.Vocab at 0x131729610>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x131729550>,
#  'folk': <gensim.models.keyedvectors.Vocab at 0x1317296d0>,
#  'couldnt': <gensim.models.keyedvectors.Vocab at 0x131729650>,
#  'save': <gensim.models.keyedvectors.Vocab at 0x131729790>,
#  'bought': <gensim.models.keyedvectors.Vocab at 0x131729710>,
#  'northern': <gensim.models.keyedvectors.Vocab at 0x131729850>,
#  'suburb': <gensim.models.keyedvectors.Vocab at 0x1317297d0>,
#  'bride': <gensim.models.keyedvectors.Vocab at 0x131729910>,
#  'gorgeous': <gensim.models.keyedvectors.Vocab at 0x131729890>,
#  'dunno': <gensim.models.keyedvectors.Vocab at 0x1317299d0>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x131729950>,
#  'packing': <gensim.models.keyedvectors.Vocab at 0x131729810>,
#  'desk': <gensim.models.keyedvectors.Vocab at 0x131729a10>,
#  'sue': <gensim.models.keyedvectors.Vocab at 0x1317298d0>,
#  'cross': <gensim.models.keyedvectors.Vocab at 0x131729a90>,
#  'machine': <gensim.models.keyedvectors.Vocab at 0x131729990>,
#  'gun': <gensim.models.keyedvectors.Vocab at 0x131729690>,
#  'tank': <gensim.models.keyedvectors.Vocab at 0x131729a50>,
#  'flame': <gensim.models.keyedvectors.Vocab at 0x131729490>,
#  'delivery': <gensim.models.keyedvectors.Vocab at 0x131729750>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x131729150>,
#  'dance': <gensim.models.keyedvectors.Vocab at 0x1317295d0>,
#  'church': <gensim.models.keyedvectors.Vocab at 0x131729290>,
#  'decided': <gensim.models.keyedvectors.Vocab at 0x131729090>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x131729b10>,
#  'beach': <gensim.models.keyedvectors.Vocab at 0x131729210>,
#  'god': <gensim.models.keyedvectors.Vocab at 0x131729b90>,
#  'theyre': <gensim.models.keyedvectors.Vocab at 0x131729590>,
#  'wall': <gensim.models.keyedvectors.Vocab at 0x131729c10>,
#  'join': <gensim.models.keyedvectors.Vocab at 0x131729b50>,
#  'michigan': <gensim.models.keyedvectors.Vocab at 0x131729c90>,
#  'barely': <gensim.models.keyedvectors.Vocab at 0x131729bd0>,
#  'luck': <gensim.models.keyedvectors.Vocab at 0x131729d10>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x131729d50>,
#  'everybody': <gensim.models.keyedvectors.Vocab at 0x131729dd0>,
#  'rush': <gensim.models.keyedvectors.Vocab at 0x131729e50>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x131729f10>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x131729fd0>,
#  'moreover': <gensim.models.keyedvectors.Vocab at 0x131729ed0>,
#  ...}

# %%
X_train_pad.shape
# Out:
# (42889, 31, 60)

# %%
X_train_token= convert_sentences(X_train)

# %%
max([len(X_train_token[k]) for k in range(len(X_train_token))])
# Out:
# 232

# %% [markdown]
# ## Making sure X_train_pad & X_train_pad have the right size

# %%
for X in [X_train_pad, X_test_pad]:
    assert type(X) == np.ndarray
    assert X.shape[-1] == word2vec.wv.vector_size


assert X_train_pad.shape[0] == len(X_train)
assert X_test_pad.shape[0] == len(X_test)

# %% [markdown]
# # Create baseline accuracy

# %%
from sklearn.metrics import accuracy_score

unique, counts = np.unique(y_train, return_counts=True)
counts = dict(zip(unique, counts))
print('Number of labels in train set', counts)
# Out:
# Number of labels in train set {'anger': 11112, 'joy': 9890, 'neutral': 7145, 'sad': 6450, 'worry': 8292}

# %% [markdown]
# # Create NN

# %%
from tensorflow.keras import Sequential
from tensorflow.keras import layers

def init_model():
    model = Sequential()
    model.add(layers.Masking())
    
    model.add(layers.Conv1D(20, activation='relu'))
    model.add(layers.Dense(15, activation='relu'))
    model.add(layers.Dense(10, activation='relu'))
    model.add(layers.Dense(5, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy',
                  optimizer='rmsprop',
                  metrics=['accuracy'])
    
    return model

model = init_model()

# %%
sentiment_coding = {'anger': 0 , 'joy': 4, 'worry': 2, 'sad': 1 , 'neutral': 3}

# %%
y_train_coded= y_train.map(sentiment_coding)

# %%
y_train_coded.value_counts()
# Out:
# 0    11112
# 4     9890
# 2     8292
# 3     7145
# 1     6450
# Name: Emotion, dtype: int64

# %%
from tensorflow.keras.utils import to_categorical

# %%
y_train_cat = to_categorical(y_train_coded)

# %% [markdown]
# # Train model

# %%
from tensorflow.keras.callbacks import EarlyStopping
X_train_pad_short = X_train_pad[:201]
y_train_cat_short = y_train_cat[:201]
es = EarlyStopping(patience=2, restore_best_weights=True)

model.fit(X_train_pad_short, y_train_cat_short, 
          batch_size = 32,
          epochs=10,
          callbacks=[es],
          verbose=1
         )
# Out:
# Epoch 1/10
# 7/7 [==============================] - ETA: 0s - loss: 1.5971 - accuracy: 0.2537WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 7/7 [==============================] - 1s 213ms/step - loss: 1.5971 - accuracy: 0.2537
# Epoch 2/10
# 7/7 [==============================] - ETA: 0s - loss: 1.5927 - accuracy: 0.2537WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 7/7 [==============================] - 1s 131ms/step - loss: 1.5927 - accuracy: 0.2537
# Epoch 3/10
# 7/7 [==============================] - ETA: 0s - loss: 1.5872 - accuracy: 0.2587WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 7/7 [==============================] - 1s 138ms/step - loss: 1.5872 - accuracy: 0.2587
# Epoch 4/10
# 7/7 [==============================] - ETA: 0s - loss: 1.5818 - accuracy: 0.2637WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 7/7 [==============================] - 1s 144ms/step - loss: 1.5818 - accuracy: 0.2637
# Epoch 5/10
# 7/7 [==============================] - ETA: 0s - loss: 1.5747 - accuracy: 0.2736WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 7/7 [==============================] - 1s 137ms/step - loss: 1.5747 - accuracy: 0.2736
# Epoch 6/10
# 7/7 [==============================] - ETA: 0s - loss: 1.5670 - accuracy: 0.3035WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 7/7 [==============================] - 1s 154ms/step - loss: 1.5670 - accuracy: 0.3035
# Epoch 7/10
# 7/7 [==============================] - ETA: 0s - loss: 1.5556 - accuracy: 0.3284WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 7/7 [==============================] - 1s 172ms/step - loss: 1.5556 - accuracy: 0.3284
# Epoch 8/10
# 7/7 [==============================] - ETA: 0s - loss: 1.5458 - accuracy: 0.3483WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 7/7 [==============================] - 1s 166ms/step - loss: 1.5458 - accuracy: 0.3483
# Epoch 9/10
# 7/7 [==============================] - ETA: 0s - loss: 1.5360 - accuracy: 0.3532WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 7/7 [==============================] - 1s 201ms/step - loss: 1.5360 - accuracy: 0.3532
# Epoch 10/10
# 7/7 [==============================] - ETA: 0s - loss: 1.5216 - accuracy: 0.3781WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 7/7 [==============================] - 1s 169ms/step - loss: 1.5216 - accuracy: 0.3781

# %%
res = model.evaluate(X_test_pad, y_test, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-5b5e15aa1b46> in <module>
# ----> 1 res = model.evaluate(X_test_pad, y_test, verbose=0)
#
# ~/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1377             with trace.Trace('TraceContext', graph_type='test', step_num=step):
#    1378               callbacks.on_test_batch_begin(step)
# -> 1379               tmp_logs = test_function(iterator)
#    1380               if data_handler.should_sync:
#    1381                 context.async_wait()
#
# ~/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     812       # In this case we have not created variables on the first call. So we can
#     813       # run the first trace but we should fail if variables are created.
# --> 814       results = self._stateful_fn(*args, **kwds)
#     815       if self._created_variables:
#     816         raise ValueError("Creating variables on a non-first call to a function"
#
# ~/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2826     """Calls a graph function specialized to the inputs."""
#    2827     with self._lock:
# -> 2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
#    2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#
# ~/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3208           and self.input_signature is None
#    3209           and call_context_key in self._function_cache.missed):
# -> 3210         return self._define_function_with_shape_relaxation(args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
#
# ~/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _define_function_with_shape_relaxation(self, args, kwargs)
#    3140
#    3141     graph_function = self._create_graph_function(
# -> 3142         args, kwargs, override_flat_arg_shapes=relaxed_arg_shapes)
#    3143     self._function_cache.arg_relaxed[rank_only_cache_key] = graph_function
#    3144
#
# ~/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3073             arg_names=arg_names,
#    3074             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3075             capture_by_value=self._capture_by_value),
#    3076         self._function_attributes,
#    3077         function_spec=self.function_spec,
#
# ~/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     598         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     599         # the function a weak reference to itself to avoid a reference cycle.
# --> 600         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     601     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     602
#
# ~/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     971           except Exception as e:  # pylint:disable=broad-except
#     972             if hasattr(e, "ag_error_metadata"):
# --> 973               raise e.ag_error_metadata.to_exception(e)
#     974             else:
#     975               raise
#
# ValueError: in user code:
#
#     /Users/audehamdi/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1224 test_function  *
#         return step_function(self, iterator)
#     /Users/audehamdi/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1215 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /Users/audehamdi/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /Users/audehamdi/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /Users/audehamdi/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /Users/audehamdi/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1208 run_step  **
#         outputs = model.test_step(data)
#     /Users/audehamdi/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1177 test_step
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     /Users/audehamdi/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/keras/engine/compile_utils.py:204 __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     /Users/audehamdi/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:149 __call__
#         losses = ag_call(y_true, y_pred)
#     /Users/audehamdi/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:253 call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     /Users/audehamdi/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /Users/audehamdi/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:1535 categorical_crossentropy
#         return K.categorical_crossentropy(y_true, y_pred, from_logits=from_logits)
#     /Users/audehamdi/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /Users/audehamdi/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/keras/backend.py:4687 categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#     /Users/audehamdi/.pyenv/versions/3.7.7/envs/le-wagon-7/lib/python3.7/site-packages/tensorflow/python/framework/tensor_shape.py:1134 assert_is_compatible_with
#         raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#
#     ValueError: Shapes (None, 1) and (None, 5) are incompatible

# %%
res
