# %% [markdown]
# # Merge data

# %%
import pandas as pd

# %%
emo_df = pd.read_csv("../raw_data/text_emotion.csv")
es_df = pd.read_csv("../raw_data/emotion-stimulus.csv")
dd_df = pd.read_csv("../raw_data/dailydialog.csv")
t_df = pd.read_csv("../raw_data/isear.csv")

emo2_df = pd.read_csv("../raw_data/emo_df.csv")
dd2_df = pd.read_csv("../raw_data/dailydialog_emotion_name.csv")

# %%
dd_df.head() #replace 0-6 to emotion name neutral, joy, surprise, sadness, anger, disgust, fear
# Out:
#    Emotion                                               Text
# 0        0  Say , Jim , how about going for a few beers af...
# 1        0   You know that is tempting but is really not g...
# 2        0     What do you mean ? It will help us to relax .
# 3        0   Do you really think so ? I don't . It will ju...
# 4        0   I guess you are right.But what shall we do ? ...

# %%
emo_df.head() # extract sentiment and content, and rename them to Emotion and Text
# Out:
#      tweet_id   sentiment       author  \
# 0  1956967341       empty   xoshayzers
# 1  1956967666     sadness    wannamama
# 2  1956967696     sadness    coolfunky
# 3  1956967789  enthusiasm  czareaquino
# 4  1956968416     neutral    xkilljoyx
#
#                                              content
# 0  @tiffanylue i know  i was listenin to bad habi...
# 1  Layin n bed with a headache  ughhhh...waitin o...
# 2                Funeral ceremony...gloomy friday...
# 3               wants to hang out with friends SOON!
# 4  @dannycastillo We want to trade with someone w...

# %%
# merge all four dataframe virtually

# %% [markdown]
# # Prep for merging

# %%
dd_df.head()
# Out:
#    Emotion                                               Text
# 0        0  Say , Jim , how about going for a few beers af...
# 1        0   You know that is tempting but is really not g...
# 2        0     What do you mean ? It will help us to relax .
# 3        0   Do you really think so ? I don't . It will ju...
# 4        0   I guess you are right.But what shall we do ? ...

# %%
dd_df["Emotion"].value_counts()
# Out:
# 0    85572
# 4    12885
# 6     1823
# 5     1150
# 1     1022
# 2      353
# 3      174
# Name: Emotion, dtype: int64

# %%
#df['column name'] = df['column name'].replace(['old value'],'new value')
dd_df['Emotion'] = dd_df["Emotion"].replace([0],'neutral')
dd_df['Emotion'] = dd_df["Emotion"].replace([1],'joy')
dd_df['Emotion'] = dd_df["Emotion"].replace([2],'surprise')
dd_df['Emotion'] = dd_df["Emotion"].replace([3],'sadness')
dd_df['Emotion'] = dd_df["Emotion"].replace([4],'anger')
dd_df['Emotion'] = dd_df["Emotion"].replace([5],'disgust')
dd_df['Emotion'] = dd_df["Emotion"].replace([6],'fear')

# %%
dd_df["Emotion"].value_counts()
# Out:
# neutral     85572
# anger       12885
# fear         1823
# disgust      1150
# joy          1022
# surprise      353
# sadness       174
# Name: Emotion, dtype: int64

# %%
dd_df.to_csv(r"../raw_data/dailydialog_emotion_name.csv", index = False)

# %%
merged_df = pd.concat([emo2_df, es_df, dd2_df, t_df])

# %%
merged_df.to_csv(r"../raw_data/merged_emotion.csv", index = False)

# %%
merged_df.head()
# Out:
#       Emotion                                               Text
# 0       empty  @tiffanylue i know  i was listenin to bad habi...
# 1     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2     sadness                Funeral ceremony...gloomy friday...
# 3  enthusiasm               wants to hang out with friends SOON!
# 4     neutral  @dannycastillo We want to trade with someone w...

# %%
merged_df.shape
# Out:
# (152866, 2)

# %%
merged_df["Emotion"].unique()
# Out:
# array(['empty', 'sadness', 'enthusiasm', 'neutral', 'worry', 'surprise',
#        'love', 'fun', 'hate', 'happiness', 'boredom', 'relief', 'anger',
#        'happy', 'sad', 'disgust', 'fear', 'shame', 'joy', 'guilt'],
#       dtype=object)

# %%
len(merged_df["Emotion"].unique())
# Out:
# 20

# %%
merged_df["Emotion"].value_counts()
# Out:
# neutral       94210
# anger         14549
# worry          8459
# sadness        6406
# happiness      5209
# love           3842
# fear           3327
# surprise       2753
# disgust        2312
# joy            2103
# fun            1776
# relief         1526
# hate           1323
# shame          1200
# guilt          1052
# empty           827
# enthusiasm      759
# sad             575
# happy           479
# boredom         179
# Name: Emotion, dtype: int64

# %% [markdown]
# digust
# 2753 = Surprise - surprise
#
# 15,694 = Joy - happiness + happy + joy + enthusiasm + fun + love + releif
# whatever we want = netural
# 9,233 = Sad - sad + sadness + guilt + shame
# 11,786 = FearWorry - fear + worry
# 15,872 = DisgustAnger - anger + hate
#
#
# remove:
# empty, boredom, relief

# %%
# emo_n = merged_df.loc[merged_df['Emotion'] == "neutral"]
#emo_n.to_csv(r"../raw_data/neutral.csv", index = False)

# for sentence in emo_n['Text'][6:15]:
#     print(sentence)

#emo_n['Text'][:5]

# %%
merged_df["Emotion"].value_counts()
# Out:
# neutral    152866
# Name: Emotion, dtype: int64

# %% [markdown]
# # Reduce and merge Emotion column

# %%
#netural = neutral
joy = ["happiness", "happy", "joy", "enthusiasm", "fun", "love", "releif"]
sad = ["sad", "sadness", "guilt", "shame"]
worry = ["fear", "worry"]
anger = ["anger", "hate"]

# %%
for emotion in joy:
    merged_df['Emotion'] = merged_df["Emotion"].replace([emotion],'joy')
    
for emotion in sad:
    merged_df['Emotion'] = merged_df["Emotion"].replace([emotion],'sad')

for emotion in worry:
    merged_df['Emotion'] = merged_df["Emotion"].replace([emotion],'worry')

for emotion in anger:
    merged_df['Emotion'] = merged_df["Emotion"].replace([emotion],'anger')

# %%
merged_df["Emotion"].value_counts()
# Out:
# neutral     94210
# anger       15872
# joy         14168
# worry       11786
# sad          9233
# surprise     2753
# disgust      2312
# relief       1526
# empty         827
# boredom       179
# Name: Emotion, dtype: int64

# %%
merged_df.to_csv(r"../raw_data/merged_df2.csv", index = False)

# %% [markdown]
# # Drop emotions

# %%
merged_df.head()
# Out:
#    Emotion                                               Text
# 0    empty  @tiffanylue i know  i was listenin to bad habi...
# 1      sad  Layin n bed with a headache  ughhhh...waitin o...
# 2      sad                Funeral ceremony...gloomy friday...
# 3      joy               wants to hang out with friends SOON!
# 4  neutral  @dannycastillo We want to trade with someone w...

# %%
# reduce neutral
# drop surpise and below
merged_df2 = pd.read_csv('../raw_data/merged_df2.csv')
merged_df2.tail()
# Out:
#         Emotion                                               Text
# 152861    anger  Two years back someone invited me to be the tu...
# 152862      sad  I had taken the responsibility to do something...
# 152863  disgust  I was at home and I heard a loud sound of spit...
# 152864      sad  I did not do the homework that the teacher had...
# 152865      sad  I had shouted at my younger brother and he was...

# %%
# merged_df2['Emotion'].drop(['surprise', 'disgust', 'relief', 'empty', 'boredom'])
# dfObj.drop( dfObj[ dfObj['Age'] == 30 ].index , inplace=True)

merged_df2.drop(merged_df2[merged_df2['Emotion'] == 'boredom'].index, inplace=True)

# %%
drop_cols = ['surprise', 'disgust', 'relief', 'empty', 'boredom']

for col in drop_cols:
    merged_df2.drop(merged_df2[merged_df2['Emotion'] == col].index, inplace=True)

# %%
merged_df2["Emotion"].value_counts()
# Out:
# neutral    94210
# anger      15872
# joy        14168
# worry      11786
# sad         9233
# Name: Emotion, dtype: int64

# %%
neutral_df = merged_df2[merged_df2['Emotion']=='neutral'][:10212]

# %%
neutral_df.shape
# Out:
# (10212, 2)

# %%
merged_df2.drop(merged_df2[merged_df2['Emotion'] == 'neutral'].index, inplace=True)

# %%
emotions_df = pd.concat([merged_df2, neutral_df])

# %%
emotions_df['Emotion'].value_counts()
# Out:
# anger      15872
# joy        14168
# worry      11786
# neutral    10212
# sad         9233
# Name: Emotion, dtype: int64

# %% [markdown]
# # The codes

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\al\.venvs\lewagon\lib\site-packages (3.5)
# Requirement already satisfied: click in c:\users\al\.venvs\lewagon\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in c:\users\al\.venvs\lewagon\lib\site-packages (from nltk) (0.14.1)
# Requirement already satisfied: regex in c:\users\al\.venvs\lewagon\lib\site-packages (from nltk) (2020.10.28)
# Requirement already satisfied: tqdm in c:\users\al\.venvs\lewagon\lib\site-packages (from nltk) (4.50.2)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Al\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
# -*- coding: UTF-8 -*-
# Copyright (C) 2018 Jean Bizot <jean@styckr.io>
""" Main lib for london-emotions Project
"""
from os.path import split
import pandas as pd
import datetime

import string
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer

def clean_data(data):
    """
    clean and preprocess data
    """

    # Lowercase text
    data['clean_text'] = data['Text'].apply(
        lambda x: x.lower()
        )
    # Strip whitespace
    data['clean_text'] = data['clean_text'].apply(
        lambda x: x.strip()
        )
    # Remove numbers
    data['clean_text'] = data['clean_text'].apply(
        lambda x: ''.join(let for let in x if not let.isdigit())
        )
    # Remove punctuation
    data['clean_text'] = data['clean_text'].apply(
        lambda x: ''.join(let for let in x if not let in string.punctuation)
        )
    # Tokenization with nltk
    data['clean_text'] = data['clean_text'].apply(
        lambda x: word_tokenize(x)
    )
    # Remove stopwords
    # stop_words = set(stopwords.words('english'))
    # data['clean_text'] = data['clean_text'].apply(
    #     lambda x: [word for word in x if word not in stop_words]
    #     )
    # Lemmatizing with nltk
    lemmatizer = WordNetLemmatizer()
    data['clean_text'] = data['clean_text'].apply(
        lambda x: ' '.join(lemmatizer.lemmatize(word) for word in x)
        )

    # Return data
    return data

# %% [markdown]
# # NN baseline

# %%
from gensim.models import Word2Vec
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
emotion_df = pd.read_csv("../raw_data/emotion_data.csv")
emotion_df.head()
# Out:
#   Emotion                                               Text
# 0     sad  Layin n bed with a headache  ughhhh...waitin o...
# 1     sad                Funeral ceremony...gloomy friday...
# 2     joy               wants to hang out with friends SOON!
# 3   worry  Re-pinging @ghostridah14: why didn't you go to...
# 4     sad  I should be sleep, but im not! thinking about ...

# %%
cleaned_emo = clean_data(emotion_df)

# %%
cleaned_emo.head()
# Out:
#   Emotion                                               Text                                         clean_text
# 0     sad  Layin n bed with a headache  ughhhh...waitin o...  layin n bed with a headache ughhhhwaitin on yo...
# 1     sad                Funeral ceremony...gloomy friday...                      funeral ceremonygloomy friday
# 2     joy               wants to hang out with friends SOON!                  want to hang out with friend soon
# 3   worry  Re-pinging @ghostridah14: why didn't you go to...  repinging ghostridah why didnt you go to prom ...
# 4     sad  I should be sleep, but im not! thinking about ...  i should be sleep but im not thinking about an...

# %%
# df.drop(['A'], axis=1)
X = list(cleaned_emo['clean_text'])
y = cleaned_emo['Emotion']

# split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train[0]
# Out:
# 'can i help you'

# %%
X_train.head()
# Out:
# 59821                                       can i help you
# 40614                           i cant help shopping there
# 25243    taylamccloud yeah i did haha rd episode is up ...
# 30108                                   my feeling exactly
# 6649                 hangin with the fam my head is hurtin
# Name: clean_text, dtype: object

# %%
len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (41051, 20220, 41051, 20220)

# %% [markdown]
# ## embed the data

# %%
X_train_token = [word_tokenize(_) for _ in X_train]
X_test_token = [word_tokenize(_) for _ in X_test]

# %%
X_train_token
# Out:
# [['can', 'i', 'help', 'you'],
#  ['i', 'cant', 'help', 'shopping', 'there'],
#  ['taylamccloud',
#   'yeah',
#   'i',
#   'did',
#   'haha',
#   'rd',
#   'episode',
#   'is',
#   'up',
#   'a',
#   'well'],
#  ['my', 'feeling', 'exactly'],
#  ['hangin', 'with', 'the', 'fam', 'my', 'head', 'is', 'hurtin'],
#  ['tommcfly',
#   'and',
#   'may',
#   'the',
#   'th',
#   'be',
#   'with',
#   'you',
#   'too',
#   'amused',
#   'loved',
#   'it'],
#  ['anix',
#   'i',
#   'bought',
#   'cheesecake',
#   'ice',
#   'cream',
#   'last',
#   'week',
#   'thinking',
#   'it',
#   'wa',
#   'good',
#   'and',
#   'it',
#   'sucked',
#   'so',
#   'much',
#   'im',
#   'taking',
#   'yours'],
#  ['dreamsthedream',
#   'dreamsthedream',
#   'dreamsthedream',
#   'i',
#   'came',
#   'back',
#   'to',
#   'germany',
#   'yesterday',
#   'my',
#   'five',
#   'day',
#   'in',
#   'the',
#   'uk',
#   'were',
#   'over'],
#  ['i', 'fucking', 'love', 'alexander', 'william', 'gaskarth'],
#  ['just',
#   'made',
#   'diy',
#   'acid',
#   'wash',
#   'short',
#   'cant',
#   'wait',
#   'to',
#   'see',
#   'what',
#   'they',
#   'look',
#   'like'],
#  ['i',
#   'wa',
#   'filled',
#   'with',
#   'joy',
#   'when',
#   'i',
#   'heard',
#   'that',
#   'i',
#   'had',
#   'been',
#   'selected',
#   'to',
#   'come',
#   'here',
#   'at',
#   'kamuzu',
#   'college',
#   'of',
#   'nursing'],
#  ['booo',
#   'my',
#   'best',
#   'friend',
#   'is',
#   'leavin',
#   'for',
#   'the',
#   'weekend',
#   'what',
#   'ever',
#   'will',
#   'i',
#   'do',
#   'without',
#   'her'],
#  ['i',
#   'made',
#   'an',
#   'appointment',
#   'with',
#   'a',
#   'friend',
#   'to',
#   'drink',
#   'coffee',
#   'togehter',
#   'however',
#   'for',
#   'the',
#   'third',
#   'time',
#   'in',
#   'that',
#   'week',
#   'she',
#   'arrived',
#   'an',
#   'hour',
#   'too',
#   'late'],
#  ['the',
#   'mother',
#   'of',
#   'a',
#   'friend',
#   'of',
#   'mine',
#   'passed',
#   'by',
#   'me',
#   'and',
#   'saw',
#   'me',
#   'sitting',
#   'on',
#   'a',
#   'boy',
#   'lap',
#   'i',
#   'tried',
#   'to',
#   'greet',
#   'her',
#   'but',
#   'could',
#   'not',
#   'help',
#   'blushing'],
#  ['i',
#   'turned',
#   'the',
#   'knob',
#   'of',
#   'my',
#   'granny',
#   'two',
#   'band',
#   'radio',
#   'and',
#   'did',
#   'not',
#   'hear',
#   'any',
#   'broadcast',
#   'what',
#   'have',
#   'i',
#   'broken',
#   'the',
#   'knob',
#   'how',
#   'much',
#   'doe',
#   'it',
#   'cost',
#   'what',
#   'if',
#   'the',
#   'spare',
#   'part',
#   'is',
#   'not',
#   'available',
#   'i',
#   'did',
#   'not',
#   'know',
#   'how',
#   'to',
#   'tune',
#   'a',
#   'radio'],
#  ['vestaeresta',
#   'geez',
#   'a',
#   'cool',
#   'man',
#   'like',
#   'him',
#   'be',
#   'the',
#   'villain',
#   'too',
#   'bad'],
#  ['i',
#   'wa',
#   'at',
#   'home',
#   'alone',
#   'when',
#   'i',
#   'realized',
#   'that',
#   'a',
#   'young',
#   'roe',
#   'approached',
#   'our',
#   'house',
#   'i',
#   'hid',
#   'because',
#   'i',
#   'did',
#   'not',
#   'want',
#   'to',
#   'frighten',
#   'it',
#   'it',
#   'limped',
#   'some',
#   'time',
#   'later',
#   'when',
#   'i',
#   'thought',
#   'that',
#   'it',
#   'had',
#   'already',
#   'run',
#   'away',
#   'i',
#   'saw',
#   'it',
#   'lying',
#   'on',
#   'our',
#   'terrace',
#   'i',
#   'came',
#   'nearer',
#   'and',
#   'saw',
#   'that',
#   'it',
#   'wa',
#   'terribly',
#   'wounded',
#   'i',
#   'informed',
#   'the',
#   'ranger',
#   'who',
#   'said',
#   'that',
#   'the',
#   'roe',
#   'must',
#   'have',
#   'been',
#   'attacked',
#   'by',
#   'dog',
#   'he',
#   'had',
#   'to',
#   'shoot',
#   'it'],
#  ['just',
#   'an',
#   'animal',
#   'but',
#   'it',
#   'ha',
#   'life',
#   'too',
#   'if',
#   'you',
#   'want',
#   'a',
#   'tattoo',
#   'get',
#   'one',
#   'it',
#   'your',
#   'choice',
#   'because',
#   'you',
#   'want',
#   'it',
#   'but',
#   'ha',
#   'anyone',
#   'asked',
#   'the',
#   'fish',
#   'if',
#   'it',
#   'wanted',
#   'one'],
#  ['lexy',
#   'add',
#   'me',
#   'here',
#   'i',
#   'cant',
#   'locate',
#   'your',
#   'handle',
#   'for',
#   'whatever',
#   'reason'],
#  ['valerie',
#   'quite',
#   'a',
#   'few',
#   'peacock',
#   'and',
#   'oceanographer',
#   'choice',
#   'are',
#   'my',
#   'new',
#   'favorite',
#   'to',
#   'play'],
#  ['guess', 'not', 'today'],
#  ['got', 'a', 'new', 'lyric', 'book'],
#  ['no', 'i', 'just', 'read', 'the', 'name', 'off', 'the', 'package', 'ha'],
#  ['ashleytisdale',
#   'httptwitpiccomaho',
#   'hahaha',
#   'ily',
#   'ashley',
#   'ur',
#   'like',
#   'the',
#   'best',
#   'in',
#   'the',
#   'world'],
#  ['im', 'the', 'dentist', 'scary', 'people', 'here'],
#  ['when',
#   'i',
#   'got',
#   'myself',
#   'the',
#   'kind',
#   'of',
#   'girlfriend',
#   'i',
#   'had',
#   'been',
#   'hunting',
#   'for',
#   'a',
#   'long',
#   'time'],
#  ['my',
#   'girlfriend',
#   'and',
#   'i',
#   'slept',
#   'in',
#   'a',
#   'lonely',
#   'hut',
#   'we',
#   'had',
#   'drunk',
#   'alcool',
#   'suddenly',
#   'some',
#   'soil',
#   'fell',
#   'on',
#   'u',
#   'then',
#   'some',
#   'water',
#   'although',
#   'we',
#   'tried',
#   'hard',
#   'we',
#   'could',
#   'not',
#   'find',
#   'out',
#   'the',
#   'cause'],
#  ['i',
#   'wa',
#   'with',
#   'a',
#   'group',
#   'of',
#   'people',
#   'and',
#   'everybody',
#   'told',
#   'me',
#   'to',
#   'do',
#   'or',
#   'say',
#   'something',
#   'it',
#   'wa',
#   'a',
#   'confusing',
#   'strong',
#   'and',
#   'traumatic',
#   'situation',
#   'for',
#   'me'],
#  ['had', 'a', 'greatttttt', 'day', 'taking', 'liz', 'home', 'now', 'lt'],
#  ['andrewbravener',
#   'happy',
#   'birthday',
#   'whats',
#   'better',
#   'than',
#   'getting',
#   'birthday',
#   'greeting',
#   'from',
#   'stranger',
#   'very',
#   'little',
#   'thats',
#   'what',
#   'i',
#   'kid',
#   'lt'],
#  ['yes',
#   'im',
#   'in',
#   'the',
#   'last',
#   'chapter',
#   'now',
#   'and',
#   'it',
#   'is',
#   'just',
#   'gripping'],
#  ['andyroddick',
#   'at',
#   'work',
#   'at',
#   'the',
#   'mo',
#   'and',
#   'it',
#   'so',
#   'sunny',
#   'here',
#   'today',
#   'off',
#   'to',
#   'see',
#   'a',
#   'band',
#   'tonight'],
#  ['old',
#   'enough',
#   'to',
#   'know',
#   'better',
#   'young',
#   'enough',
#   'to',
#   'not',
#   'care'],
#  ['i', 'never', 'get', 'any', 'followfridays'],
#  ['sure',
#   'that',
#   'sound',
#   'great',
#   'where',
#   'are',
#   'your',
#   'appetizer',
#   'listed'],
#  ['you',
#   'should',
#   'be',
#   'you',
#   'worked',
#   'really',
#   'hard',
#   'last',
#   'night',
#   'preparing',
#   'for',
#   'it'],
#  ['some',
#   'colleague',
#   'decided',
#   'to',
#   'go',
#   'out',
#   'on',
#   'a',
#   'saturday',
#   'not',
#   'inviting',
#   'me',
#   'to',
#   'decide',
#   'either',
#   'the',
#   'place',
#   'nor',
#   'the',
#   'time'],
#  ['broooooke',
#   'omg',
#   'and',
#   'you',
#   'never',
#   'would',
#   'believe',
#   'what',
#   'we',
#   'did',
#   'ahaha',
#   'i',
#   'loved',
#   'it',
#   'but',
#   'it',
#   'felt',
#   'like',
#   'a',
#   'movie',
#   'but',
#   'real'],
#  ['thenetimp',
#   'yeah',
#   'it',
#   'gon',
#   'na',
#   'be',
#   'a',
#   'long',
#   'while',
#   'for',
#   'me'],
#  ['going',
#   'to',
#   'look',
#   'at',
#   'a',
#   'bunch',
#   'of',
#   'open',
#   'home',
#   'today',
#   'just',
#   'to',
#   'get',
#   'a',
#   'feel',
#   'for',
#   'the',
#   'market',
#   'i',
#   'think',
#   'ive',
#   'got',
#   'a',
#   'lot',
#   'of',
#   'saving',
#   'to',
#   'do'],
#  ['then',
#   'we',
#   'can',
#   'take',
#   'a',
#   'walk',
#   'and',
#   'enjoy',
#   'the',
#   'scenery',
#   'in',
#   'the',
#   'park'],
#  ['thank', 'you', 'for', 'your', 'hospitality'],
#  ['nearby',
#   'on',
#   'the',
#   'bank',
#   'of',
#   'the',
#   'thames',
#   'there',
#   '’',
#   's',
#   'the',
#   'statue',
#   'of',
#   'boadicea',
#   'she',
#   'fought',
#   'the',
#   'roman',
#   'when',
#   'they',
#   'invaded',
#   'britain'],
#  ['i',
#   'look',
#   'forward',
#   'to',
#   'having',
#   'dinner',
#   'at',
#   'your',
#   'restaurant',
#   'thank',
#   'you',
#   'for',
#   'your',
#   'help'],
#  ['you', 'know', 'you', 'didnt'],
#  ['i',
#   'hadnt',
#   'been',
#   'at',
#   'my',
#   'parent',
#   'place',
#   'for',
#   'a',
#   'long',
#   'time',
#   'when',
#   'i',
#   'went',
#   'to',
#   'visit',
#   'them',
#   'i',
#   'had',
#   'high',
#   'expectation',
#   'but',
#   'when',
#   'i',
#   'wa',
#   'there',
#   'it',
#   'wa',
#   'very',
#   'different',
#   'from',
#   'what',
#   'i',
#   'expected'],
#  ['sicky', 'sicky', 'suck', 'on', 'such', 'a', 'lovely', 'day'],
#  ['currently',
#   'working',
#   'on',
#   'the',
#   'sdps',
#   'prototype',
#   'so',
#   'much',
#   'to',
#   'do'],
#  ['the',
#   'treelined',
#   'avenuebegins',
#   'to',
#   'fade',
#   'from',
#   'viewdrowning',
#   'past',
#   'regret',
#   'in',
#   'tea',
#   'and',
#   'cigarettesbut',
#   'i',
#   'cant',
#   'seem',
#   'to',
#   'forgetwhen',
#   'you',
#   'came',
#   'along'],
#  ['waiting',
#   'for',
#   'someone',
#   'sm',
#   'it',
#   'been',
#   'week',
#   'and',
#   'nearly',
#   'a',
#   'month'],
#  ['i', 'love', 'winter', 'i', 'love', 'snow'],
#  ['telling',
#   'friend',
#   'about',
#   'how',
#   'my',
#   'parent',
#   'had',
#   'been',
#   'treating',
#   'my',
#   'brother',
#   'and',
#   'sister',
#   'unfairly'],
#  ['fajarjasmin',
#   'im',
#   'a',
#   'huge',
#   'fan',
#   'of',
#   'take',
#   'that',
#   'since',
#   'i',
#   'wa',
#   'a',
#   'baby',
#   'yeah',
#   'month',
#   'really',
#   'feel',
#   'like',
#   'month'],
#  ['the',
#   'final',
#   'report',
#   'is',
#   'exceptionally',
#   'thorough',
#   'and',
#   'well',
#   'done',
#   'i',
#   'think',
#   'that',
#   'you',
#   'have',
#   'been',
#   'come',
#   'up',
#   'with',
#   'some',
#   'interesting',
#   'recommendation',
#   'for',
#   'the',
#   'client'],
#  ['glassdahl',
#   'im',
#   'more',
#   'than',
#   'willing',
#   'to',
#   'give',
#   'him',
#   'what',
#   'he',
#   'need',
#   'xd',
#   'but',
#   'srsly',
#   'i',
#   'also',
#   'think',
#   'he',
#   'need',
#   'one',
#   'soon'],
#  ['battleacure', 'hey', 'good', 'am', 'to', 'you', 'too'],
#  ['you',
#   'wont',
#   'play',
#   'online',
#   'game',
#   'full',
#   'of',
#   'violence',
#   'will',
#   'you'],
#  ['what',
#   'is',
#   'that',
#   'it',
#   'look',
#   'like',
#   'something',
#   'from',
#   'a',
#   'swamp'],
#  ['darealsunisakim',
#   'there',
#   'ding',
#   'tai',
#   'fung',
#   'here',
#   'in',
#   'sydney',
#   'aswell',
#   'making',
#   'me',
#   'want',
#   'dumpling'],
#  ['my',
#   'pen',
#   'just',
#   'blew',
#   'up',
#   'in',
#   'my',
#   'hand',
#   'there',
#   'ink',
#   'everywhere',
#   'i',
#   'am',
#   'now',
#   'a',
#   'walking',
#   'rorschach',
#   'test'],
#  ['ashleeadams', 'i', 'dont', 'know', 'what', 'to', 'say', 'except', 'hug'],
#  ['really', 'why'],
#  ['wow',
#   'it',
#   '’',
#   's',
#   'really',
#   'good',
#   'for',
#   'me',
#   'especially',
#   'the',
#   'living',
#   'room',
#   'it',
#   'is',
#   'big',
#   'enough',
#   'to',
#   'put',
#   'all',
#   'my',
#   'stuff',
#   'there',
#   'it',
#   '’',
#   's',
#   'a',
#   'deal',
#   'i',
#   '’',
#   'll',
#   'rent',
#   'this',
#   'one'],
#  ['shashitharoor',
#   'i',
#   'hope',
#   'such',
#   'moment',
#   'inspire',
#   'you',
#   'on',
#   'your',
#   'political',
#   'journey',
#   'back',
#   'home',
#   'all',
#   'the',
#   'best'],
#  ['amoonchilde',
#   'thank',
#   'you',
#   'tomorrow',
#   'is',
#   'my',
#   'bday',
#   'too',
#   'i',
#   'tease',
#   'my',
#   'mom',
#   'and',
#   'tell',
#   'her',
#   'i',
#   'wa',
#   'her',
#   'mother',
#   'day',
#   'gift'],
#  ['haha',
#   'i',
#   'bet',
#   'a',
#   'man',
#   'did',
#   'make',
#   'heel',
#   'im',
#   'sorry',
#   'you',
#   'hurt',
#   'though',
#   'i',
#   'hope',
#   'you',
#   'feel',
#   'better',
#   'livelovesing'],
#  ['a', 'party', 'i', 'went', 'to', 'last', 'christmas'],
#  ['dont', 'forget', 'to', 'call', 'your', 'mom', 'tomorrow'],
#  ['zefrank', 'have', 'a', 'lovely', 'weekend'],
#  ['is',
#   'off',
#   'to',
#   'work',
#   'still',
#   'quotrecoveringquot',
#   'from',
#   'an',
#   'amazing',
#   'and',
#   'beautiful',
#   'weekend',
#   'have',
#   'i',
#   'mentioned',
#   'how',
#   'incredible',
#   'my',
#   'friend',
#   'are'],
#  ['i',
#   'have',
#   'no',
#   'reason',
#   'to',
#   'distrust',
#   'him',
#   'he',
#   'never',
#   'caused',
#   'any',
#   'harm'],
#  ['oh', 'thank', 'youyou', 'are', 'so', 'sweet'],
#  ['an',
#   'extra',
#   'night',
#   'in',
#   'pasadena',
#   'with',
#   'sergi',
#   'baby',
#   'cuz',
#   'i',
#   'missed',
#   'my',
#   'train',
#   'to',
#   'riverside'],
#  ['thank',
#   'you',
#   'ive',
#   'got',
#   'just',
#   'minute',
#   'to',
#   'go',
#   'can',
#   'we',
#   'manage'],
#  ['thinking',
#   'about',
#   'con',
#   'law',
#   'fighting',
#   'a',
#   'headache',
#   'amp',
#   'paying',
#   'bill'],
#  ['to',
#   'neenz',
#   'i',
#   'wa',
#   'going',
#   'to',
#   'reply',
#   'to',
#   'your',
#   'quotwhat',
#   'do',
#   'ppl',
#   'in',
#   'hi',
#   'do',
#   'on',
#   'the',
#   'weekendquot',
#   'postand',
#   'then',
#   'i',
#   'realized',
#   'my',
#   'top',
#   'choice',
#   'wa',
#   'work'],
#  ['death', 'in', 'the', 'close', 'family'],
#  ['dimple',
#   'wa',
#   'in',
#   'the',
#   'preview',
#   'are',
#   'they',
#   'not',
#   'on',
#   'today',
#   'it',
#   'hasnt',
#   'aired',
#   'here',
#   'yet',
#   'via',
#   'httptwibescpf'],
#  ['your', 'dream', 'will', 'come', 'true', 'it', 'really', 'breathtaking'],
#  ['thatd', 'be', 'nice'],
#  ['sure', 'let', 'go', 'to', 'malibu'],
#  ['i',
#   'wa',
#   'going',
#   'to',
#   'go',
#   'on',
#   'a',
#   'vacation',
#   'to',
#   'texas',
#   'this',
#   'summer',
#   'but',
#   'wa',
#   'unable',
#   'to',
#   'go',
#   'because',
#   'of',
#   'registration'],
#  ['i',
#   'am',
#   'troubled',
#   'by',
#   'hair',
#   'growing',
#   'in',
#   'my',
#   'neck',
#   'i',
#   'wa',
#   'troubled',
#   'by',
#   'this',
#   'for',
#   'a',
#   'long',
#   'time',
#   'and',
#   'wa',
#   'much',
#   'ashamed',
#   'when',
#   'someone',
#   'brought',
#   'hisher',
#   'hand',
#   'close',
#   'to',
#   'my',
#   'face'],
#  ['listening', 'to', 'miley', 'cyrus', 'breakout', 'cd', 'love', 'it'],
#  ['tino', 'hat', 'ne', 'wii'],
#  ['mary', 'this', 'is', 'mr', 'wu', 'my', 'new', 'chinese', 'friend'],
#  ['when',
#   'someone',
#   'doe',
#   'not',
#   'listen',
#   'to',
#   'me',
#   'after',
#   'having',
#   'asked',
#   'me',
#   'to',
#   'repeat',
#   'what',
#   'i',
#   'said',
#   'this',
#   'happened',
#   'more',
#   'than',
#   'one',
#   'time',
#   'with',
#   'the',
#   'same',
#   'person'],
#  ['i',
#   '’',
#   'll',
#   'till',
#   'the',
#   'soil',
#   'and',
#   'then',
#   'sow',
#   'the',
#   'seed',
#   'i',
#   '’',
#   'll',
#   'then',
#   'add',
#   'some',
#   'fertilizer',
#   'and',
#   'voila',
#   'gardening',
#   'all',
#   'done'],
#  ['pmed',
#   'awesome',
#   'good',
#   'luck',
#   'with',
#   'the',
#   'kegging',
#   'i',
#   'need',
#   'to',
#   'get',
#   'into',
#   'that',
#   'instead',
#   'of',
#   'bottling'],
#  ['tofuatomic', 'my', 'bos', 'shes', 'moving', 'to', 'nyc'],
#  ['youre', 'lucky'],
#  ['it',
#   'so',
#   'windy',
#   'and',
#   'raining',
#   'harder',
#   'then',
#   'the',
#   'day',
#   'before',
#   'today',
#   'bye',
#   'bye',
#   'if',
#   'the',
#   'power',
#   'go',
#   'out'],
#  ['tedmurphy',
#   'thanks',
#   'for',
#   'the',
#   'follow',
#   'im',
#   'loving',
#   'the',
#   'energy',
#   'on',
#   'your',
#   'site',
#   'the',
#   'spaz',
#   'in',
#   'me',
#   'cant',
#   'help',
#   'but',
#   'be',
#   'drawn',
#   'to',
#   'you',
#   'httpwwwtedme'],
#  ['you',
#   'can',
#   'say',
#   'that',
#   'again',
#   'it',
#   'much',
#   'more',
#   'modern',
#   'than',
#   'people',
#   'imagine',
#   'where',
#   'are',
#   'you',
#   'from'],
#  ['smackdown', 'is', 'a', 'lot', 'more', 'boring', 'without', 'maria'],
#  ['when', 'i', 'wa', 'admitted', 'to', 'the', 'university'],
#  ['ha',
#   'j',
#   'perfect',
#   'timing',
#   'on',
#   'that',
#   'message',
#   'the',
#   'cure',
#   'just',
#   'came',
#   'on'],
#  ['yumifujii',
#   'ill',
#   'miss',
#   'yall',
#   'back',
#   'give',
#   'lesleyboudy',
#   'my',
#   'regard'],
#  ['i', 'wish', 'it', 'would', 'stay', 'this', 'way', 'for', 'the', 'weekend'],
#  ['no',
#   'im',
#   'a',
#   'tourist',
#   'this',
#   'place',
#   'is',
#   'amazing',
#   'it',
#   'much',
#   'bigger',
#   'than',
#   'i',
#   'imagined',
#   'and',
#   'much',
#   'more',
#   'exciting',
#   'there',
#   'so',
#   'much',
#   'to',
#   'see',
#   'here'],
#  ['what',
#   'you',
#   'call',
#   'that',
#   'a',
#   'stir',
#   'fry',
#   'more',
#   'meat',
#   'than',
#   'vegetable',
#   'that',
#   '’',
#   's',
#   'the',
#   'worst',
#   'insult',
#   'you',
#   'could',
#   'throw',
#   'at',
#   'a',
#   'chinese',
#   'stir',
#   'fry',
#   'what',
#   'a',
#   'disgrace',
#   'to',
#   'the',
#   'wok',
#   'she',
#   'fried',
#   'it',
#   'in',
#   'what',
#   'you',
#   'had',
#   'is',
#   'equivalent',
#   'to',
#   'a',
#   'fajita',
#   'without',
#   'the',
#   'wrap'],
#  ['wish',
#   'zak',
#   'wuld',
#   'trust',
#   'me',
#   'enough',
#   'to',
#   'give',
#   'me',
#   'bac',
#   'my',
#   'necklace',
#   'i',
#   'want',
#   'it',
#   'back',
#   'but',
#   'he',
#   'think',
#   'ill',
#   'cut',
#   'with',
#   'it',
#   'httpplurkcompxqkb'],
#  ['leirastorm', 'thats', 'sucky', 'well', 'miss', 'you', 'being', 'on'],
#  ['swearing', 'in', 'public'],
#  ['phyllig', 'mtv', 'movie', 'award', 'go', 'vote', 'stat'],
#  ['rain',
#   'rain',
#   'rain',
#   'go',
#   'away',
#   'come',
#   'back',
#   'next',
#   'week',
#   'when',
#   'im',
#   'gone',
#   'via',
#   'gigglingmarlin',
#   'raining',
#   'lie',
#   'crazy',
#   'in',
#   'the',
#   'key'],
#  ['nice', 'win', 'by', 'the', 'dodger', 'over', 'giant'],
#  ['no', 'no', 'stupid', 'machine', 'what', 'are', 'you', 'doing', 'no'],
#  ['just',
#   'got',
#   'notified',
#   'my',
#   'podcast',
#   'wa',
#   'accepted',
#   'into',
#   'itunes',
#   'httpbudurlcomsbit',
#   'of',
#   'course',
#   'i',
#   'then',
#   'realized',
#   'it',
#   'wa',
#   'miss',
#   'formated',
#   'fixed',
#   'now'],
#  ['yazziness'],
#  ['julia',
#   's',
#   'question',
#   'about',
#   'the',
#   'line',
#   'the',
#   'defence',
#   'lawyer',
#   'were',
#   'taking',
#   'were',
#   'a',
#   'acute',
#   'a',
#   'anything',
#   'she',
#   'had',
#   'ever',
#   'asked',
#   'david',
#   'and',
#   'they',
#   'filled',
#   'him',
#   'with',
#   'relieved',
#   'delight'],
#  ['so',
#   'sleepy',
#   'again',
#   'and',
#   'it',
#   'not',
#   'even',
#   'that',
#   'late',
#   'i',
#   'fail',
#   'once',
#   'again'],
#  ['just', 'sittin', 'here', 'listenin', 'to', 'music', 'follow', 'me'],
#  ['i',
#   'like',
#   'spring',
#   'toowe',
#   'can',
#   'go',
#   'for',
#   'a',
#   'walk',
#   'and',
#   'enjoy',
#   'the',
#   'fresh',
#   'air'],
#  ['yes',
#   'ive',
#   'dreamed',
#   'a',
#   'thousand',
#   'time',
#   'that',
#   'i',
#   'could',
#   'lie',
#   'down',
#   'here',
#   'to',
#   'relax'],
#  ['have',
#   'somebody',
#   'installed',
#   'vcenter',
#   'server',
#   'on',
#   'window',
#   'x',
#   'w',
#   'sp',
#   'sp',
#   'is',
#   'not',
#   'in',
#   'the',
#   'compability',
#   'matrix'],
#  ['phomor',
#   'you',
#   'cant',
#   'put',
#   'off',
#   'age',
#   'but',
#   'you',
#   'can',
#   'put',
#   'off',
#   'grumpiness'],
#  ['had', 'fun', 'at', 'wango', 'tangooo'],
#  ['jdpeterson',
#   'i',
#   'say',
#   'the',
#   'same',
#   'about',
#   'poem',
#   'when',
#   'you',
#   'are',
#   'ready',
#   'to',
#   'write',
#   'quotnothing',
#   'else',
#   'mattersquot',
#   'a',
#   'a',
#   'well',
#   'known',
#   'song',
#   'tell',
#   'u'],
#  ['when',
#   'i',
#   'noticed',
#   'obvious',
#   'mark',
#   'of',
#   'old',
#   'age',
#   'in',
#   'a',
#   'negative',
#   'sense',
#   'on',
#   'a',
#   'close',
#   'relative',
#   'of',
#   'mine'],
#  ['i',
#   'heard',
#   'an',
#   'icecream',
#   'truck',
#   'and',
#   'took',
#   'of',
#   'like',
#   'a',
#   'shot',
#   'but',
#   'i',
#   'couldnt',
#   'catch',
#   'it'],
#  ['going', 'to', 'cal', 'not', 'knowing', 'anyone'],
#  ['eileenright',
#   'should',
#   'work',
#   'fine',
#   'a',
#   'far',
#   'a',
#   'i',
#   'know',
#   'shrug',
#   'maybe',
#   'send',
#   'a',
#   'tweet',
#   'to',
#   'verizon'],
#  ['my',
#   'mother',
#   'wa',
#   'only',
#   'a',
#   'sad',
#   'woman',
#   'in',
#   'an',
#   'old',
#   'photograph',
#   'younger',
#   'then',
#   'than',
#   'i',
#   'wa',
#   'now'],
#  ['lasttt', 'mondayyy', 'of', 'class'],
#  ['but',
#   'kirkwood',
#   'who',
#   'wa',
#   'a',
#   'particularly',
#   'dejected',
#   'figure',
#   'after',
#   'monday',
#   's',
#   'decisive',
#   'defeat',
#   'by',
#   'canada',
#   'injected',
#   'some',
#   'pride',
#   'back',
#   'into',
#   'irish',
#   'rank',
#   'in',
#   'the',
#   'dying',
#   'second',
#   'when',
#   'he',
#   'flicked',
#   'home',
#   'the',
#   'winner'],
#  ['is',
#   'hurt',
#   'and',
#   'upset',
#   'and',
#   'trying',
#   'to',
#   'smile',
#   'when',
#   'i',
#   'feel',
#   'broken',
#   'inside'],
#  ['hate',
#   'being',
#   'sick',
#   'especially',
#   'when',
#   'there',
#   'no',
#   'one',
#   'to',
#   'pamper',
#   'me'],
#  ['i', 'will', 'do', 'my', 'best'],
#  ['watching', 'john', 'edward', 'cross', 'country'],
#  ['my',
#   'best',
#   'frieend',
#   'left',
#   'school',
#   'recently',
#   'the',
#   'next',
#   'day',
#   'the',
#   'weather',
#   'turned',
#   'bad',
#   'suddenly',
#   'and',
#   'the',
#   'male',
#   'classmate',
#   'turned',
#   'off',
#   'the',
#   'light',
#   'i',
#   'remained',
#   'on',
#   'the',
#   'table',
#   'and',
#   'wa',
#   'scared'],
#  ['cetras', 'lol', 'anyway', 'ni', 'shi', 'wai', 'guo', 'ren'],
#  ['ladybug',
#   'oh',
#   'yes',
#   'i',
#   'sure',
#   'will',
#   'but',
#   'sad',
#   'cause',
#   'i',
#   'will',
#   'miss',
#   'the',
#   'view',
#   'at',
#   'the',
#   'house',
#   'am',
#   'leaving',
#   'actually'],
#  ['new',
#   'pollster',
#   'data',
#   'on',
#   'party',
#   'identification',
#   'in',
#   'the',
#   'united',
#   'state',
#   'democratic',
#   'independent',
#   'republican',
#   'ouch'],
#  ['once',
#   'in',
#   'my',
#   'home',
#   'yard',
#   'i',
#   'wa',
#   'plaing',
#   'football',
#   'with',
#   'my',
#   'cousin',
#   'and',
#   'in',
#   'a',
#   'certain',
#   'quick',
#   'the',
#   'ball',
#   'went',
#   'on',
#   'uncontrolled',
#   'putting',
#   'down',
#   'a',
#   'birdcage',
#   'killing',
#   'it'],
#  ['he', 'sound', 'hot', 'what', 'doe', 'he', 'do', 'for', 'a', 'living'],
#  ['you', 'were', 'dull', 'at', 'that', 'time'],
#  ['yay',
#   'boxing',
#   'although',
#   'after',
#   'the',
#   'boxing',
#   'sparring',
#   'amp',
#   'eating',
#   'have',
#   'to',
#   'spend',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'evening',
#   'troubleshooting',
#   'java',
#   'code',
#   'for',
#   'hw'],
#  ['jim',
#   'could',
#   'nonetheless',
#   'tell',
#   'by',
#   'his',
#   'anxious',
#   'face',
#   'that',
#   'something',
#   'wa',
#   'wrong'],
#  ['thank', 'you', 'david'],
#  ['diehard',
#   'fan',
#   'might',
#   'be',
#   'miffed',
#   'at',
#   'some',
#   'of',
#   'what',
#   's',
#   'left',
#   'out',
#   'but',
#   'it',
#   's',
#   'tough',
#   'to',
#   'argue',
#   'against',
#   'any',
#   'of',
#   'the',
#   'song',
#   'included'],
#  ['when',
#   'my',
#   'grandmother',
#   'who',
#   'ha',
#   'been',
#   'living',
#   'with',
#   'u',
#   'for',
#   'year',
#   'had',
#   'a',
#   'stroke',
#   'and',
#   'wa',
#   'left',
#   'paralysed',
#   'on',
#   'one',
#   'side',
#   'she',
#   'ha',
#   'been',
#   'quite',
#   'close',
#   'to',
#   'our',
#   'family',
#   'and',
#   'to',
#   'see',
#   'her',
#   'suffer',
#   'in',
#   'this',
#   'way',
#   'make',
#   'me',
#   'feel',
#   'really',
#   'sad'],
#  ['peterpaega',
#   'you',
#   'better',
#   'believe',
#   'it',
#   'tigerschamps',
#   'and',
#   'i',
#   'wouldnt',
#   'miss',
#   'it',
#   'for',
#   'the',
#   'world'],
#  ['good', 'may', 'i', 'have', 'your', 'name', 'please'],
#  ['hpfreak',
#   'awww',
#   'it',
#   'doe',
#   'remind',
#   'me',
#   'of',
#   'getting',
#   'ready',
#   'for',
#   'the',
#   'ball'],
#  ['brgd', 'oh', 'cool', 'you', 'are', 'coming', 'to', 'berlin'],
#  ['akitaonrails',
#   'i',
#   'dont',
#   'want',
#   'to',
#   'be',
#   'a',
#   'complete',
#   'hypocrite',
#   'i',
#   'attended',
#   'an',
#   'rrated',
#   'event',
#   'while',
#   'i',
#   'wa',
#   'there',
#   'the',
#   'timing',
#   'wa',
#   'just',
#   'ironic'],
#  ['he',
#   'also',
#   'incurred',
#   'the',
#   'anger',
#   'of',
#   'the',
#   'apothecary',
#   'who',
#   'were',
#   'afraid',
#   'of',
#   'being',
#   'put',
#   'out',
#   'of',
#   'business',
#   'if',
#   'all',
#   'their',
#   'complex',
#   'mixture',
#   'were',
#   'swept',
#   'away'],
#  ['im',
#   'looking',
#   'forward',
#   'to',
#   'going',
#   'home',
#   'tomorrow',
#   'but',
#   'i',
#   'really',
#   'wish',
#   'it',
#   'wa',
#   'for',
#   'a',
#   'different',
#   'reason'],
#  ['that',
#   '’',
#   's',
#   'why',
#   'it',
#   'wa',
#   'so',
#   'weird',
#   'traveling',
#   'from',
#   'beijing',
#   'to',
#   'la',
#   'because',
#   'of',
#   'the',
#   'huge',
#   'time',
#   'difference',
#   'even',
#   'though',
#   'we',
#   'left',
#   'beijing',
#   'at',
#   'noon',
#   'and',
#   'flew',
#   'for',
#   'more',
#   'than',
#   'eight',
#   'hour',
#   'we',
#   'still',
#   'arrived',
#   'in',
#   'la',
#   'the',
#   'same',
#   'day',
#   'at',
#   'noon',
#   'it',
#   '’',
#   's',
#   'like',
#   'we',
#   'went',
#   'back',
#   'in',
#   'time'],
#  ['i', 'appreciate', 'it', 'thank', 'you'],
#  ['one', 'glass', 'of', 'red', 'wine', 'coming', 'up'],
#  ['why',
#   'i',
#   'mean',
#   'why',
#   'did',
#   'she',
#   'part',
#   'company',
#   'with',
#   'you',
#   'after',
#   'seven',
#   'year',
#   'together'],
#  ['when',
#   'my',
#   'brother',
#   'did',
#   'not',
#   'send',
#   'me',
#   'the',
#   'transport',
#   'money',
#   'to',
#   'resume',
#   'my',
#   'study',
#   'in',
#   'time',
#   'at',
#   'unza'],
#  ['that', 'is', 'called', 'a', 'nuclear', 'family'],
#  ['jessmcflyxxx', 'that', 'would', 'be', 'an', 'idea', 'haha', 'xx'],
#  ['i',
#   'couldnt',
#   'find',
#   'p',
#   'so',
#   'i',
#   'couldnt',
#   'show',
#   'brantley',
#   'my',
#   'foot',
#   'and',
#   'now',
#   'it',
#   'raining'],
#  ['vicslic', 'doing', 'pretty', 'well', 'up', 'and', 'wide', 'awake'],
#  ['when', 'i', 'get', 'a', 'hug', 'from', 'someone', 'i', 'love'],
#  ['what', 'not', 'my', 'dad', 'i', 'hope'],
#  ['id',
#   'like',
#   'to',
#   'but',
#   'i',
#   'have',
#   'to',
#   'meet',
#   'my',
#   'parent',
#   'in',
#   'an',
#   'hour',
#   'for',
#   'dinner',
#   'how',
#   'about',
#   'tomorrow'],
#  ['prom', 'over', 'at', 'dennys', 'now', 'with', 'katie', 'and', 'kellylt'],
#  ['lyndygirl',
#   'any',
#   'suggestion',
#   'on',
#   'how',
#   'to',
#   'get',
#   'rid',
#   'of',
#   'that',
#   'lovely',
#   'gasoline',
#   'smell',
#   'a',
#   'it',
#   'is',
#   'still',
#   'in',
#   'my',
#   'car'],
#  ['oh',
#   'theyre',
#   'both',
#   'so',
#   'beautiful',
#   'let',
#   'me',
#   'have',
#   'this',
#   'one',
#   'i',
#   'think'],
#  ['mnoxon', 'the', 'fan', 'have', 'found', 'you'],
#  ['emlevins'],
#  ['man',
#   'i',
#   'wish',
#   'i',
#   'could',
#   'just',
#   'bathe',
#   'in',
#   'my',
#   'icecold',
#   'sunkist',
#   'right',
#   'now',
#   'but',
#   'then',
#   'id',
#   'be',
#   'sticky'],
#  ['miasmom',
#   'awhhh',
#   'age',
#   'doesnt',
#   'matter',
#   'you',
#   'awesome',
#   'lady',
#   'you'],
#  ['work', 'time'],
#  ['planning',
#   'to',
#   'install',
#   'window',
#   'tomorrow',
#   'so',
#   'probably',
#   'no',
#   'new',
#   'post',
#   'for',
#   'another',
#   'few',
#   'day',
#   'at',
#   'least'],
#  ['kalliet',
#   'this',
#   'is',
#   'sounding',
#   'like',
#   'the',
#   'worst',
#   'lurgy',
#   'ever',
#   'the',
#   'one',
#   'that',
#   'just',
#   'wont',
#   'go',
#   'away',
#   'are',
#   'you',
#   'ready',
#   'for',
#   'endofrope',
#   'action',
#   'yet'],
#  ['tired', 'tired', 'tired', 'freefest', 'today'],
#  ['suzzyqotstyle', 'me', 'too', 'chick'],
#  ['want',
#   'to',
#   'wish',
#   'all',
#   'the',
#   'mom',
#   'out',
#   'there',
#   'and',
#   'momstobe',
#   'a',
#   'very',
#   'happy',
#   'mother',
#   'day'],
#  ['you',
#   'said',
#   'it',
#   'i',
#   'always',
#   'count',
#   'on',
#   'him',
#   'when',
#   'i',
#   'need',
#   'his',
#   'help'],
#  ['everyone',
#   'is',
#   'looking',
#   'at',
#   'the',
#   'issue',
#   'in',
#   'the',
#   'short',
#   'term',
#   'rather',
#   'than',
#   'the',
#   'long',
#   'term',
#   'it',
#   '’',
#   's',
#   'the',
#   'same',
#   'with',
#   'the',
#   'destruction',
#   'of',
#   'the',
#   'rainforest',
#   'country',
#   'and',
#   'company',
#   'just',
#   'want',
#   'the',
#   'wood',
#   'they',
#   '’',
#   're',
#   'not',
#   'thinking',
#   'about',
#   'the',
#   'longterm',
#   'damage',
#   'to',
#   'the',
#   'forest',
#   'we',
#   'should',
#   'also',
#   'remember',
#   'that',
#   'the',
#   'forest',
#   'are',
#   'an',
#   'important',
#   'natural',
#   'habitat',
#   'for',
#   'thousand',
#   'of',
#   'specie',
#   'of',
#   'animal',
#   'and',
#   'plant',
#   'life'],
#  ['well',
#   'i',
#   'hope',
#   'scientist',
#   'don',
#   '’',
#   't',
#   'decode',
#   'to',
#   'make',
#   'a',
#   'clone',
#   'of',
#   'me',
#   'in',
#   'the',
#   'future',
#   'i',
#   'wouldn',
#   '’',
#   't',
#   'like',
#   'to',
#   'be',
#   'the',
#   'subject',
#   'of',
#   'an',
#   'experiment'],
#  ['yoyonb', 'tehe', 'it', 'wa', 'on', 'the', 'th'],
#  ['there',
#   'have',
#   'been',
#   'so',
#   'many',
#   'dry',
#   'winter',
#   'lately',
#   'that',
#   'it',
#   'about',
#   'time',
#   'dont',
#   'you',
#   'think'],
#  ['thank',
#   'you',
#   'mmm',
#   'can',
#   'you',
#   'tell',
#   'me',
#   'about',
#   'the',
#   'terrine'],
#  ['went',
#   'on',
#   'a',
#   'short',
#   'flight',
#   'around',
#   'the',
#   'geelong',
#   'waterfront',
#   'surprised',
#   'at',
#   'how',
#   'well',
#   'i',
#   'handled',
#   'it',
#   'a',
#   'im',
#   'still',
#   'exhausted',
#   'from',
#   'last',
#   'week',
#   'meetup'],
#  ['when',
#   'i',
#   'have',
#   'suffered',
#   'a',
#   'terrible',
#   'fit',
#   'of',
#   'eating',
#   'that',
#   'frequently',
#   'occurs',
#   'then',
#   'i',
#   'eat',
#   'everything',
#   'i',
#   'act',
#   'like',
#   'a',
#   'glutton',
#   'i',
#   'eat',
#   'big',
#   'amount',
#   'of',
#   'food',
#   'sometimes',
#   'even',
#   'half',
#   'a',
#   'loaf'],
#  ['it',
#   'got',
#   'chickpea',
#   'and',
#   'vegetable',
#   'in',
#   'a',
#   'spicy',
#   'curry',
#   'sauce',
#   'with',
#   'rice'],
#  ['so',
#   'much',
#   'for',
#   'running',
#   'outside',
#   'like',
#   'i',
#   'thought',
#   'i',
#   'wa',
#   'going',
#   'to',
#   'look',
#   'like',
#   'the',
#   'treadmill',
#   'will',
#   'have',
#   'to',
#   'do',
#   'for',
#   'todaythanks',
#   'a',
#   'lot',
#   'rain'],
#  ['google',
#   'show',
#   'me',
#   'apple',
#   'i',
#   'only',
#   'want',
#   'to',
#   'see',
#   'image',
#   'with',
#   'green',
#   'in',
#   'them',
#   'httptinyurlcomclrbau',
#   'cool'],
#  ['i', 'got', 'ill', 'and', 'tomorrow', 'iï¿½ve', 'got', 'birthday'],
#  ['my', 'tongue', 'still', 'hurt', 'i', 'need', 'to', 'sleep'],
#  ['lycoloco',
#   'im',
#   'not',
#   'proud',
#   'but',
#   'o',
#   'x',
#   'excels',
#   'at',
#   'videophoto',
#   'editing',
#   'where',
#   'the',
#   'pc',
#   'lag',
#   'so',
#   'much',
#   'behind'],
#  ['a', 'minutos', 'splitup'],
#  ['well', 'i', 'hope', 'the', 'client', 'feel', 'the', 'same', 'way'],
#  ['dont', 'act', 'like', 'your', 'not', 'impressed'],
#  ['without',
#   'my',
#   'permission',
#   'my',
#   'son',
#   'had',
#   'made',
#   'popcorn',
#   'after',
#   'coming',
#   'back',
#   'from',
#   'school',
#   'the',
#   'consequence',
#   'were',
#   'a',
#   'spoilt',
#   'kettle',
#   'and',
#   'chaos',
#   'in',
#   'the',
#   'kitchen',
#   'but',
#   'what',
#   'could',
#   'have',
#   'happened',
#   'with',
#   'the',
#   'hot',
#   'grease'],
#  ['whats', 'your', 'comment', 'on', 'his', 'new', 'album'],
#  ['after',
#   'a',
#   'long',
#   'trip',
#   'in',
#   'my',
#   'dad',
#   'van',
#   'without',
#   'incident',
#   'i',
#   'stopped',
#   'to',
#   'fill',
#   'the',
#   'tank',
#   'with',
#   'gas',
#   'and',
#   'dented',
#   'the',
#   'side',
#   'of',
#   'the',
#   'van',
#   'against',
#   'the',
#   'pole',
#   'then',
#   'my',
#   'car',
#   'electrical',
#   'system',
#   'would',
#   'not',
#   'work',
#   'when',
#   'i',
#   'tried',
#   'to',
#   'drive',
#   'home',
#   'from',
#   'his',
#   'house'],
#  ['watching',
#   'one',
#   'of',
#   'my',
#   'fav',
#   'movie',
#   'sparkle',
#   'go',
#   'get',
#   'food',
#   'later'],
#  ['imperial', 'later', 'im', 'ready', 'ready', 'for', 'a', 'nap'],
#  ['fjdskal', 'im', 'really', 'frustrated'],
#  ['dayv', 'haha', 'i', 'just', 'playing'],
#  ['hogman', 'thank', 'you', 'i', 'really', 'appreciate', 'that', 'babe'],
#  ['i',
#   'can',
#   '’',
#   't',
#   'believe',
#   'the',
#   'cost',
#   'of',
#   'apartment',
#   'in',
#   'new',
#   'york',
#   'city'],
#  ['actually',
#   'it',
#   'wa',
#   'just',
#   'some',
#   'leftover',
#   'from',
#   'yesterday',
#   'i',
#   'made',
#   'far',
#   'too',
#   'much',
#   'food',
#   'to',
#   'eat',
#   'alone',
#   'i',
#   'am',
#   'glad',
#   'you',
#   'could',
#   'come',
#   'over',
#   'to',
#   'help',
#   'me',
#   'finish',
#   'it'],
#  ['emperorliu',
#   'my',
#   'dick',
#   'feel',
#   'smaller',
#   'when',
#   'i',
#   'look',
#   'at',
#   'you'],
#  ['telling', 'white', 'lie'],
#  ['it', 'so', 'cold', 'out', 'there', 'ive', 'just', 'lost', 'my', 'wallet'],
#  ['thank',
#   'you',
#   'for',
#   'such',
#   'a',
#   'lovely',
#   'evening',
#   'the',
#   'food',
#   'wa',
#   'amazing',
#   'and',
#   'i',
#   'had',
#   'a',
#   'great',
#   'time'],
#  ['new',
#   'pic',
#   'twitter',
#   'is',
#   'finally',
#   'letting',
#   'me',
#   'change',
#   'my',
#   'pic',
#   'for',
#   'those',
#   'that',
#   'missed',
#   'it',
#   'fannish',
#   'inquisition',
#   'is',
#   'now',
#   'fannish',
#   'please',
#   'follow'],
#  ['last',
#   'academic',
#   'year',
#   'i',
#   'received',
#   'bad',
#   'news',
#   'my',
#   'granduncle',
#   'had',
#   'passed',
#   'away',
#   'i',
#   'felt',
#   'lonely',
#   'and',
#   'bad',
#   'because',
#   'apart',
#   'from',
#   'the',
#   'biological',
#   'tie',
#   'he',
#   'wa',
#   'a',
#   'good',
#   'old',
#   'friend',
#   'of',
#   'mine',
#   'at',
#   'home'],
#  ['who', 'singing', 'in', 'your', 'home', 'jim'],
#  ['oh', 'thats', 'good', 'i', 'guess', 'the', 'caddy', 'were', 'pleased'],
#  ['bummed',
#   'i',
#   'didnt',
#   'get',
#   'to',
#   'see',
#   'manchester',
#   'orchestra',
#   'bc',
#   'it',
#   'wa',
#   'sold',
#   'out',
#   'i',
#   'spent',
#   'all',
#   'night',
#   'buying',
#   'tv',
#   'show',
#   'on',
#   'itunes',
#   'lame'],
#  ['of', 'course', 'i', 'will'],
#  ['is', 'on', 'msn', 'but', 'none', 'on'],
#  ['kepp',
#   'been',
#   'there',
#   'done',
#   'that',
#   'it',
#   'always',
#   'ended',
#   'up',
#   'with',
#   'me',
#   'selling',
#   'the',
#   'machine',
#   'and',
#   'going',
#   'back',
#   'to',
#   'my',
#   'mac'],
#  ['having', 'asthma', 'issue', 'today', 'bah'],
#  ['dont', 'brother', 'me'],
#  ['this',
#   'is',
#   'a',
#   'nice',
#   'set',
#   'of',
#   'wheel',
#   'how',
#   'much',
#   'did',
#   'the',
#   'dealer',
#   'charge',
#   'you',
#   'for',
#   'this'],
#  ['and', 'i', 'never', 'got', 'to', 'see', 'it', 'on', 'print'],
#  ['it', 'raining'],
#  ['man', 'it', 'starting', 'to', 'rain', 'real', 'hard'],
#  ['jamiebower',
#   'you',
#   'should',
#   'come',
#   'to',
#   'chile',
#   'and',
#   'your',
#   'band',
#   'too',
#   'why',
#   'everything',
#   'happens',
#   'far',
#   'away',
#   'from',
#   'here',
#   'lol',
#   'were',
#   'losing',
#   'good',
#   'live',
#   'music'],
#  ['yeah', 'it', 'wa', 'a', 'lot', 'of', 'fun'],
#  ['when',
#   'the',
#   'university',
#   'withdrew',
#   'the',
#   'accomodation',
#   'that',
#   'it',
#   'had',
#   'given',
#   'me'],
#  ['httppicgdfadc',
#   'one',
#   'sunday',
#   'night',
#   'at',
#   'helsinki',
#   'we',
#   'hadnt',
#   'drink',
#   'anything',
#   'xd',
#   'yeah',
#   'right'],
#  ['update'],
#  ['to',
#   'the',
#   'doctor',
#   'anyone',
#   'wan',
#   'na',
#   'do',
#   'somethin',
#   'after',
#   'for',
#   'a',
#   'bit'],
#  ['thats',
#   'good',
#   'we',
#   'eat',
#   'chinese',
#   'food',
#   'only',
#   'at',
#   'the',
#   'chinese',
#   'restaurant'],
#  ['naughtycowgir', 'i', 'love', 'music', 'i', 'like', 'almost', 'everything'],
#  ['dnkanais', 'i', 'feel', 'reeeally', 'bad', 'now', 'sorry'],
#  ['zanzoon',
#   'omg',
#   'i',
#   'saw',
#   'something',
#   'about',
#   'a',
#   'flood',
#   'in',
#   'your',
#   'area',
#   'on',
#   'the',
#   'news',
#   'be',
#   'careful',
#   'zaina'],
#  ['is', 'off'],
#  ['shaevvv'],
#  ['also',
#   'i',
#   'managed',
#   'to',
#   'ink',
#   'half',
#   'more',
#   'page',
#   'unfortunately',
#   'page',
#   'will',
#   'totally',
#   'suck',
#   'but',
#   'at',
#   'least',
#   'i',
#   'tried',
#   'hard',
#   'before',
#   'i',
#   'decided',
#   'to',
#   'move',
#   'on'],
#  ['lilabiem',
#   'awww',
#   'dont',
#   'do',
#   'this',
#   'to',
#   'meee',
#   'haha',
#   'now',
#   'youre',
#   'gon',
#   'na',
#   'make',
#   'me',
#   'saddd'],
#  ['teabot', 'use', 'the', 'facial', 'recognition', 'feature', 'in', 'ilife'],
#  ['i',
#   'think',
#   'the',
#   'vog',
#   'is',
#   'making',
#   'me',
#   'sicker',
#   'than',
#   'i',
#   'think',
#   'feeling',
#   'slightly',
#   'achy'],
#  ['ma',
#   'he',
#   'said',
#   'in',
#   'a',
#   'tentative',
#   'tone',
#   'of',
#   'voice',
#   'his',
#   'face',
#   'going',
#   'slowly',
#   'pink',
#   'with',
#   'the',
#   'strain',
#   'of',
#   'trying',
#   'to',
#   'communicate',
#   'with',
#   'his',
#   'despondent',
#   'parent'],
#  ['my',
#   'favourite',
#   'horse',
#   'died',
#   'we',
#   'had',
#   'tried',
#   'our',
#   'best',
#   'to',
#   'save',
#   'him',
#   'but',
#   'it',
#   'wa',
#   'hopeless',
#   'he',
#   'had',
#   'to',
#   'be',
#   'shot'],
#  ['i', 'agree', 'it', 'just', 'never', 'on', 'time'],
#  ['ma', 'i', 'really', 'dont', 'know', 'how', 'to', 'thank', 'you'],
#  ['steam',
#   'punlk',
#   'fashion',
#   'show',
#   'at',
#   'anime',
#   'north',
#   'and',
#   'for',
#   'the',
#   'first',
#   'year',
#   'since',
#   'torcon',
#   'we',
#   'arent',
#   'back',
#   'til',
#   'anticipationsf',
#   'amp',
#   'missed',
#   'it'],
#  ['no', 'problem', 'good', 'luck'],
#  ['dmbdork',
#   'had',
#   'to',
#   'give',
#   'him',
#   'an',
#   'ultimatum',
#   'dont',
#   'think',
#   'it',
#   'gon',
#   'na',
#   'go',
#   'the',
#   'way',
#   'i',
#   'want',
#   'but',
#   'i',
#   'had',
#   'to',
#   'do',
#   'it'],
#  ['im',
#   'uploading',
#   'some',
#   'video',
#   'to',
#   'youtube',
#   'will',
#   'give',
#   'link',
#   'once',
#   'i',
#   'get',
#   'more',
#   'loaded',
#   'variety',
#   'from',
#   'my',
#   'daily',
#   'life',
#   'not',
#   'amazing',
#   'but',
#   'fun',
#   'to',
#   'watch'],
#  ['it',
#   'very',
#   'easy',
#   'here',
#   'it',
#   'is',
#   'ready',
#   'excellent',
#   'you',
#   'are',
#   'a',
#   'good',
#   'singer',
#   'you',
#   'sing',
#   'the',
#   'bass',
#   'so',
#   'well'],
#  ['yawnnnnn', 'slight', 'headache', 'n', 'hangover', 'grrr'],
#  ['it',
#   'd',
#   'animation',
#   'is',
#   'attractive',
#   'and',
#   'it',
#   'colorful',
#   'scene',
#   'are',
#   'also',
#   'unforgettable'],
#  ['such',
#   'a',
#   'lovely',
#   'girl',
#   'i',
#   'hope',
#   'my',
#   'paul',
#   'is',
#   'lucky',
#   'enough',
#   'to',
#   'find',
#   'a',
#   'girl',
#   'like',
#   'that',
#   'someday'],
#  ['this',
#   'is',
#   'the',
#   'end',
#   'jane',
#   'i',
#   'dont',
#   'want',
#   'a',
#   'girlfriend',
#   'who',
#   'go',
#   'out',
#   'with',
#   'other',
#   'guy',
#   'all',
#   'the',
#   'time'],
#  ['jessmcflyxxx', 'yeaahh', 'punch', 'her', 'haha', 'xx'],
#  ['alexalltimelow',
#   'aww',
#   'cant',
#   'wait',
#   'till',
#   'u',
#   'get',
#   'sydney',
#   'd',
#   'i',
#   'missed',
#   'out',
#   'on',
#   'ticket',
#   'tho',
#   'o',
#   'xxx'],
#  ['last', 'day', 'of', 'cgi'],
#  ['finger',
#   'crossed',
#   'that',
#   'my',
#   'neighbor',
#   'can',
#   'sign',
#   'for',
#   'my',
#   'ups',
#   'package',
#   'today',
#   'otherwise',
#   'it',
#   'may',
#   'be',
#   'byebye',
#   'pretty',
#   'skirt'],
#  ['i', 'agree', 'with', 'you'],
#  ['marypascoe',
#   'thanks',
#   'buddi',
#   'and',
#   'it',
#   'no',
#   'problem',
#   'your',
#   'my',
#   'friend',
#   'yah',
#   'i',
#   'should',
#   'post',
#   'more',
#   'pic',
#   'of',
#   'london',
#   'nothing',
#   'much',
#   'really',
#   'u'],
#  ['i',
#   'wa',
#   'too',
#   'miserable',
#   'to',
#   'giggle',
#   'but',
#   'i',
#   'wondered',
#   'if',
#   'the',
#   'fiance',
#   'had',
#   'when',
#   'he',
#   'postured',
#   'on',
#   'his',
#   'lawn'],
#  ['i',
#   'had',
#   'to',
#   'call',
#   'someone',
#   'and',
#   'make',
#   'an',
#   'appointment',
#   'for',
#   'a',
#   'conversation',
#   'i',
#   'wa',
#   'very',
#   'afraid',
#   'to',
#   'fail'],
#  ['velmadaria',
#   'im',
#   'still',
#   'thinking',
#   'about',
#   'that',
#   'fkc',
#   'meal',
#   'i',
#   'missed',
#   'yesterday'],
#  ['olegs', 'cant', 'test', 'itmy', 'demo', 'license', 'expired', 'yesterday'],
#  ['on',
#   'jacksonville',
#   'beach',
#   'walking',
#   'in',
#   'the',
#   'cold',
#   'as',
#   'water',
#   'but',
#   'have',
#   'to',
#   'work',
#   'in',
#   'the',
#   'morning',
#   'ily',
#   'ltgt'],
#  ['annoyingtweeple', 'you', 'having', 'fun', 'lol', 'hehe'],
#  ['thank',
#   'you',
#   'for',
#   'joining',
#   'u',
#   'now',
#   'let',
#   'see',
#   'some',
#   'picture',
#   'and',
#   'know',
#   'more',
#   'about',
#   'kung',
#   'fu'],
#  ['what',
#   'is',
#   'it',
#   'with',
#   'chocolate',
#   'i',
#   'just',
#   'can',
#   'never',
#   'say',
#   'no'],
#  ['her',
#   'excitement',
#   'shone',
#   'in',
#   'her',
#   'eye',
#   'a',
#   'she',
#   'showed',
#   'him',
#   'her',
#   'sketch'],
#  ['serenechai',
#   'thats',
#   'cool',
#   'i',
#   'think',
#   'dels',
#   'going',
#   'to',
#   'korea',
#   'same',
#   'time',
#   'a',
#   'you',
#   'have',
#   'fun'],
#  ['i',
#   'know',
#   'he',
#   '’',
#   's',
#   'going',
#   'to',
#   'be',
#   'the',
#   'next',
#   'president'],
#  ['why', 'you', '’', 're', 'not', 'satisfied', 'anymore'],
#  ['oh',
#   'that',
#   '’',
#   's',
#   'great',
#   'thanks',
#   'grace',
#   'can',
#   'you',
#   'give',
#   'me',
#   'her',
#   'number',
#   'i',
#   '’',
#   'll',
#   'talk',
#   'it',
#   'over',
#   'with',
#   'dan',
#   'and',
#   'give',
#   'her',
#   'a',
#   'call',
#   'tomorrow',
#   'maybe',
#   'this',
#   'way',
#   'i',
#   'won',
#   '’',
#   't',
#   'be',
#   'so',
#   'tired',
#   'every',
#   'day',
#   'and',
#   'dan',
#   'and',
#   'i',
#   'might',
#   'even',
#   'get',
#   'to',
#   'go'],
#  ['trillmill',
#   'i',
#   'need',
#   'to',
#   'go',
#   'shopping',
#   'with',
#   'youbut',
#   'i',
#   'need',
#   'to',
#   'save',
#   'my',
#   'money'],
#  ['right', 'now', 'im', 'on', 'the', 'internet', 'cafe'],
#  ['im', 'afraid', 'it', 'gain', 'a', 'little'],
#  ['hangin', 'out', 'with', 'some', 'cool', 'as', 'people', 'httpshorttojp'],
#  ['grasuth', 'is', 'that', 'it', 'welsh', 'name'],
#  ['officialtila',
#   'i',
#   'cnt',
#   'get',
#   'it',
#   'it',
#   'goin',
#   'to',
#   'ur',
#   'old',
#   'message',
#   'gtgtgtgt',
#   'helpltltltlt'],
#  ['wa', 'nearly', 'knocked', 'down', 'by', 'a', 'car'],
#  ['i',
#   'cant',
#   'comment',
#   'directly',
#   'to',
#   'someone',
#   'and',
#   'im',
#   'here',
#   'all',
#   'alone'],
#  ['jesuisnancy', 'thats', 'really', 'ultra', 'sweet'],
#  ['on',
#   'way',
#   'home',
#   'tonight',
#   'i',
#   'saw',
#   'a',
#   'newspaper',
#   'headline',
#   'susan',
#   'boyle',
#   'quits',
#   'surely',
#   'not',
#   'true'],
#  ['fureousangel', 'that', 'is', 'comedy', 'good', 'luck', 'my', 'friend'],
#  ['watching',
#   'jeremy',
#   'assemble',
#   'jr',
#   'new',
#   'radio',
#   'flyer',
#   'bike',
#   'jr',
#   'is',
#   'sick',
#   'with',
#   'degree',
#   'fever',
#   'taking',
#   'a',
#   'nap',
#   'this',
#   'will',
#   'cheer',
#   'him',
#   'up',
#   'though'],
#  ['mabelandviolet',
#   'i',
#   'wa',
#   'going',
#   'to',
#   'send',
#   'you',
#   'the',
#   'photo',
#   'by',
#   'dm',
#   'but',
#   'cant',
#   'a',
#   'you',
#   'not',
#   'following',
#   'me'],
#  ['annerondeau', 'i', 'love', 'you'],
#  ['beauknows',
#   'good',
#   'luck',
#   'going',
#   'to',
#   'sleep',
#   'im',
#   'up',
#   'working',
#   'on',
#   'a',
#   'stupid',
#   'paper',
#   'no',
#   'worry',
#   'ur',
#   'not',
#   'alone',
#   'so',
#   'u',
#   'ready',
#   'to',
#   'record',
#   'that',
#   'album',
#   'or',
#   'what'],
#  ['yes', 'i', 'am', 'i', 'got', 'married', 'five', 'year', 'ago'],
#  ['nelsonsito', 'hi', 'fellow', 'peruvian'],
#  ['thank', 'you', 'sir', 'just', 'a', 'moment', 'please'],
#  ['gary',
#   'just',
#   'tried',
#   'the',
#   'ommegang',
#   'chocolate',
#   'indulgence',
#   'no',
#   'chocolate',
#   'no',
#   'indulgence',
#   'just',
#   'metallic',
#   'best',
#   'i',
#   'can',
#   'httpffimorv'],
#  ['what', 'a', 'heavy', 'snow', 'look', 'the', 'water', 'is', 'frozen'],
#  ['when',
#   'a',
#   'thief',
#   'broke',
#   'into',
#   'my',
#   'house',
#   'and',
#   'stole',
#   'some',
#   'valuable',
#   'good'],
#  ['yay', 'my', 'ear', 'match'],
#  ['i',
#   'wa',
#   'very',
#   'sad',
#   'when',
#   'i',
#   'could',
#   'not',
#   'take',
#   'the',
#   'ma',
#   'i',
#   'exam',
#   'due',
#   'to',
#   'illness',
#   'and',
#   'a',
#   'relative',
#   'of',
#   'mine',
#   'disheartened',
#   'me',
#   'about',
#   'it'],
#  ['feelin',
#   'depressed',
#   'i',
#   'miss',
#   'you',
#   'soo',
#   'damn',
#   'fcking',
#   'much',
#   'besties',
#   'i',
#   'wish',
#   'i',
#   'wouldnt',
#   'have',
#   'left',
#   'yt'],
#  ['fuck', 'maaaaannnn', 'it', 'holidayzzzzz'],
#  ['shift', 'time', 'bbye', 'biochem', 'waaaaahhhhhh', 'httpplurkcompwxizo'],
#  ['shelbystroman',
#   'yes',
#   'it',
#   'is',
#   'like',
#   'superglued',
#   'inside',
#   'my',
#   'head'],
#  ['im', 'awake', 'while', 'others', 'sleep'],
#  ['wondering',
#   'where',
#   'all',
#   'the',
#   'money',
#   'i',
#   'earnt',
#   'this',
#   'financial',
#   'year',
#   'ha',
#   'gone',
#   'i',
#   'can',
#   'account',
#   'for',
#   'like',
#   'grand',
#   'but',
#   'wheres',
#   'the',
#   'rest'],
#  ['hi', 'rose', 'what', 'are', 'you', 'busy', 'with', 'right', 'now'],
#  ['ericandersen', 'thank', 'you', 'eric', 'glad', 'u', 'appreciate', 'that'],
#  ['laralowell', 'well', 'i', 'know', 'i', 'am'],
#  ['got',
#   'ta',
#   'love',
#   'nasty',
#   'weatherrrrr',
#   'kileyymariee',
#   'so',
#   'jealous',
#   'ur',
#   'at',
#   'knotts'],
#  ['yes',
#   'jane',
#   'invited',
#   'me',
#   'for',
#   'dinner',
#   'to',
#   'this',
#   'new',
#   'restaurant',
#   'which',
#   'opened',
#   'near',
#   'u'],
#  ['he',
#   'had',
#   'a',
#   'clear',
#   'picture',
#   'of',
#   'a',
#   'sad',
#   'and',
#   'lonely',
#   'man',
#   'deeply',
#   'concerned',
#   'about',
#   'his',
#   'health',
#   'and',
#   'dwelling',
#   'on',
#   'a',
#   'future',
#   'which',
#   'seemed',
#   'to',
#   'promise',
#   'only',
#   'a',
#   'fairly',
#   'rapid',
#   'decline',
#   'into',
#   'senility'],
#  ['when',
#   'i',
#   'ate',
#   'my',
#   'sister',
#   'food',
#   'and',
#   'then',
#   'she',
#   'found',
#   'out',
#   'that',
#   'it',
#   'wa',
#   'me',
#   'i',
#   'felt',
#   'very',
#   'ashamed',
#   'but',
#   'still',
#   'refused',
#   'to',
#   'admit',
#   'that',
#   'it',
#   'wa',
#   'me'],
#  ['well',
#   'we',
#   'have',
#   'always',
#   'dreamed',
#   'of',
#   'owning',
#   'our',
#   'own',
#   'home',
#   'but',
#   'real',
#   'estate',
#   'in',
#   'this',
#   'area',
#   'is',
#   'extremely',
#   'expensive'],
#  ['im',
#   'so',
#   'glad',
#   'you',
#   'can',
#   'finally',
#   'see',
#   'thing',
#   'in',
#   'my',
#   'way',
#   'can',
#   'we',
#   'leave',
#   'this',
#   'dull',
#   'place',
#   'now'],
#  ['is', 'thinking', 'about', 'a', 'career', 'change'],
#  ['played',
#   'a',
#   'bit',
#   'pool',
#   'with',
#   'my',
#   'buddiesgoing',
#   'to',
#   'bed',
#   'now',
#   'have',
#   'to',
#   'work',
#   'tomorrow'],
#  ['is',
#   'somewhat',
#   'irritated',
#   'by',
#   'people',
#   'coming',
#   'up',
#   'to',
#   'me',
#   'and',
#   'asking',
#   'if',
#   'im',
#   'so',
#   'and',
#   'so',
#   'from',
#   'tv',
#   'or',
#   'that',
#   'i',
#   'look',
#   'familiar',
#   'i',
#   'thought',
#   'i',
#   'wa',
#   'original'],
#  ['lisr', 'i', 'love', 'electro', 'house'],
#  ['last', 'day', 'working', 'for', 'the', 'uni', 'today', 'sad', 'time'],
#  ['see', 'you', 'then'],
#  ['i',
#   'have',
#   'been',
#   'hearing',
#   'rumour',
#   'that',
#   'you',
#   'have',
#   'not',
#   'been',
#   'allowing',
#   'people',
#   'in',
#   'your',
#   'room',
#   'he',
#   'said',
#   'this',
#   'sentence',
#   'really',
#   'shot',
#   'my',
#   'heart',
#   'i',
#   'failed',
#   'to',
#   'find',
#   'the',
#   'right',
#   'word',
#   'instead',
#   'i',
#   'walked',
#   'away',
#   'without',
#   'uttering',
#   'a',
#   'word'],
#  ['during',
#   'the',
#   'summer',
#   'at',
#   'my',
#   'workplace',
#   'a',
#   'person',
#   'kept',
#   'interfering',
#   'with',
#   'my',
#   'task',
#   'and',
#   'making',
#   'unfounded',
#   'remark',
#   'i',
#   'felt',
#   'hatred',
#   'for',
#   'him',
#   'but',
#   'it',
#   'stopped',
#   'when',
#   'i',
#   'realized',
#   'that',
#   'he',
#   'just',
#   'longed',
#   'for',
#   'attention'],
#  ['going',
#   'to',
#   'eat',
#   'rice',
#   'and',
#   'fried',
#   'chicken',
#   'from',
#   'sederhana',
#   'the',
#   'padang',
#   'restaurant',
#   'yummy'],
#  ['not', 'eating', 'lunch', 'with', 'my', 'wife', 'like', 'i', 'wanted', 'to'],
#  ['neeshababyyy', 'they', 'wont', 'guy', 'are', 'retarded'],
#  ['my', 'nose', 'is', 'stuffy'],
#  ['chet',
#   'yep',
#   'infact',
#   'she',
#   'is',
#   'popular',
#   'miss',
#   'india',
#   'talented',
#   'film',
#   'actress',
#   'and',
#   'lot',
#   'more'],
#  ['after',
#   'a',
#   'disagreement',
#   'between',
#   'my',
#   'parent',
#   'when',
#   'i',
#   'wa',
#   'alone',
#   'with',
#   'my',
#   'father',
#   'and',
#   'my',
#   'sister',
#   'the',
#   'aggression',
#   'continued',
#   'when',
#   'my',
#   'father',
#   'tried',
#   'to',
#   'put',
#   'me',
#   'and',
#   'my',
#   'sister',
#   'against',
#   'my',
#   'mother',
#   'revealing',
#   'fact',
#   'that',
#   'had',
#   'happened',
#   'in',
#   'the',
#   'past',
#   'like',
#   'a',
#   'talk',
#   'between',
#   'my',
#   'father',
#   'and',
#   'his',
#   'mother',
#   'in',
#   'law',
#   'where',
#   'she',
#   'told',
#   'him',
#   'that',
#   'my',
#   'mother',
#   'wa',
#   'not',
#   'quite',
#   'save'],
#  ['supertriviaguy',
#   'hey',
#   'we',
#   'were',
#   'at',
#   'tallebudgera',
#   'creek',
#   'at',
#   'pmvisiting',
#   'anitas',
#   'special',
#   'treecould',
#   'have',
#   'almost',
#   'bumped',
#   'into',
#   'you'],
#  ['rebeccaleigh',
#   'thank',
#   'you',
#   'just',
#   'trying',
#   'to',
#   'stay',
#   'in',
#   'a',
#   'positive',
#   'head',
#   'space',
#   'to',
#   'keep',
#   'pushing',
#   'through',
#   'it',
#   'all',
#   'hows',
#   'thing',
#   'at',
#   'your',
#   'end'],
#  ['steveagent',
#   'i',
#   'think',
#   'i',
#   'should',
#   'but',
#   'with',
#   'who',
#   'hmmmm',
#   'maybe',
#   'a',
#   'friend',
#   'in',
#   'alaska'],
#  ['thanks'],
#  ['when',
#   'we',
#   'could',
#   'not',
#   'land',
#   'our',
#   'plane',
#   'and',
#   'we',
#   'knew',
#   'that',
#   'the',
#   'fuel',
#   'wa',
#   'running',
#   'out',
#   'bad',
#   'weather',
#   'had',
#   'already',
#   'frightened',
#   'u'],
#  ['ammoxxx',
#   'great',
#   'day',
#   'woman',
#   'did',
#   'you',
#   'notice',
#   'the',
#   'smile',
#   'that',
#   'never',
#   'disappeared',
#   'off',
#   'my',
#   'face',
#   'ha',
#   'murray',
#   'all',
#   'co',
#   'of',
#   'you',
#   'i',
#   'owe',
#   'you'],
#  ['thank', 'you'],
#  ['at',
#   'work',
#   'a',
#   'boy',
#   'wa',
#   'injured',
#   'because',
#   'of',
#   'my',
#   'lack',
#   'of',
#   'supervision'],
#  ['can', 'you', 'imagine', 'shes', 'over', 'forty'],
#  ['when',
#   'i',
#   'succeed',
#   'in',
#   'writing',
#   'something',
#   'i',
#   'felt',
#   'and',
#   'doing',
#   'it',
#   'i',
#   'felt',
#   'well',
#   'and',
#   'very',
#   'happy',
#   'for',
#   'being',
#   'able',
#   'to',
#   'express',
#   'to',
#   'myself',
#   'something',
#   'that',
#   'wa',
#   'suffocating',
#   'me'],
#  ['rain',
#   'stopped',
#   'a',
#   'few',
#   'minute',
#   'ago',
#   'i',
#   'noticed',
#   'that',
#   'every',
#   'time',
#   'i',
#   'cheer',
#   'for',
#   'the',
#   'rain',
#   'while',
#   'it',
#   'raining',
#   'it',
#   'stop',
#   'i',
#   'shall',
#   'not',
#   'cheer',
#   'next',
#   'time'],
#  ['powerpoole', 'you', 'are', 'quite', 'welcome', 'mr', 'poole'],
#  ['when',
#   'i',
#   'met',
#   'my',
#   'girlfriend',
#   'i',
#   'had',
#   'not',
#   'counted',
#   'on',
#   'that'],
#  ['got',
#   'into',
#   'the',
#   'show',
#   'early',
#   'jackson',
#   'chillen',
#   'lil',
#   'shorty'],
#  ['brian', 'is', 'teaching', 'me', 'soccer', 'lot', 'of', 'fun'],
#  ['when',
#   'i',
#   'sided',
#   'with',
#   'my',
#   'mother',
#   'in',
#   'a',
#   'quarrel',
#   'she',
#   'had',
#   'with',
#   'my',
#   'father',
#   'before',
#   'they',
#   'briefly',
#   'separated'],
#  ['thanks',
#   'for',
#   'coming',
#   'over',
#   'to',
#   'help',
#   'i',
#   'really',
#   'appreciate',
#   'itfirst',
#   'could',
#   'you',
#   'peel',
#   'the',
#   'vegetable',
#   'i',
#   '’',
#   've',
#   'put',
#   'them',
#   'all',
#   'in',
#   'the',
#   'sink',
#   'and',
#   'there',
#   'is',
#   'a',
#   'peeler'],
#  ['on',
#   'the',
#   'list',
#   'of',
#   'park',
#   'closure',
#   'calaveras',
#   'big',
#   'tree',
#   'sp',
#   'where',
#   'im',
#   'headed',
#   'this',
#   'weekend',
#   'so',
#   'glad',
#   'to',
#   'be',
#   'visiting',
#   'before',
# ...
#   'crashed',
#   'through',
#   'that',
#   'by',
#   'the',
#   'time',
#   'i',
#   'come',
#   'back',
#   'tonight'],
#  ['yes',
#   'that',
#   '’',
#   's',
#   'why',
#   'i',
#   'listen',
#   'to',
#   'it',
#   'in',
#   'the',
#   'evening',
#   'i',
#   'usually',
#   'play',
#   'it',
#   'a',
#   'background',
#   'music',
#   'while',
#   'i',
#   '’',
#   'm',
#   'cooking',
#   'or',
#   'doing',
#   'other',
#   'housework'],
#  ['bored',
#   'and',
#   'kinda',
#   'lonely',
#   'my',
#   'parent',
#   'went',
#   'up',
#   'to',
#   'the',
#   'lake',
#   'i',
#   'didnt',
#   'have',
#   'a',
#   'friend',
#   'to',
#   'bring',
#   'up',
#   'so',
#   'i',
#   'knew',
#   'i',
#   'wa',
#   'bored',
#   'and',
#   'didnt',
#   'go'],
#  ['there', 'are', 'three', 'of', 'them', 'the', 'three', 'tenor'],
#  ['good',
#   'morning',
#   'to',
#   'all',
#   'the',
#   'mommy',
#   'happy',
#   'mother',
#   'day',
#   'now',
#   'i',
#   'am',
#   'off',
#   'the',
#   'pull',
#   'the',
#   'cat',
#   'tail',
#   'i',
#   'know',
#   'she',
#   'like',
#   'it'],
#  ['he',
#   'came',
#   'in',
#   'too',
#   'fast',
#   'jammed',
#   'on',
#   'the',
#   'break',
#   'and',
#   'spun',
#   'out',
#   'we',
#   'have',
#   'a',
#   'yellow',
#   'flag',
#   'and',
#   'the',
#   'pace',
#   'car',
#   'is',
#   'making',
#   'it',
#   'way',
#   'onto',
#   'the',
#   'track'],
#  ['calvinharris',
#   'stop',
#   'talkin',
#   'about',
#   'food',
#   'haha',
#   'fill',
#   'like',
#   'sum',
#   'nw',
#   'hha',
#   'hows',
#   'your',
#   'day',
#   'goin',
#   'or',
#   'starting'],
#  ['thegreenwizard',
#   'ah',
#   'ha',
#   'cool',
#   'will',
#   'look',
#   'into',
#   'that',
#   'more',
#   'closely',
#   'when',
#   'i',
#   'get',
#   'on',
#   'a',
#   'proper',
#   'sized',
#   'screen',
#   'thanks'],
#  ['at',
#   'the',
#   'end',
#   'of',
#   'my',
#   'senior',
#   'yr',
#   'in',
#   'high',
#   'school',
#   'i',
#   'found',
#   'out',
#   'that',
#   'a',
#   'friend',
#   'of',
#   'mine',
#   'i',
#   'knew',
#   'had',
#   'cancer',
#   'had',
#   'been',
#   'diagnosed',
#   'a',
#   'terminally',
#   'ill'],
#  ['donniewahlberg',
#   'ready',
#   'and',
#   'waiting',
#   'donnie',
#   'we',
#   'love',
#   'you',
#   'too'],
#  ['he',
#   'considered',
#   'this',
#   'thoughtfully',
#   'then',
#   'a',
#   'gleam',
#   'of',
#   'amusement',
#   'came',
#   'into',
#   'his',
#   'eye'],
#  ['hey', 'guy', 'im', 'back', 'from', 'work', 'it', 'wa', 'kinda', 'horrible'],
#  ['katdart',
#   'im',
#   'talking',
#   'to',
#   'myself',
#   'didnt',
#   'know',
#   'you',
#   'could',
#   'do',
#   'that'],
#  ['oath',
#   'that',
#   'make',
#   'so',
#   'much',
#   'more',
#   'sense',
#   'haha',
#   'well',
#   'great',
#   'i',
#   'dont',
#   'like',
#   'german',
#   'food',
#   'anyway'],
#  ['pyuric',
#   'enjoy',
#   'the',
#   'coffee',
#   'we',
#   'miss',
#   'you',
#   'petite',
#   'puce',
#   'adica',
#   'puricel',
#   'in',
#   'franceza'],
#  ['gon',
#   'na',
#   'head',
#   'to',
#   'bed',
#   'then',
#   'work',
#   'then',
#   'moncton',
#   'to',
#   'see',
#   'jill'],
#  ['oh', 'really', 'is', 'he', 'all', 'right'],
#  ['feeling',
#   'so',
#   'low',
#   'and',
#   'depressed',
#   'that',
#   'im',
#   'not',
#   'on',
#   'holiday'],
#  ['httpbitlyjov',
#   'how',
#   'genius',
#   'he',
#   'look',
#   'good',
#   'in',
#   'bret',
#   'lov',
#   'him',
#   'why',
#   'cancelled',
#   'concert',
#   'in',
#   'france',
#   'i',
#   'wa',
#   'ready',
#   'men'],
#  ['no',
#   'the',
#   'burn',
#   'ointment',
#   'seemed',
#   'to',
#   'take',
#   'effect',
#   'right',
#   'away',
#   'i',
#   'think',
#   'it',
#   'already',
#   'healed'],
#  ['tomfelton',
#   'httptwitpiccomjam',
#   'beautiful',
#   'landscape',
#   'it',
#   'seems',
#   'very',
#   'quiet'],
#  ['being', 'asked', 'to', 'go', 'out', 'by', 'someone', 'i', 'care'],
#  ['nelpix', 'turned', 'out', 'nice', 'i', 'think', 'httptwitpiccomjeil'],
#  ['strawberry', 'margarita', 'baked', 'stuffed', 'shrimp'],
#  ['stephhh',
#   'awww',
#   'i',
#   'heard',
#   'he',
#   'is',
#   'the',
#   'sweetest',
#   'guy',
#   'with',
#   'fan'],
#  ['miss', 'her', 'phone', 'having', 'no', 'service', 'suck'],
#  ['that',
#   'sound',
#   'good',
#   'they',
#   'have',
#   'a',
#   'movie',
#   'theatre',
#   'there',
#   'so',
#   'if',
#   'we',
#   'get',
#   'bored',
#   'we',
#   'can',
#   'watch',
#   'a',
#   'movie'],
#  ['ginger',
#   'biscuit',
#   'rule',
#   'by',
#   'the',
#   'way',
#   'i',
#   'urgently',
#   'need',
#   'weight',
#   'scale'],
#  ['we',
#   'really',
#   'were',
#   'lucky',
#   'we',
#   'got',
#   'the',
#   'last',
#   'available',
#   'table',
#   'for',
#   'twoand',
#   'we',
#   'didnt',
#   'even',
#   'have',
#   'a',
#   'reservation',
#   'did',
#   'you',
#   'see',
#   'the',
#   'long',
#   'line',
#   'behind',
#   'u'],
#  ['take',
#   'care',
#   'of',
#   'yourself',
#   'and',
#   'remember',
#   'to',
#   'keep',
#   'in',
#   'touch'],
#  ['galiiit',
#   'haha',
#   'def',
#   'that',
#   'song',
#   'is',
#   'epic',
#   'have',
#   'fun',
#   'im',
#   'listening',
#   'to',
#   'new',
#   'fnb'],
#  ['souljaboytellem', 'aw', 'thats', 'cute'],
#  ['at',
#   'school',
#   'cant',
#   'wait',
#   'to',
#   'get',
#   'out',
#   'of',
#   'here',
#   'todayget',
#   'my',
#   'tattoo',
#   'at'],
#  ['we',
#   'have',
#   'a',
#   'guy',
#   'who',
#   'play',
#   'guitar',
#   'and',
#   'another',
#   'who',
#   'play',
#   'bassalthough',
#   'we',
#   'still',
#   'haven',
#   '’',
#   't',
#   'found',
#   'anyone',
#   'to',
#   'be',
#   'our',
#   'singer',
#   'you',
#   'told',
#   'me',
#   'that',
#   'you',
#   'had',
#   'some',
#   'musical',
#   'talent',
#   'right'],
#  ['happy', 'mother', 'day'],
#  ['paulbaan',
#   'hello',
#   'paul',
#   'nice',
#   'to',
#   'hear',
#   'someone',
#   'is',
#   'listening',
#   'some',
#   'interesting',
#   'thought',
#   'from',
#   'kaashoek',
#   'unisys',
#   'patel',
#   'from',
#   'doculabs',
#   'next'],
#  ['cupcake', 'creme', 'brulee', 'tiramisu', 'i', 'want', 'some', 'sugar'],
#  ['neil',
#   'kinnock',
#   'wa',
#   'happy',
#   'that',
#   'his',
#   'deputy',
#   'should',
#   'spell',
#   'out',
#   'his',
#   'commitment',
#   'to',
#   'equality',
#   'a',
#   'labour',
#   's',
#   'objective'],
#  ['my',
#   'twitteeeerrr',
#   'babiieshow',
#   'ive',
#   'missed',
#   'you',
#   'i',
#   'hate',
#   'this',
#   'whole',
#   'not',
#   'having',
#   'a',
#   'phone',
#   'thng'],
#  ['thank',
#   'you',
#   'which',
#   'gate',
#   'should',
#   'i',
#   'go',
#   'to',
#   'for',
#   'the',
#   'bus'],
#  ['my',
#   'mother',
#   'wa',
#   'unwell',
#   'and',
#   'went',
#   'for',
#   'many',
#   'cancer',
#   'test',
#   'she',
#   'spent',
#   'time',
#   'in',
#   'hospital',
#   'being',
#   'opened',
#   'and',
#   'closed',
#   'many',
#   'time'],
#  ['pourpresheep', 'lol', 'thanks', 'babe'],
#  ['rliversidge', 'great', 'stuff', 'cant', 'wait', 'to', 'hear', 'it'],
#  ['peapodann',
#   'the',
#   'second',
#   'i',
#   'hit',
#   'reply',
#   'to',
#   'that',
#   'tweet',
#   'i',
#   'wa',
#   'asked',
#   'to',
#   'stop',
#   'playing',
#   'music',
#   'i',
#   'am',
#   'now',
#   'sad',
#   'someone',
#   'sing',
#   'to',
#   'me',
#   'on',
#   'or',
#   'off',
#   'key',
#   'work'],
#  ['do',
#   'you',
#   'want',
#   'to',
#   'go',
#   'to',
#   'an',
#   'exhibition',
#   'there',
#   '’',
#   's',
#   'one',
#   'of',
#   'xinghai',
#   'exhibition',
#   'hall',
#   'tomorrow'],
#  ['the',
#   'veronica',
#   'are',
#   'gon',
#   'na',
#   'rock',
#   'the',
#   'stage',
#   'tomorrow',
#   'happy',
#   'mother',
#   'day',
#   'everyone'],
#  ['hywd', 'no', 'are', 'you', 'for', 'sure', 'going'],
#  ['what', 'happen', 'john'],
#  ['ah',
#   'wa',
#   'affronted',
#   'fur',
#   'her',
#   'imagine',
#   'gettin',
#   'stuck',
#   'n',
#   'huvin',
#   'to',
#   'get',
#   'rolled',
#   'on',
#   'to',
#   'a',
#   'stretcher',
#   'the',
#   'perr',
#   'o',
#   'them',
#   'and',
#   'kerted',
#   'oot',
#   'covered',
#   'up',
#   'wi',
#   'his',
#   'poplin',
#   'shortie'],
#  ['now',
#   'i',
#   'like',
#   'startrek',
#   'personal',
#   'feel',
#   'that',
#   'startrek',
#   'movie',
#   'is',
#   'better',
#   'than',
#   'xmen'],
#  ['lulazoid', 'so', 'vacation', 'is', 'good', 'so', 'far'],
#  ['this',
#   'is',
#   'about',
#   'a',
#   'close',
#   'to',
#   'brooklyn',
#   'a',
#   'i',
#   'usually',
#   'get',
#   'this',
#   'neighborhood',
#   'ha',
#   'changed',
#   'a',
#   'lot',
#   'in',
#   'year',
#   'httptwitpiccomwfr'],
#  ['it',
#   'really',
#   'doesnt',
#   'matter',
#   'at',
#   'all',
#   'i',
#   'never',
#   'did',
#   'like',
#   'it',
#   'anyway'],
#  ['and',
#   'if',
#   'we',
#   'dont',
#   'need',
#   'them',
#   'we',
#   'wont',
#   'need',
#   'zina',
#   'either'],
#  ['twitter', 'wont', 'work', 'on', 'my', 'mob'],
#  ['rainbowmonkeys',
#   'that',
#   'is',
#   'not',
#   'even',
#   'a',
#   'question',
#   'whenwhen',
#   'is',
#   'the',
#   'question'],
#  ['iamdpbeltran', 'where', 'is', 'home'],
#  ['really', 'doe', 'she', 'live', 'here', 'in', 'seattle'],
#  ['bom',
#   'dia',
#   'good',
#   'morning',
#   'guten',
#   'morgen',
#   'i',
#   'am',
#   'returning',
#   'to',
#   'twitter'],
#  ['q',
#   'what',
#   'studio',
#   'created',
#   'open',
#   'season',
#   'should',
#   'google',
#   'it',
#   'or',
#   'look',
#   'at',
#   'the',
#   'dvd',
#   'downstairs',
#   'but',
#   'feeling',
#   'lazy'],
#  ['evermore',
#   'amp',
#   'end',
#   'of',
#   'fashion',
#   'rock',
#   'my',
#   'poor',
#   'foot',
#   'though',
#   'oww',
#   'injured',
#   'my',
#   'foot',
#   'not',
#   'good',
#   'will',
#   'be',
#   'sore',
#   'tomorrow',
#   'detail',
#   'to',
#   'follow',
#   'later'],
#  ['curious',
#   'if',
#   'they',
#   'fixed',
#   'the',
#   'window',
#   'handle',
#   'in',
#   'our',
#   'room',
#   'in',
#   'the',
#   'meantime',
#   'edc'],
#  ['playing', 'with', 'zeke', 'he', 'leaving', 'today'],
#  ['erinmusicluver', 'i', 'thought', 'you', 'liked', 'the', 'name'],
#  ['pathea',
#   'good',
#   'morning',
#   'duh',
#   'must',
#   'get',
#   'my',
#   'brain',
#   'in',
#   'gear',
#   'before',
#   'tweeting'],
#  ['i',
#   'can',
#   'not',
#   'think',
#   'of',
#   'any',
#   'incident',
#   'when',
#   'i',
#   'have',
#   'felt',
#   'very',
#   'ashamed',
#   'there',
#   'are',
#   'small',
#   'incident',
#   'that',
#   'i',
#   'am',
#   'ashamed',
#   'of',
#   'for',
#   'instance',
#   'not',
#   'sending',
#   'money',
#   'to',
#   'the',
#   'child',
#   'in',
#   'ethiopia'],
#  ['good',
#   'morning',
#   'twitterer',
#   'rise',
#   'and',
#   'shine',
#   'just',
#   'on',
#   'my',
#   'way',
#   'to',
#   'school'],
#  ['carolina', 'won', 'yeah'],
#  ['when',
#   'i',
#   'wa',
#   'young',
#   'my',
#   'parent',
#   'took',
#   'me',
#   'to',
#   'the',
#   'one',
#   'in',
#   'california',
#   'i',
#   'always',
#   'forget',
#   'which',
#   '—',
#   'is',
#   'that',
#   'one',
#   'disneyland',
#   'or',
#   'disneyworld'],
#  ['in',
#   'the',
#   's',
#   'wife',
#   'were',
#   'still',
#   'bitterly',
#   'resentful',
#   'of',
#   'the',
#   'fact',
#   'that',
#   'their',
#   'husband',
#   'did',
#   'not',
#   'seem',
#   'to',
#   'realise',
#   'that',
#   'they',
#   'needed',
#   'leisure'],
#  ['workk', 'yay'],
#  ['it', '’', 's', 'simply', 'because', 'the', 'tin', 'were', 'damaged'],
#  ['another', 'week', 'start'],
#  ['im',
#   'hungry',
#   'amp',
#   'i',
#   'dunno',
#   'what',
#   'to',
#   'makei',
#   'want',
#   'popcorn',
#   'chicken',
#   'w',
#   'mac',
#   'amp',
#   'cheese'],
#  ['in',
#   'those',
#   'day',
#   'captain',
#   'of',
#   'industry',
#   'were',
#   'not',
#   'ashamed',
#   'to',
#   'live',
#   'close',
#   'to',
#   'the',
#   'source',
#   'of',
#   'their',
#   'wealth'],
#  ['not',
#   'feeling',
#   'very',
#   'good',
#   'at',
#   'all',
#   'why',
#   'doe',
#   'this',
#   'have',
#   'to',
#   'happen',
#   'today',
#   'of',
#   'all',
#   'day',
#   'not',
#   'going',
#   'to',
#   'friend',
#   'tonight'],
#  ['left',
#   'alone',
#   'in',
#   'the',
#   'biology',
#   'building',
#   'surrounded',
#   'by',
#   'empty',
#   'building'],
#  ['it',
#   '’',
#   's',
#   'an',
#   'absolute',
#   'outrage',
#   'sarah',
#   'the',
#   'u',
#   'government',
#   'want',
#   'to',
#   'give',
#   'billion',
#   'dollar',
#   'of',
#   'taxpayer',
#   '’',
#   'money',
#   'to',
#   'the',
#   'auto',
#   'industry',
#   'these',
#   'are',
#   'company',
#   'that',
#   'have',
#   'been',
#   'mismanaged',
#   'and',
#   'are',
#   'now',
#   'nearly',
#   'bankrupt'],
#  ['what', 'a', 'splendid', 'idea'],
#  ['after',
#   'seeing',
#   'a',
#   'horror',
#   'film',
#   'omen',
#   'i',
#   'could',
#   'not',
#   'sleep',
#   'at',
#   'night',
#   'even',
#   'though',
#   'i',
#   'closed',
#   'my',
#   'eye',
#   'the',
#   'last',
#   'scene',
#   'of',
#   'the',
#   'film',
#   'kept',
#   'coming',
#   'back',
#   'to',
#   'me',
#   'i',
#   'seemed',
#   'to',
#   'hear',
#   'the',
#   'girl',
#   'in',
#   'the',
#   'film',
#   'shouting',
#   'at',
#   'the',
#   'devil',
#   'the',
#   'devil',
#   'did',
#   'not',
#   'have',
#   'any',
#   'expression',
#   'on',
#   'his',
#   'face',
#   'and',
#   'i',
#   'thought',
#   'that',
#   'he',
#   'would',
#   'choose',
#   'me'],
#  ['puddynface',
#   'dont',
#   'know',
#   'yet',
#   'lem',
#   'me',
#   'know',
#   'if',
#   'you',
#   'come',
#   'up',
#   'with',
#   'something',
#   'though'],
#  ['it',
#   '’',
#   's',
#   'asian',
#   'fusion',
#   'i',
#   'heard',
#   'it',
#   '’',
#   's',
#   'delicious'],
#  ['forgot', 'to', 'wish', 'sister', 'happy', 'birthday', 'yesterday'],
#  ['saying', 'goodbye', 'to', 'a', 'friend'],
#  ['it', 'very', 'kind', 'of', 'you'],
#  ['thank', 'you', 'for', 'the', 'invitation'],
#  ['cowgirlnchaps',
#   'it',
#   'would',
#   'be',
#   'so',
#   'fun',
#   'too',
#   'much',
#   'to',
#   'do',
#   'not',
#   'enough',
#   'time',
#   'or',
#   'money'],
#  ['macquid',
#   'no',
#   'strange',
#   'each',
#   'time',
#   'we',
#   'return',
#   'i',
#   'feel',
#   'like',
#   'i',
#   'have',
#   'come',
#   'home',
#   'and',
#   'yet',
#   'i',
#   'have',
#   'no',
#   'spanish',
#   'blood',
#   'that',
#   'i',
#   'know',
#   'of'],
#  ['jtsui',
#   'i',
#   'wish',
#   'i',
#   'could',
#   'sat',
#   'but',
#   'thats',
#   'a',
#   'super',
#   'busy',
#   'day',
#   'sunday',
#   'perhaps',
#   'playing',
#   'football',
#   'in',
#   'dolores',
#   'park',
#   'too',
#   'youre',
#   'welcome',
#   'to',
#   'come',
#   'hang'],
#  ['lamaestrada',
#   'i',
#   'agree',
#   'about',
#   'tw',
#   'me',
#   'and',
#   'my',
#   'cat',
#   'have',
#   'been',
#   'watching',
#   'full',
#   'housse',
#   'sabrina',
#   'the',
#   'teenage',
#   'witch',
#   'and',
#   'sister',
#   'sister',
#   'rerun'],
#  ['lizziecoulter', 'oh', 'dear', 'im', 'sorry', 'but', 'i', 'laughed'],
#  ['is', 'eating', 'poutine', 'and', 'listening', 'to', 'mitch', 'hedburg'],
#  ['perhaps',
#   'he',
#   'wa',
#   'just',
#   'imagining',
#   'the',
#   'undercurrent',
#   'of',
#   'nostalgia',
#   'he',
#   'told',
#   'himself',
#   'a',
#   'he',
#   'looked',
#   'at',
#   'corabeth',
#   's',
#   'flushed',
#   'excited',
#   'face'],
#  ['hammett',
#   'i',
#   'wish',
#   'i',
#   'could',
#   'have',
#   'time',
#   'for',
#   'my',
#   'xbox',
#   'project',
#   'all',
#   'tied'],
#  ['oxgrace', 'i', 'cant', 'do', 'anything'],
#  ['epicfail', 'and', 'joseph', 'in', 'class', 'very', 'long', 'liao'],
#  ['gintareauglyte', 'hey', 'how', 'are', 'you', 'x'],
#  ['he',
#   'is',
#   'not',
#   'answering',
#   'youd',
#   'better',
#   'check',
#   'his',
#   'pulse',
#   'and',
#   'breathing'],
#  ['cascandar', 'we', 'are', 'working'],
#  ['agonisingnewt', 'morning', 'newthope', 'you', 'are', 'well'],
#  ['it', 'amazing', 'make', 'my', 'heart', 'sing'],
#  ['doodleworld',
#   'thx',
#   'had',
#   'a',
#   'great',
#   'day',
#   'amp',
#   'gon',
#   'na',
#   'have',
#   'a',
#   'long',
#   'weekend',
#   'excited',
#   'yet',
#   'ill',
#   'be',
#   'missin',
#   'my',
#   'tweeple',
#   'badly'],
#  ['this',
#   'one',
#   'brings',
#   'back',
#   'so',
#   'many',
#   'memory',
#   'michael',
#   'penn',
#   'quotthis',
#   'and',
#   'thatquot',
#   'httptwtfm',
#   'musicmonday'],
#  ['yes',
#   'i',
#   'do',
#   'i',
#   'know',
#   'a',
#   'place',
#   'that',
#   'ha',
#   'excellent',
#   'food'],
#  ['the',
#   'most',
#   'painful',
#   'sound',
#   'in',
#   'the',
#   'world',
#   'to',
#   'me',
#   'is',
#   'the',
#   'cry',
#   'of',
#   'someone',
#   'i',
#   'love',
#   'whats',
#   'worse',
#   'is',
#   'i',
#   'cant',
#   'even',
#   'hold',
#   'them',
#   'and',
#   'say',
#   'im',
#   'sorry'],
#  ['very', 'bad', 'thingsi', 'need', 'to', 'stop', 'thinking'],
#  ['im', 'grounded', 'tonight', 'i', 'hate', 'stupid', 'silent', 'mode'],
#  ['just',
#   'arrived',
#   'at',
#   'eurodjangocon',
#   'on',
#   'about',
#   'fellow',
#   'i',
#   'cant',
#   'see',
#   'a',
#   'girl'],
#  ['good', 'morning'],
#  ['we',
#   'are',
#   'repainting',
#   'room',
#   'in',
#   'my',
#   'house',
#   'my',
#   'mother',
#   'started',
#   'to',
#   'enact',
#   'plan',
#   'to',
#   'paint',
#   'my',
#   'room',
#   'without',
#   'consulting',
#   'me'],
#  ['night',
#   'night',
#   'everyone',
#   'happy',
#   'mother',
#   'day',
#   'to',
#   'all',
#   'mother'],
#  ['at',
#   'night',
#   'when',
#   'i',
#   'wa',
#   'coming',
#   'from',
#   'lingadzi',
#   'inn',
#   'i',
#   'heard',
#   'a',
#   'hyena',
#   'cry',
#   'in',
#   'the',
#   'lingadzi',
#   'jungle',
#   'i',
#   'wa',
#   'alone'],
#  ['goooooddd',
#   'morning',
#   'tweet',
#   'week',
#   'three',
#   'of',
#   'my',
#   'workout',
#   'did',
#   'i',
#   'mention',
#   'i',
#   'got',
#   'my',
#   'new',
#   'glass',
#   'yesterday'],
#  ['had', 'a', 'little', 'romantic', 'date', 'with', 'suzy', 'in', 'uptown'],
#  ['thank', 'you'],
#  ['maryrivss', 'hahaha', 'that', 'wa', 'funnyy'],
#  ['both',
#   'her',
#   'mother',
#   'and',
#   'lisa',
#   'had',
#   'been',
#   'cross',
#   'with',
#   'her',
#   'they',
#   'both',
#   'had',
#   'felt',
#   'she',
#   'ought',
#   'to',
#   'settle',
#   'down'],
#  ...]

# %%
word2vec = Word2Vec(sentences=X_train_token, size=60, min_count=10, window=10)

# %%
word2vec.wv.vocab
# Out:
# {'can': <gensim.models.keyedvectors.Vocab at 0x28abdb3dcc8>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x28abdb1fbc8>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x28abdb1f388>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x28abdb1f148>,
#  'cant': <gensim.models.keyedvectors.Vocab at 0x28abdb1fec8>,
#  'shopping': <gensim.models.keyedvectors.Vocab at 0x28abdb16c48>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x28abdb164c8>,
#  'yeah': <gensim.models.keyedvectors.Vocab at 0x28abdb16088>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x28abdb1fdc8>,
#  'haha': <gensim.models.keyedvectors.Vocab at 0x28abdb16b88>,
#  'rd': <gensim.models.keyedvectors.Vocab at 0x28abdb165c8>,
#  'episode': <gensim.models.keyedvectors.Vocab at 0x28abdb16688>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x28abdb16348>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x28abdb16608>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x28abdb16b48>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x28abdb16188>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x28abdb16f88>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x28abdb16808>,
#  'exactly': <gensim.models.keyedvectors.Vocab at 0x28abdb163c8>,
#  'hangin': <gensim.models.keyedvectors.Vocab at 0x28abdb16c88>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x28abdb18bc8>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x28abdb18588>,
#  'fam': <gensim.models.keyedvectors.Vocab at 0x28abdb18dc8>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x28abdb18348>,
#  'tommcfly': <gensim.models.keyedvectors.Vocab at 0x28abdb18448>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x28abdb18a08>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x28abdb18848>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x28abdb18188>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x28abdb18808>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x28abdb18e88>,
#  'amused': <gensim.models.keyedvectors.Vocab at 0x28abdb187c8>,
#  'loved': <gensim.models.keyedvectors.Vocab at 0x28abdb18508>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x28abdb18f08>,
#  'bought': <gensim.models.keyedvectors.Vocab at 0x28abdb18888>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x28abdb18548>,
#  'cream': <gensim.models.keyedvectors.Vocab at 0x28abdb18c08>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x28abdb18ec8>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x28abdb23588>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x28abdb23c88>,
#  'wa': <gensim.models.keyedvectors.Vocab at 0x28abdb23d88>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x28abdb23688>,
#  'sucked': <gensim.models.keyedvectors.Vocab at 0x28abdb23188>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x28abdb23908>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x28abdb23e88>,
#  'im': <gensim.models.keyedvectors.Vocab at 0x28abdb23288>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x28abdb23248>,
#  'yours': <gensim.models.keyedvectors.Vocab at 0x28abdb239c8>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x28abdb23dc8>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x28abdb23a48>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x28abdb23f88>,
#  'germany': <gensim.models.keyedvectors.Vocab at 0x28abdb23c48>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x28abdb23d48>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x28abdb23448>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x28abdb23088>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x28abdb23e08>,
#  'uk': <gensim.models.keyedvectors.Vocab at 0x28abdb23308>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x28abdb23408>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x28abdb237c8>,
#  'fucking': <gensim.models.keyedvectors.Vocab at 0x28abdb23348>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x28abdb238c8>,
#  'william': <gensim.models.keyedvectors.Vocab at 0x28abdb23048>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x28abdb23d08>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x28abdb23748>,
#  'wash': <gensim.models.keyedvectors.Vocab at 0x28abdb233c8>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x28abdb23788>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x28abdb23a88>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x28abdb23a08>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x28abdb27608>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x28abdb272c8>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x28abdb27148>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x28abdb27348>,
#  'filled': <gensim.models.keyedvectors.Vocab at 0x28abdb27408>,
#  'joy': <gensim.models.keyedvectors.Vocab at 0x28abdb27c88>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x28abdb27f88>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x28abdb27708>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x28abdb27948>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x28abdb27988>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x28abdb27cc8>,
#  'selected': <gensim.models.keyedvectors.Vocab at 0x28abdb27dc8>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x28abdb27188>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x28abdb271c8>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x28abdb27808>,
#  'college': <gensim.models.keyedvectors.Vocab at 0x28abdb276c8>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x28abdb27a08>,
#  'nursing': <gensim.models.keyedvectors.Vocab at 0x28abdb27d88>,
#  'booo': <gensim.models.keyedvectors.Vocab at 0x28abdb27ec8>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x28abdb27e48>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x28abdb27d48>,
#  'leavin': <gensim.models.keyedvectors.Vocab at 0x28abdb27308>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x28abdb279c8>,
#  'weekend': <gensim.models.keyedvectors.Vocab at 0x28abdb27548>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x28abdb274c8>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x28abd420688>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x28abdb121c8>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x28abdb12c48>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x28abdb12988>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x28abdb15488>,
#  'appointment': <gensim.models.keyedvectors.Vocab at 0x28abdb15208>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x28abdb15bc8>,
#  'coffee': <gensim.models.keyedvectors.Vocab at 0x28abdb15ac8>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x28abdb111c8>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x28abd525808>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x28ac2b642c8>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x28ac2b64ac8>,
#  'arrived': <gensim.models.keyedvectors.Vocab at 0x28ac2b64508>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x28abd3e2748>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x28abdb192c8>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x28abdb19dc8>,
#  'mine': <gensim.models.keyedvectors.Vocab at 0x28abdb19b48>,
#  'passed': <gensim.models.keyedvectors.Vocab at 0x28abdb19f08>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x28abdb19248>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x28abdb17808>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x28abdb17208>,
#  'sitting': <gensim.models.keyedvectors.Vocab at 0x28abdb17f88>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x28abdb176c8>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x28abdb17fc8>,
#  'lap': <gensim.models.keyedvectors.Vocab at 0x28abd3c98c8>,
#  'tried': <gensim.models.keyedvectors.Vocab at 0x28abdb0dc88>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x28abdb0de08>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x28abdb0df48>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x28abdb0ddc8>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x28abdb0dbc8>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x28abdb0dd48>,
#  'band': <gensim.models.keyedvectors.Vocab at 0x28abd442788>,
#  'radio': <gensim.models.keyedvectors.Vocab at 0x28abd442e48>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x28abd442348>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x28abdb0e448>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x28abdb0e308>,
#  'broken': <gensim.models.keyedvectors.Vocab at 0x28abdb0e208>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x28abdb0e408>,
#  'doe': <gensim.models.keyedvectors.Vocab at 0x28abdb0e488>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x28abdb0e8c8>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x28abdb0e508>,
#  'spare': <gensim.models.keyedvectors.Vocab at 0x28abdb0ec08>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x28abdb0e1c8>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x28abdb0e288>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x28abdb0e088>,
#  'tune': <gensim.models.keyedvectors.Vocab at 0x28abdb0e108>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x28abdb0e148>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x28abdb0e248>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x28abdb0e0c8>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x28abdb0e188>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x28abd444308>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x28abd444648>,
#  'realized': <gensim.models.keyedvectors.Vocab at 0x28abd444d48>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x28abd444d08>,
#  'approached': <gensim.models.keyedvectors.Vocab at 0x28abd3fa888>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x28ab4442188>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x28ab4444048>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x28abdb10e88>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x28abdb10348>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x28abdb10648>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x28abdb10688>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x28abdb101c8>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x28abdb106c8>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x28abdb10b08>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x28abdb10088>,
#  'lying': <gensim.models.keyedvectors.Vocab at 0x28abdb10d08>,
#  'terribly': <gensim.models.keyedvectors.Vocab at 0x28abdb10448>,
#  'informed': <gensim.models.keyedvectors.Vocab at 0x28abdb10248>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x28abdb10b48>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x28abdb27448>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x28abdb270c8>,
#  'attacked': <gensim.models.keyedvectors.Vocab at 0x28abdb27508>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x28abdb27a48>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x28abdb27ac8>,
#  'shoot': <gensim.models.keyedvectors.Vocab at 0x28abdb27288>,
#  'animal': <gensim.models.keyedvectors.Vocab at 0x28abdb27f08>,
#  'ha': <gensim.models.keyedvectors.Vocab at 0x28abdb27108>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x28abdb27748>,
#  'tattoo': <gensim.models.keyedvectors.Vocab at 0x28abdb275c8>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x28abdb27e88>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x28abdb27b08>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x28abdb27488>,
#  'choice': <gensim.models.keyedvectors.Vocab at 0x28abdb27b48>,
#  'anyone': <gensim.models.keyedvectors.Vocab at 0x28abdb27088>,
#  'asked': <gensim.models.keyedvectors.Vocab at 0x28abdb27208>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x28abdb27588>,
#  'wanted': <gensim.models.keyedvectors.Vocab at 0x28abdb27b88>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x28abdb27388>,
#  'handle': <gensim.models.keyedvectors.Vocab at 0x28abdb277c8>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x28abdb27bc8>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x28abdb27c08>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x28abdb27888>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x28abdb27788>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x28abdb278c8>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x28abdb27908>,
#  'favorite': <gensim.models.keyedvectors.Vocab at 0x28abdb27848>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x28abdb27fc8>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x28abdb27048>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x28abdb27a88>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x28abdb27c48>,
#  'lyric': <gensim.models.keyedvectors.Vocab at 0x28abdb27d08>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x28abdb27688>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x28abdb27f48>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x28abdb27e08>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x28abdb27648>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x28abdb21e88>,
#  'package': <gensim.models.keyedvectors.Vocab at 0x28abdb21988>,
#  'hahaha': <gensim.models.keyedvectors.Vocab at 0x28abdb21108>,
#  'ily': <gensim.models.keyedvectors.Vocab at 0x28abdb21ec8>,
#  'ashley': <gensim.models.keyedvectors.Vocab at 0x28abdb21e48>,
#  'ur': <gensim.models.keyedvectors.Vocab at 0x28abdb21488>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x28abdb21c48>,
#  'dentist': <gensim.models.keyedvectors.Vocab at 0x28abdb21f48>,
#  'scary': <gensim.models.keyedvectors.Vocab at 0x28abdb216c8>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x28abdb211c8>,
#  'myself': <gensim.models.keyedvectors.Vocab at 0x28abdb21308>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x28abdb21dc8>,
#  'girlfriend': <gensim.models.keyedvectors.Vocab at 0x28abdb21508>,
#  'hunting': <gensim.models.keyedvectors.Vocab at 0x28abdb21b48>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x28abdb21388>,
#  'slept': <gensim.models.keyedvectors.Vocab at 0x28abdb24608>,
#  'lonely': <gensim.models.keyedvectors.Vocab at 0x28abdb24ac8>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x28abdb241c8>,
#  'drunk': <gensim.models.keyedvectors.Vocab at 0x28abdb24848>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x28abdb24f48>,
#  'fell': <gensim.models.keyedvectors.Vocab at 0x28abdb24488>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x28abdb24388>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x28abdb24548>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x28abdb24588>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x28abdb24788>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x28abdb24b08>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x28abdb24d08>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x28abdb249c8>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x28abdb24088>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x28abdb240c8>,
#  'everybody': <gensim.models.keyedvectors.Vocab at 0x28abdb28048>,
#  'told': <gensim.models.keyedvectors.Vocab at 0x28abdb28088>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x28abdb280c8>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x28abdb28108>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x28abdb28148>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x28abdb28188>,
#  'situation': <gensim.models.keyedvectors.Vocab at 0x28abdb281c8>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x28abdb28208>,
#  'lt': <gensim.models.keyedvectors.Vocab at 0x28abdb28248>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x28abdb28288>,
#  'birthday': <gensim.models.keyedvectors.Vocab at 0x28abdb282c8>,
#  'whats': <gensim.models.keyedvectors.Vocab at 0x28abdb28308>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x28abdb28348>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x28abdb28388>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x28abdb283c8>,
#  'greeting': <gensim.models.keyedvectors.Vocab at 0x28abdb28408>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x28abdb28448>,
#  'stranger': <gensim.models.keyedvectors.Vocab at 0x28abdb28488>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x28abdb284c8>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x28abdb28508>,
#  'thats': <gensim.models.keyedvectors.Vocab at 0x28abdb28548>,
#  'kid': <gensim.models.keyedvectors.Vocab at 0x28abdb28588>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x28abdb285c8>,
#  'chapter': <gensim.models.keyedvectors.Vocab at 0x28abdb28608>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x28abdb28648>,
#  'mo': <gensim.models.keyedvectors.Vocab at 0x28abdb28688>,
#  'sunny': <gensim.models.keyedvectors.Vocab at 0x28abdb286c8>,
#  'tonight': <gensim.models.keyedvectors.Vocab at 0x28abdb28708>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x28abdb28748>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x28abdb28788>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x28abdb287c8>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x28abdb28808>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x28abdb28848>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x28abdb28888>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x28abdb288c8>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x28abdb28908>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x28abdb28948>,
#  'worked': <gensim.models.keyedvectors.Vocab at 0x28abdb28988>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x28abdb289c8>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x28abdb28a08>,
#  'preparing': <gensim.models.keyedvectors.Vocab at 0x28abdb28a48>,
#  'colleague': <gensim.models.keyedvectors.Vocab at 0x28abdb28a88>,
#  'decided': <gensim.models.keyedvectors.Vocab at 0x28abdb28ac8>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x28abdb28b08>,
#  'saturday': <gensim.models.keyedvectors.Vocab at 0x28abdb28b48>,
#  'inviting': <gensim.models.keyedvectors.Vocab at 0x28abdb28b88>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x28abdb28bc8>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x28abdb28c08>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x28abdb28c48>,
#  'nor': <gensim.models.keyedvectors.Vocab at 0x28abdb28c88>,
#  'omg': <gensim.models.keyedvectors.Vocab at 0x28abdb28cc8>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x28abdb28d08>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x28abdb28d48>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x28abdb28d88>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x28abdb28dc8>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x28abdb28e08>,
#  'gon': <gensim.models.keyedvectors.Vocab at 0x28abdb28e48>,
#  'na': <gensim.models.keyedvectors.Vocab at 0x28abdb28e88>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x28abdb28ec8>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x28abdb28f08>,
#  'bunch': <gensim.models.keyedvectors.Vocab at 0x28abdb28f48>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x28abdb28f88>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x28abdb28fc8>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x28abdb2b048>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x28abdb2b088>,
#  'ive': <gensim.models.keyedvectors.Vocab at 0x28abdb2b0c8>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x28abdb2b108>,
#  'saving': <gensim.models.keyedvectors.Vocab at 0x28abdb2b148>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x28abdb2b188>,
#  'walk': <gensim.models.keyedvectors.Vocab at 0x28abdb2b1c8>,
#  'enjoy': <gensim.models.keyedvectors.Vocab at 0x28abdb2b208>,
#  'scenery': <gensim.models.keyedvectors.Vocab at 0x28abdb2b248>,
#  'park': <gensim.models.keyedvectors.Vocab at 0x28abdb2b288>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x28abdb2b2c8>,
#  'hospitality': <gensim.models.keyedvectors.Vocab at 0x28abdb2b308>,
#  'nearby': <gensim.models.keyedvectors.Vocab at 0x28abdb2b348>,
#  'bank': <gensim.models.keyedvectors.Vocab at 0x28abdb2b388>,
#  '’': <gensim.models.keyedvectors.Vocab at 0x28abdb2b3c8>,
#  's': <gensim.models.keyedvectors.Vocab at 0x28abdb2b408>,
#  'fought': <gensim.models.keyedvectors.Vocab at 0x28abdb2b448>,
#  'britain': <gensim.models.keyedvectors.Vocab at 0x28abdb2b488>,
#  'forward': <gensim.models.keyedvectors.Vocab at 0x28abdb2b4c8>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x28abdb2b508>,
#  'dinner': <gensim.models.keyedvectors.Vocab at 0x28abdb2b548>,
#  'restaurant': <gensim.models.keyedvectors.Vocab at 0x28abdb2b588>,
#  'didnt': <gensim.models.keyedvectors.Vocab at 0x28abdb2b5c8>,
#  'hadnt': <gensim.models.keyedvectors.Vocab at 0x28abdb2b608>,
#  'parent': <gensim.models.keyedvectors.Vocab at 0x28abdb2b648>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x28abdb2b688>,
#  'visit': <gensim.models.keyedvectors.Vocab at 0x28abdb2b6c8>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x28abdb2b708>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x28abdb2b748>,
#  'expectation': <gensim.models.keyedvectors.Vocab at 0x28abdb2b788>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x28abdb2b7c8>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x28abdb2b808>,
#  'suck': <gensim.models.keyedvectors.Vocab at 0x28abdb2b848>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x28abdb2b888>,
#  'lovely': <gensim.models.keyedvectors.Vocab at 0x28abdb2b8c8>,
#  'currently': <gensim.models.keyedvectors.Vocab at 0x28abdb2b908>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x28abdb2b948>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x28abdb2b988>,
#  'regret': <gensim.models.keyedvectors.Vocab at 0x28abdb2b9c8>,
#  'tea': <gensim.models.keyedvectors.Vocab at 0x28abdb2ba08>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x28abdb2ba48>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x28abdb2ba88>,
#  'waiting': <gensim.models.keyedvectors.Vocab at 0x28abdb2bac8>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x28abdb2bb08>,
#  'nearly': <gensim.models.keyedvectors.Vocab at 0x28abdb2bb48>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x28abdb2bb88>,
#  'winter': <gensim.models.keyedvectors.Vocab at 0x28abdb2bbc8>,
#  'snow': <gensim.models.keyedvectors.Vocab at 0x28abdb2bc08>,
#  'telling': <gensim.models.keyedvectors.Vocab at 0x28abdb2bc48>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x28abdb2bc88>,
#  'treating': <gensim.models.keyedvectors.Vocab at 0x28abdb2bcc8>,
#  'brother': <gensim.models.keyedvectors.Vocab at 0x28abdb2bd08>,
#  'sister': <gensim.models.keyedvectors.Vocab at 0x28abdb2bd48>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x28abdb2bd88>,
#  'fan': <gensim.models.keyedvectors.Vocab at 0x28abdb2bdc8>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x28abdb2be08>,
#  'baby': <gensim.models.keyedvectors.Vocab at 0x28abdb2be48>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x28abdb2be88>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x28abdb2bec8>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x28abdb2bf08>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x28abdb2bf48>,
#  'recommendation': <gensim.models.keyedvectors.Vocab at 0x28abdb2bf88>,
#  'client': <gensim.models.keyedvectors.Vocab at 0x28abdb2bfc8>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x28abdb2d148>,
#  'willing': <gensim.models.keyedvectors.Vocab at 0x28abdb2d0c8>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x28abdb2d188>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x28abdb2d888>,
#  'xd': <gensim.models.keyedvectors.Vocab at 0x28abdb2d208>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x28abdb2d108>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x28abdb2d288>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x28abdb2d408>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x28abdb2d388>,
#  'wont': <gensim.models.keyedvectors.Vocab at 0x28abdb2d4c8>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x28abdb2d448>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x28abdb2d588>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x28abdb2d508>,
#  'sydney': <gensim.models.keyedvectors.Vocab at 0x28abdb2d648>,
#  'aswell': <gensim.models.keyedvectors.Vocab at 0x28abdb2d6c8>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x28abdb2d608>,
#  'pen': <gensim.models.keyedvectors.Vocab at 0x28abdb2d788>,
#  'blew': <gensim.models.keyedvectors.Vocab at 0x28abdb2d708>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x28abdb2d5c8>,
#  'everywhere': <gensim.models.keyedvectors.Vocab at 0x28abdb2d7c8>,
#  'walking': <gensim.models.keyedvectors.Vocab at 0x28abdb2d688>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x28abdb2d848>,
#  'dont': <gensim.models.keyedvectors.Vocab at 0x28abdb2d748>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x28abdb2d488>,
#  'hug': <gensim.models.keyedvectors.Vocab at 0x28abdb2d808>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x28abdb2d308>,
#  'wow': <gensim.models.keyedvectors.Vocab at 0x28abdb2d548>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x28abdb2d048>,
#  'living': <gensim.models.keyedvectors.Vocab at 0x28abdb2d3c8>,
#  'room': <gensim.models.keyedvectors.Vocab at 0x28abdb2d348>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x28abdb2d1c8>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x28abdb2d088>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x28abdb2d2c8>,
#  'stuff': <gensim.models.keyedvectors.Vocab at 0x28abdb2d908>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x28abdb2d248>,
#  'll': <gensim.models.keyedvectors.Vocab at 0x28abdb2d988>,
#  'rent': <gensim.models.keyedvectors.Vocab at 0x28abdb2d8c8>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x28abdb2da08>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x28abdb2d948>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x28abdb2da88>,
#  'journey': <gensim.models.keyedvectors.Vocab at 0x28abdb2dac8>,
#  'tomorrow': <gensim.models.keyedvectors.Vocab at 0x28abdb2dfc8>,
#  'bday': <gensim.models.keyedvectors.Vocab at 0x28abdb2db48>,
#  'mom': <gensim.models.keyedvectors.Vocab at 0x28abdb2dc48>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x28abdb2dbc8>,
#  'gift': <gensim.models.keyedvectors.Vocab at 0x28abdb2dd08>,
#  'bet': <gensim.models.keyedvectors.Vocab at 0x28abdb2dc88>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x28abdb2ddc8>,
#  'sorry': <gensim.models.keyedvectors.Vocab at 0x28abdb2dd48>,
#  'hurt': <gensim.models.keyedvectors.Vocab at 0x28abdb2de88>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x28abdb2de08>,
#  'party': <gensim.models.keyedvectors.Vocab at 0x28abdb2df48>,
#  'christmas': <gensim.models.keyedvectors.Vocab at 0x28abdb2dec8>,
#  'forget': <gensim.models.keyedvectors.Vocab at 0x28abdb2dcc8>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x28abdb2df88>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x28abdb2dd88>,
#  'amazing': <gensim.models.keyedvectors.Vocab at 0x28abdb2de48>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x28abdb2db88>,
#  'mentioned': <gensim.models.keyedvectors.Vocab at 0x28abdb2df08>,
#  'incredible': <gensim.models.keyedvectors.Vocab at 0x28abdb2da48>,
#  'caused': <gensim.models.keyedvectors.Vocab at 0x28abdb2dc08>,
#  'oh': <gensim.models.keyedvectors.Vocab at 0x28abdb2db08>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x28abdb2d9c8>,
#  'extra': <gensim.models.keyedvectors.Vocab at 0x28abdb32348>,
#  'cuz': <gensim.models.keyedvectors.Vocab at 0x28abdb32048>,
#  'missed': <gensim.models.keyedvectors.Vocab at 0x28abdb32108>,
#  'train': <gensim.models.keyedvectors.Vocab at 0x28abdb321c8>,
#  'minute': <gensim.models.keyedvectors.Vocab at 0x28abdb32088>,
#  'manage': <gensim.models.keyedvectors.Vocab at 0x28abdb32208>,
#  'con': <gensim.models.keyedvectors.Vocab at 0x28abdb322c8>,
#  'law': <gensim.models.keyedvectors.Vocab at 0x28abdb32148>,
#  'fighting': <gensim.models.keyedvectors.Vocab at 0x28abdb32248>,
#  'headache': <gensim.models.keyedvectors.Vocab at 0x28abdb32288>,
#  'amp': <gensim.models.keyedvectors.Vocab at 0x28abdb320c8>,
#  'paying': <gensim.models.keyedvectors.Vocab at 0x28abdb32308>,
#  'bill': <gensim.models.keyedvectors.Vocab at 0x28abdb323c8>,
#  'reply': <gensim.models.keyedvectors.Vocab at 0x28abdb32188>,
#  'ppl': <gensim.models.keyedvectors.Vocab at 0x28abdb32448>,
#  'hi': <gensim.models.keyedvectors.Vocab at 0x28abdb32388>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x28abdb324c8>,
#  'death': <gensim.models.keyedvectors.Vocab at 0x28abdb32408>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x28abdb32548>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x28abdb32488>,
#  'hasnt': <gensim.models.keyedvectors.Vocab at 0x28abdb325c8>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x28abdb32508>,
#  'via': <gensim.models.keyedvectors.Vocab at 0x28abdb32588>,
#  'dream': <gensim.models.keyedvectors.Vocab at 0x28abdb32688>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x28abdb32608>,
#  'thatd': <gensim.models.keyedvectors.Vocab at 0x28abdb32708>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x28abdb32648>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x28abdb32788>,
#  'vacation': <gensim.models.keyedvectors.Vocab at 0x28abdb327c8>,
#  'texas': <gensim.models.keyedvectors.Vocab at 0x28abdb32f88>,
#  'summer': <gensim.models.keyedvectors.Vocab at 0x28abdb32848>,
#  'unable': <gensim.models.keyedvectors.Vocab at 0x28abdb32948>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x28abdb328c8>,
#  'growing': <gensim.models.keyedvectors.Vocab at 0x28abdb32a08>,
#  'neck': <gensim.models.keyedvectors.Vocab at 0x28abdb32988>,
#  'ashamed': <gensim.models.keyedvectors.Vocab at 0x28abdb32ac8>,
#  'brought': <gensim.models.keyedvectors.Vocab at 0x28abdb32a48>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x28abdb32b88>,
#  'listening': <gensim.models.keyedvectors.Vocab at 0x28abdb32b08>,
#  'miley': <gensim.models.keyedvectors.Vocab at 0x28abdb32c48>,
#  'cyrus': <gensim.models.keyedvectors.Vocab at 0x28abdb32bc8>,
#  'cd': <gensim.models.keyedvectors.Vocab at 0x28abdb32d08>,
#  'hat': <gensim.models.keyedvectors.Vocab at 0x28abdb32c88>,
#  'wii': <gensim.models.keyedvectors.Vocab at 0x28abdb32dc8>,
#  'mary': <gensim.models.keyedvectors.Vocab at 0x28abdb32d48>,
#  'mr': <gensim.models.keyedvectors.Vocab at 0x28abdb32e88>,
#  'chinese': <gensim.models.keyedvectors.Vocab at 0x28abdb32e08>,
#  'listen': <gensim.models.keyedvectors.Vocab at 0x28abdb32cc8>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x28abdb32ec8>,
#  'repeat': <gensim.models.keyedvectors.Vocab at 0x28abdb32d88>,
#  'happened': <gensim.models.keyedvectors.Vocab at 0x28abdb32f48>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x28abdb32e48>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x28abdb32b48>,
#  'till': <gensim.models.keyedvectors.Vocab at 0x28abdb32f08>,
#  'gardening': <gensim.models.keyedvectors.Vocab at 0x28abdb329c8>,
#  'awesome': <gensim.models.keyedvectors.Vocab at 0x28abdb32c08>,
#  'luck': <gensim.models.keyedvectors.Vocab at 0x28abdb32888>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x28abdb32a88>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x28abdb32748>,
#  'bos': <gensim.models.keyedvectors.Vocab at 0x28abdb32908>,
#  'shes': <gensim.models.keyedvectors.Vocab at 0x28abdb32fc8>,
#  'moving': <gensim.models.keyedvectors.Vocab at 0x28abdb32808>,
#  'nyc': <gensim.models.keyedvectors.Vocab at 0x28abdb326c8>,
#  'youre': <gensim.models.keyedvectors.Vocab at 0x28abdb350c8>,
#  'lucky': <gensim.models.keyedvectors.Vocab at 0x28abdb35188>,
#  'raining': <gensim.models.keyedvectors.Vocab at 0x28abdb35248>,
#  'harder': <gensim.models.keyedvectors.Vocab at 0x28abdb357c8>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x28abdb35208>,
#  'bye': <gensim.models.keyedvectors.Vocab at 0x28abdb35108>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x28abdb35308>,
#  'thanks': <gensim.models.keyedvectors.Vocab at 0x28abdb35488>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x28abdb35408>,
#  'loving': <gensim.models.keyedvectors.Vocab at 0x28abdb35548>,
#  'energy': <gensim.models.keyedvectors.Vocab at 0x28abdb354c8>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x28abdb35608>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x28abdb35588>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x28abdb356c8>,
#  'imagine': <gensim.models.keyedvectors.Vocab at 0x28abdb35648>,
#  'boring': <gensim.models.keyedvectors.Vocab at 0x28abdb35508>,
#  'maria': <gensim.models.keyedvectors.Vocab at 0x28abdb35708>,
#  'admitted': <gensim.models.keyedvectors.Vocab at 0x28abdb355c8>,
#  'university': <gensim.models.keyedvectors.Vocab at 0x28abdb35788>,
#  'j': <gensim.models.keyedvectors.Vocab at 0x28abdb35688>,
#  'perfect': <gensim.models.keyedvectors.Vocab at 0x28abdb35348>,
#  'timing': <gensim.models.keyedvectors.Vocab at 0x28abdb35748>,
#  'message': <gensim.models.keyedvectors.Vocab at 0x28abdb35148>,
#  'ill': <gensim.models.keyedvectors.Vocab at 0x28abdb35448>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x28abdb353c8>,
#  'yall': <gensim.models.keyedvectors.Vocab at 0x28abdb351c8>,
#  'regard': <gensim.models.keyedvectors.Vocab at 0x28abdb35088>,
#  'wish': <gensim.models.keyedvectors.Vocab at 0x28abdb35048>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x28abdb35388>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x28abdb35288>,
#  'tourist': <gensim.models.keyedvectors.Vocab at 0x28abdb35848>,
#  'bigger': <gensim.models.keyedvectors.Vocab at 0x28abdb352c8>,
#  'imagined': <gensim.models.keyedvectors.Vocab at 0x28abdb358c8>,
#  'exciting': <gensim.models.keyedvectors.Vocab at 0x28abdb35808>,
#  'fry': <gensim.models.keyedvectors.Vocab at 0x28abdb35948>,
#  'meat': <gensim.models.keyedvectors.Vocab at 0x28abdb35888>,
#  'vegetable': <gensim.models.keyedvectors.Vocab at 0x28abdb359c8>,
#  'worst': <gensim.models.keyedvectors.Vocab at 0x28abdb35908>,
#  'insult': <gensim.models.keyedvectors.Vocab at 0x28abdb35a48>,
#  'throw': <gensim.models.keyedvectors.Vocab at 0x28abdb35988>,
#  'fried': <gensim.models.keyedvectors.Vocab at 0x28abdb35a08>,
#  'wrap': <gensim.models.keyedvectors.Vocab at 0x28abdb35b08>,
#  'trust': <gensim.models.keyedvectors.Vocab at 0x28abdb35a88>,
#  'necklace': <gensim.models.keyedvectors.Vocab at 0x28abdb35b88>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x28abdb35ac8>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x28abdb35c08>,
#  'public': <gensim.models.keyedvectors.Vocab at 0x28abdb35b48>,
#  'mtv': <gensim.models.keyedvectors.Vocab at 0x28abdb35c88>,
#  'award': <gensim.models.keyedvectors.Vocab at 0x28abdb35bc8>,
#  'vote': <gensim.models.keyedvectors.Vocab at 0x28abdb35c48>,
#  'rain': <gensim.models.keyedvectors.Vocab at 0x28abdb35d48>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x28abdb35cc8>,
#  'gone': <gensim.models.keyedvectors.Vocab at 0x28abdb35dc8>,
#  'lie': <gensim.models.keyedvectors.Vocab at 0x28abdb35d08>,
#  'crazy': <gensim.models.keyedvectors.Vocab at 0x28abdb35e48>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x28abdb35d88>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x28abdb35ec8>,
#  'giant': <gensim.models.keyedvectors.Vocab at 0x28abdb35f08>,
#  'stupid': <gensim.models.keyedvectors.Vocab at 0x28abdb35f88>,
#  'machine': <gensim.models.keyedvectors.Vocab at 0x28abdb35e08>,
#  'doing': <gensim.models.keyedvectors.Vocab at 0x28abdb35e88>,
#  'podcast': <gensim.models.keyedvectors.Vocab at 0x28abdb35f48>,
#  'accepted': <gensim.models.keyedvectors.Vocab at 0x28abdb35fc8>,
#  'itunes': <gensim.models.keyedvectors.Vocab at 0x28abdb39048>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x28abdb39148>,
#  'fixed': <gensim.models.keyedvectors.Vocab at 0x28abdb39208>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x28abdb39548>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x28abdb39288>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x28abdb39088>,
#  'david': <gensim.models.keyedvectors.Vocab at 0x28abdb39248>,
#  'delight': <gensim.models.keyedvectors.Vocab at 0x28abdb39408>,
#  'sleepy': <gensim.models.keyedvectors.Vocab at 0x28abdb39388>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x28abdb394c8>,
#  'fail': <gensim.models.keyedvectors.Vocab at 0x28abdb39448>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x28abdb39588>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x28abdb39508>,
#  'spring': <gensim.models.keyedvectors.Vocab at 0x28abdb39648>,
#  'fresh': <gensim.models.keyedvectors.Vocab at 0x28abdb395c8>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x28abdb39708>,
#  'dreamed': <gensim.models.keyedvectors.Vocab at 0x28abdb39688>,
#  'thousand': <gensim.models.keyedvectors.Vocab at 0x28abdb397c8>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x28abdb392c8>,
#  'relax': <gensim.models.keyedvectors.Vocab at 0x28abdb39488>,
#  'somebody': <gensim.models.keyedvectors.Vocab at 0x28abdb391c8>,
#  'server': <gensim.models.keyedvectors.Vocab at 0x28abdb393c8>,
#  'window': <gensim.models.keyedvectors.Vocab at 0x28abdb39308>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x28abdb390c8>,
#  'w': <gensim.models.keyedvectors.Vocab at 0x28abdb39108>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x28abdb39348>,
#  'fun': <gensim.models.keyedvectors.Vocab at 0x28abdb396c8>,
#  'poem': <gensim.models.keyedvectors.Vocab at 0x28abdb39748>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x28abdb39808>,
#  'write': <gensim.models.keyedvectors.Vocab at 0x28abdb39908>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x28abdb39888>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x28abdb399c8>,
#  'song': <gensim.models.keyedvectors.Vocab at 0x28abdb39948>,
#  'noticed': <gensim.models.keyedvectors.Vocab at 0x28abdb39a88>,
#  'obvious': <gensim.models.keyedvectors.Vocab at 0x28abdb39a08>,
#  'mark': <gensim.models.keyedvectors.Vocab at 0x28abdb39b48>,
#  'negative': <gensim.models.keyedvectors.Vocab at 0x28abdb39ac8>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x28abdb39c08>,
#  'relative': <gensim.models.keyedvectors.Vocab at 0x28abdb39b88>,
#  'icecream': <gensim.models.keyedvectors.Vocab at 0x28abdb39cc8>,
#  'truck': <gensim.models.keyedvectors.Vocab at 0x28abdb39c48>,
#  'took': <gensim.models.keyedvectors.Vocab at 0x28abdb39d88>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x28abdb39d08>,
#  'couldnt': <gensim.models.keyedvectors.Vocab at 0x28abdb39e48>,
#  'catch': <gensim.models.keyedvectors.Vocab at 0x28abdb39dc8>,
#  'cal': <gensim.models.keyedvectors.Vocab at 0x28abdb39f08>,
#  'knowing': <gensim.models.keyedvectors.Vocab at 0x28abdb39e88>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x28abdb39ec8>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x28abdb39f88>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x28abdb39b08>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x28abdb39c88>,
#  'tweet': <gensim.models.keyedvectors.Vocab at 0x28abdb398c8>,
#  'verizon': <gensim.models.keyedvectors.Vocab at 0x28abdb39a48>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x28abdb39608>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x28abdb39848>,
#  'woman': <gensim.models.keyedvectors.Vocab at 0x28abdb39fc8>,
#  'younger': <gensim.models.keyedvectors.Vocab at 0x28abdb39188>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x28abdb39bc8>,
#  'particularly': <gensim.models.keyedvectors.Vocab at 0x28abdb39988>,
#  'figure': <gensim.models.keyedvectors.Vocab at 0x28abdb39788>,
#  'monday': <gensim.models.keyedvectors.Vocab at 0x28abdb39f48>,
#  'canada': <gensim.models.keyedvectors.Vocab at 0x28abdb39e08>,
#  'pride': <gensim.models.keyedvectors.Vocab at 0x28abdb39d48>,
#  'irish': <gensim.models.keyedvectors.Vocab at 0x28abdb3c388>,
#  'dying': <gensim.models.keyedvectors.Vocab at 0x28abdb3c048>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x28abdb3c108>,
#  'winner': <gensim.models.keyedvectors.Vocab at 0x28abdb3c1c8>,
#  'upset': <gensim.models.keyedvectors.Vocab at 0x28abdb3c288>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x28abdb3c348>,
#  'smile': <gensim.models.keyedvectors.Vocab at 0x28abdb3c408>,
#  'inside': <gensim.models.keyedvectors.Vocab at 0x28abdb3c208>,
#  'hate': <gensim.models.keyedvectors.Vocab at 0x28abdb3c2c8>,
#  'sick': <gensim.models.keyedvectors.Vocab at 0x28abdb3c148>,
#  'watching': <gensim.models.keyedvectors.Vocab at 0x28abdb3c548>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x28abdb3c088>,
#  'cross': <gensim.models.keyedvectors.Vocab at 0x28abdb3c488>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x28abdb3c248>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x28abdb3c3c8>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x28abdb3c0c8>,
#  'recently': <gensim.models.keyedvectors.Vocab at 0x28abdb3c308>,
#  'weather': <gensim.models.keyedvectors.Vocab at 0x28abdb3c4c8>,
#  'male': <gensim.models.keyedvectors.Vocab at 0x28abdb3c188>,
#  'classmate': <gensim.models.keyedvectors.Vocab at 0x28abdb3c588>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x28abdb3c448>,
#  'table': <gensim.models.keyedvectors.Vocab at 0x28abdb3c608>,
#  'scared': <gensim.models.keyedvectors.Vocab at 0x28abdb3c508>,
#  'lol': <gensim.models.keyedvectors.Vocab at 0x28abdb3c688>,
#  'anyway': <gensim.models.keyedvectors.Vocab at 0x28abdb3c6c8>,
#  'view': <gensim.models.keyedvectors.Vocab at 0x28abdb3cc88>,
#  'leaving': <gensim.models.keyedvectors.Vocab at 0x28abdb3c748>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x28abdb3c848>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x28abdb3c7c8>,
#  'united': <gensim.models.keyedvectors.Vocab at 0x28abdb3c908>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x28abdb3c888>,
#  'ouch': <gensim.models.keyedvectors.Vocab at 0x28abdb3c9c8>,
#  'yard': <gensim.models.keyedvectors.Vocab at 0x28abdb3c948>,
#  'football': <gensim.models.keyedvectors.Vocab at 0x28abdb3ca88>,
#  'cousin': <gensim.models.keyedvectors.Vocab at 0x28abdb3ca08>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x28abdb3cb48>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x28abdb3cac8>,
#  'ball': <gensim.models.keyedvectors.Vocab at 0x28abdb3cc08>,
#  'putting': <gensim.models.keyedvectors.Vocab at 0x28abdb3cb88>,
#  'killing': <gensim.models.keyedvectors.Vocab at 0x28abdb3ccc8>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x28abdb3cc48>,
#  'yay': <gensim.models.keyedvectors.Vocab at 0x28abdb3cd88>,
#  'eating': <gensim.models.keyedvectors.Vocab at 0x28abdb3cd08>,
#  'spend': <gensim.models.keyedvectors.Vocab at 0x28abdb3ce48>,
#  'rest': <gensim.models.keyedvectors.Vocab at 0x28abdb3cdc8>,
#  'evening': <gensim.models.keyedvectors.Vocab at 0x28abdb3cf08>,
#  'code': <gensim.models.keyedvectors.Vocab at 0x28abdb3ca48>,
#  'jim': <gensim.models.keyedvectors.Vocab at 0x28abdb3cbc8>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x28abdb3c8c8>,
#  'anxious': <gensim.models.keyedvectors.Vocab at 0x28abdb3cb08>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x28abdb3c788>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x28abdb3c988>,
#  'miffed': <gensim.models.keyedvectors.Vocab at 0x28abdb3c648>,
#  'tough': <gensim.models.keyedvectors.Vocab at 0x28abdb3c808>,
#  'argue': <gensim.models.keyedvectors.Vocab at 0x28abdb3cd48>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x28abdb3c708>,
#  'included': <gensim.models.keyedvectors.Vocab at 0x28abdb3ce88>,
#  'grandmother': <gensim.models.keyedvectors.Vocab at 0x28abdb3c5c8>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x28abdb3cf48>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x28abdb3ce08>,
#  'suffer': <gensim.models.keyedvectors.Vocab at 0x28abdb3cfc8>,
#  'wouldnt': <gensim.models.keyedvectors.Vocab at 0x28abdb3cec8>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x28abdb3cf88>,
#  'awww': <gensim.models.keyedvectors.Vocab at 0x28abdc91048>,
#  'remind': <gensim.models.keyedvectors.Vocab at 0x28abdc91088>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x28abdc910c8>,
#  'complete': <gensim.models.keyedvectors.Vocab at 0x28abdc91108>,
#  'attended': <gensim.models.keyedvectors.Vocab at 0x28abdc91148>,
#  'event': <gensim.models.keyedvectors.Vocab at 0x28abdc91188>,
#  'anger': <gensim.models.keyedvectors.Vocab at 0x28abdc911c8>,
#  'afraid': <gensim.models.keyedvectors.Vocab at 0x28abdc91208>,
#  'business': <gensim.models.keyedvectors.Vocab at 0x28abdc91248>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x28abdc91288>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x28abdc912c8>,
#  'weird': <gensim.models.keyedvectors.Vocab at 0x28abdc91308>,
#  'traveling': <gensim.models.keyedvectors.Vocab at 0x28abdc91348>,
#  'beijing': <gensim.models.keyedvectors.Vocab at 0x28abdc91388>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x28abdc913c8>,
#  'difference': <gensim.models.keyedvectors.Vocab at 0x28abdc91408>,
#  'noon': <gensim.models.keyedvectors.Vocab at 0x28abdc91448>,
#  'eight': <gensim.models.keyedvectors.Vocab at 0x28abdc91488>,
#  'appreciate': <gensim.models.keyedvectors.Vocab at 0x28abdc914c8>,
#  'glass': <gensim.models.keyedvectors.Vocab at 0x28abdc91508>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x28abdc91548>,
#  'wine': <gensim.models.keyedvectors.Vocab at 0x28abdc91588>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x28abdc915c8>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x28abdc91608>,
#  'seven': <gensim.models.keyedvectors.Vocab at 0x28abdc91648>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x28abdc91688>,
#  'transport': <gensim.models.keyedvectors.Vocab at 0x28abdc916c8>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x28abdc91708>,
#  'study': <gensim.models.keyedvectors.Vocab at 0x28abdc91748>,
#  'unza': <gensim.models.keyedvectors.Vocab at 0x28abdc91788>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x28abdc917c8>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x28abdc91808>,
#  'xx': <gensim.models.keyedvectors.Vocab at 0x28abdc91848>,
#  'p': <gensim.models.keyedvectors.Vocab at 0x28abdc91888>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x28abdc918c8>,
#  'foot': <gensim.models.keyedvectors.Vocab at 0x28abdc91908>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x28abdc91948>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x28abdc91988>,
#  'awake': <gensim.models.keyedvectors.Vocab at 0x28abdc919c8>,
#  'dad': <gensim.models.keyedvectors.Vocab at 0x28abdc91a08>,
#  'id': <gensim.models.keyedvectors.Vocab at 0x28abdc91a48>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x28abdc91a88>,
#  'prom': <gensim.models.keyedvectors.Vocab at 0x28abdc91ac8>,
#  'suggestion': <gensim.models.keyedvectors.Vocab at 0x28abdc91b08>,
#  'rid': <gensim.models.keyedvectors.Vocab at 0x28abdc91b48>,
#  'smell': <gensim.models.keyedvectors.Vocab at 0x28abdc91b88>,
#  'car': <gensim.models.keyedvectors.Vocab at 0x28abdc91bc8>,
#  'theyre': <gensim.models.keyedvectors.Vocab at 0x28abdc91c08>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x28abdc91c48>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x28abdc91c88>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x28abdc91cc8>,
#  'doesnt': <gensim.models.keyedvectors.Vocab at 0x28abdc91d08>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x28abdc91d48>,
#  'lady': <gensim.models.keyedvectors.Vocab at 0x28abdc91d88>,
#  'planning': <gensim.models.keyedvectors.Vocab at 0x28abdc91dc8>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x28abdc91e08>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x28abdc91e48>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x28abdc91e88>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x28abdc91ec8>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x28abdc91f08>,
#  'tired': <gensim.models.keyedvectors.Vocab at 0x28abdc91f48>,
#  'chick': <gensim.models.keyedvectors.Vocab at 0x28abdc91f88>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x28abdc91fc8>,
#  'count': <gensim.models.keyedvectors.Vocab at 0x28abdc94048>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x28abdc94088>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x28abdc940c8>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x28abdc94108>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x28abdc94148>,
#  'wood': <gensim.models.keyedvectors.Vocab at 0x28abdc94188>,
#  're': <gensim.models.keyedvectors.Vocab at 0x28abdc941c8>,
#  'damage': <gensim.models.keyedvectors.Vocab at 0x28abdc94208>,
#  'forest': <gensim.models.keyedvectors.Vocab at 0x28abdc94248>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x28abdc94288>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x28abdc942c8>,
#  'natural': <gensim.models.keyedvectors.Vocab at 0x28abdc94308>,
#  'plant': <gensim.models.keyedvectors.Vocab at 0x28abdc94348>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x28abdc94388>,
#  't': <gensim.models.keyedvectors.Vocab at 0x28abdc943c8>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x28abdc94408>,
#  'wouldn': <gensim.models.keyedvectors.Vocab at 0x28abdc94448>,
#  'subject': <gensim.models.keyedvectors.Vocab at 0x28abdc94488>,
#  'experiment': <gensim.models.keyedvectors.Vocab at 0x28abdc944c8>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x28abdc94508>,
#  'dry': <gensim.models.keyedvectors.Vocab at 0x28abdc94548>,
#  'lately': <gensim.models.keyedvectors.Vocab at 0x28abdc94588>,
#  'mmm': <gensim.models.keyedvectors.Vocab at 0x28abdc945c8>,
#  'flight': <gensim.models.keyedvectors.Vocab at 0x28abdc94608>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x28abdc94648>,
#  'surprised': <gensim.models.keyedvectors.Vocab at 0x28abdc94688>,
#  'exhausted': <gensim.models.keyedvectors.Vocab at 0x28abdc946c8>,
#  'suffered': <gensim.models.keyedvectors.Vocab at 0x28abdc94708>,
#  'terrible': <gensim.models.keyedvectors.Vocab at 0x28abdc94748>,
#  'fit': <gensim.models.keyedvectors.Vocab at 0x28abdc94788>,
#  'frequently': <gensim.models.keyedvectors.Vocab at 0x28abdc947c8>,
#  'eat': <gensim.models.keyedvectors.Vocab at 0x28abdc94808>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x28abdc94848>,
#  'act': <gensim.models.keyedvectors.Vocab at 0x28abdc94888>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x28abdc948c8>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x28abdc94908>,
#  'sometimes': <gensim.models.keyedvectors.Vocab at 0x28abdc94948>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x28abdc94988>,
#  'spicy': <gensim.models.keyedvectors.Vocab at 0x28abdc949c8>,
#  'sauce': <gensim.models.keyedvectors.Vocab at 0x28abdc94a08>,
#  'rice': <gensim.models.keyedvectors.Vocab at 0x28abdc94a48>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x28abdc94a88>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x28abdc94ac8>,
#  'google': <gensim.models.keyedvectors.Vocab at 0x28abdc94b08>,
#  'apple': <gensim.models.keyedvectors.Vocab at 0x28abdc94b48>,
#  'image': <gensim.models.keyedvectors.Vocab at 0x28abdc94b88>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x28abdc94bc8>,
#  'tongue': <gensim.models.keyedvectors.Vocab at 0x28abdc94c08>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x28abdc94c48>,
#  'proud': <gensim.models.keyedvectors.Vocab at 0x28abdc94c88>,
#  'o': <gensim.models.keyedvectors.Vocab at 0x28abdc94cc8>,
#  'editing': <gensim.models.keyedvectors.Vocab at 0x28abdc94d08>,
#  'pc': <gensim.models.keyedvectors.Vocab at 0x28abdc94d48>,
#  'behind': <gensim.models.keyedvectors.Vocab at 0x28abdc94d88>,
#  'impressed': <gensim.models.keyedvectors.Vocab at 0x28abdc94dc8>,
#  'permission': <gensim.models.keyedvectors.Vocab at 0x28abdc94e08>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x28abdc94e48>,
#  'popcorn': <gensim.models.keyedvectors.Vocab at 0x28abdc94e88>,
#  'consequence': <gensim.models.keyedvectors.Vocab at 0x28abdc94ec8>,
#  'kitchen': <gensim.models.keyedvectors.Vocab at 0x28abdc94f08>,
#  'comment': <gensim.models.keyedvectors.Vocab at 0x28abdc94f48>,
#  'album': <gensim.models.keyedvectors.Vocab at 0x28abdc94f88>,
#  'trip': <gensim.models.keyedvectors.Vocab at 0x28abdc94fc8>,
#  'van': <gensim.models.keyedvectors.Vocab at 0x28abdc98048>,
#  'incident': <gensim.models.keyedvectors.Vocab at 0x28abdc98088>,
#  'stopped': <gensim.models.keyedvectors.Vocab at 0x28abdc980c8>,
#  'fill': <gensim.models.keyedvectors.Vocab at 0x28abdc98108>,
#  'gas': <gensim.models.keyedvectors.Vocab at 0x28abdc98148>,
#  'pole': <gensim.models.keyedvectors.Vocab at 0x28abdc98188>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x28abdc981c8>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x28abdc98208>,
#  'fav': <gensim.models.keyedvectors.Vocab at 0x28abdc98248>,
#  'nap': <gensim.models.keyedvectors.Vocab at 0x28abdc98288>,
#  'frustrated': <gensim.models.keyedvectors.Vocab at 0x28abdc982c8>,
#  'playing': <gensim.models.keyedvectors.Vocab at 0x28abdc98308>,
#  'babe': <gensim.models.keyedvectors.Vocab at 0x28abdc98348>,
#  'apartment': <gensim.models.keyedvectors.Vocab at 0x28abdc98388>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x28abdc983c8>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x28abdc98408>,
#  'glad': <gensim.models.keyedvectors.Vocab at 0x28abdc98448>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x28abdc98488>,
#  'dick': <gensim.models.keyedvectors.Vocab at 0x28abdc984c8>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x28abdc98508>,
#  'cold': <gensim.models.keyedvectors.Vocab at 0x28abdc98548>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x28abdc98588>,
#  'wallet': <gensim.models.keyedvectors.Vocab at 0x28abdc985c8>,
#  'pic': <gensim.models.keyedvectors.Vocab at 0x28abdc98608>,
#  'twitter': <gensim.models.keyedvectors.Vocab at 0x28abdc98648>,
#  'finally': <gensim.models.keyedvectors.Vocab at 0x28abdc98688>,
#  'letting': <gensim.models.keyedvectors.Vocab at 0x28abdc986c8>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x28abdc98708>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x28abdc98748>,
#  'received': <gensim.models.keyedvectors.Vocab at 0x28abdc98788>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x28abdc987c8>,
#  'apart': <gensim.models.keyedvectors.Vocab at 0x28abdc98808>,
#  'tie': <gensim.models.keyedvectors.Vocab at 0x28abdc98848>,
#  'singing': <gensim.models.keyedvectors.Vocab at 0x28abdc98888>,
#  'pleased': <gensim.models.keyedvectors.Vocab at 0x28abdc988c8>,
#  'bummed': <gensim.models.keyedvectors.Vocab at 0x28abdc98908>,
#  'manchester': <gensim.models.keyedvectors.Vocab at 0x28abdc98948>,
#  'bc': <gensim.models.keyedvectors.Vocab at 0x28abdc98988>,
#  'sold': <gensim.models.keyedvectors.Vocab at 0x28abdc989c8>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x28abdc98a08>,
#  'buying': <gensim.models.keyedvectors.Vocab at 0x28abdc98a48>,
#  'tv': <gensim.models.keyedvectors.Vocab at 0x28abdc98a88>,
#  'lame': <gensim.models.keyedvectors.Vocab at 0x28abdc98ac8>,
#  'msn': <gensim.models.keyedvectors.Vocab at 0x28abdc98b08>,
#  'none': <gensim.models.keyedvectors.Vocab at 0x28abdc98b48>,
#  'ended': <gensim.models.keyedvectors.Vocab at 0x28abdc98b88>,
#  'selling': <gensim.models.keyedvectors.Vocab at 0x28abdc98bc8>,
#  'mac': <gensim.models.keyedvectors.Vocab at 0x28abdc98c08>,
#  'bah': <gensim.models.keyedvectors.Vocab at 0x28abdc98c48>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x28abdc98c88>,
#  'wheel': <gensim.models.keyedvectors.Vocab at 0x28abdc98cc8>,
#  'charge': <gensim.models.keyedvectors.Vocab at 0x28abdc98d08>,
#  'print': <gensim.models.keyedvectors.Vocab at 0x28abdc98d48>,
#  'starting': <gensim.models.keyedvectors.Vocab at 0x28abdc98d88>,
#  'happens': <gensim.models.keyedvectors.Vocab at 0x28abdc98dc8>,
#  'losing': <gensim.models.keyedvectors.Vocab at 0x28abdc98e08>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x28abdc98e48>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x28abdc98e88>,
#  'sunday': <gensim.models.keyedvectors.Vocab at 0x28abdc98ec8>,
#  'update': <gensim.models.keyedvectors.Vocab at 0x28abdc98f08>,
#  'doctor': <gensim.models.keyedvectors.Vocab at 0x28abdc98f48>,
#  'wan': <gensim.models.keyedvectors.Vocab at 0x28abdc98f88>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x28abdc98fc8>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x28abdc9b048>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x28abdc9b088>,
#  'careful': <gensim.models.keyedvectors.Vocab at 0x28abdc9b0c8>,
#  'managed': <gensim.models.keyedvectors.Vocab at 0x28abdc9b108>,
#  'page': <gensim.models.keyedvectors.Vocab at 0x28abdc9b148>,
#  'unfortunately': <gensim.models.keyedvectors.Vocab at 0x28abdc9b188>,
#  'totally': <gensim.models.keyedvectors.Vocab at 0x28abdc9b1c8>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x28abdc9b208>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x28abdc9b248>,
#  'feature': <gensim.models.keyedvectors.Vocab at 0x28abdc9b288>,
#  'slightly': <gensim.models.keyedvectors.Vocab at 0x28abdc9b2c8>,
#  'ma': <gensim.models.keyedvectors.Vocab at 0x28abdc9b308>,
#  'voice': <gensim.models.keyedvectors.Vocab at 0x28abdc9b348>,
#  'slowly': <gensim.models.keyedvectors.Vocab at 0x28abdc9b388>,
#  'pink': <gensim.models.keyedvectors.Vocab at 0x28abdc9b3c8>,
#  'despondent': <gensim.models.keyedvectors.Vocab at 0x28abdc9b408>,
#  'favourite': <gensim.models.keyedvectors.Vocab at 0x28abdc9b448>,
#  'horse': <gensim.models.keyedvectors.Vocab at 0x28abdc9b488>,
#  'died': <gensim.models.keyedvectors.Vocab at 0x28abdc9b4c8>,
#  'save': <gensim.models.keyedvectors.Vocab at 0x28abdc9b508>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x28abdc9b548>,
#  'fashion': <gensim.models.keyedvectors.Vocab at 0x28abdc9b588>,
#  'north': <gensim.models.keyedvectors.Vocab at 0x28abdc9b5c8>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x28abdc9b608>,
#  'arent': <gensim.models.keyedvectors.Vocab at 0x28abdc9b648>,
#  'til': <gensim.models.keyedvectors.Vocab at 0x28abdc9b688>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x28abdc9b6c8>,
#  'uploading': <gensim.models.keyedvectors.Vocab at 0x28abdc9b708>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x28abdc9b748>,
#  'youtube': <gensim.models.keyedvectors.Vocab at 0x28abdc9b788>,
#  'link': <gensim.models.keyedvectors.Vocab at 0x28abdc9b7c8>,
#  'daily': <gensim.models.keyedvectors.Vocab at 0x28abdc9b808>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x28abdc9b848>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x28abdc9b888>,
#  'excellent': <gensim.models.keyedvectors.Vocab at 0x28abdc9b8c8>,
#  'singer': <gensim.models.keyedvectors.Vocab at 0x28abdc9b908>,
#  'sing': <gensim.models.keyedvectors.Vocab at 0x28abdc9b948>,
#  'bass': <gensim.models.keyedvectors.Vocab at 0x28abdc9b988>,
#  'slight': <gensim.models.keyedvectors.Vocab at 0x28abdc9b9c8>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x28abdc9ba08>,
#  'hangover': <gensim.models.keyedvectors.Vocab at 0x28abdc9ba48>,
#  'grrr': <gensim.models.keyedvectors.Vocab at 0x28abdc9ba88>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x28abdc9bac8>,
#  'attractive': <gensim.models.keyedvectors.Vocab at 0x28abdc9bb08>,
#  'colorful': <gensim.models.keyedvectors.Vocab at 0x28abdc9bb48>,
#  'scene': <gensim.models.keyedvectors.Vocab at 0x28abdc9bb88>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x28abdc9bbc8>,
#  'paul': <gensim.models.keyedvectors.Vocab at 0x28abdc9bc08>,
#  'someday': <gensim.models.keyedvectors.Vocab at 0x28abdc9bc48>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x28abdc9bc88>,
#  'jane': <gensim.models.keyedvectors.Vocab at 0x28abdc9bcc8>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x28abdc9bd08>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x28abdc9bd48>,
#  'aww': <gensim.models.keyedvectors.Vocab at 0x28abdc9bd88>,
#  'ticket': <gensim.models.keyedvectors.Vocab at 0x28abdc9bdc8>,
#  'tho': <gensim.models.keyedvectors.Vocab at 0x28abdc9be08>,
#  'xxx': <gensim.models.keyedvectors.Vocab at 0x28abdc9be48>,
#  'finger': <gensim.models.keyedvectors.Vocab at 0x28abdc9be88>,
#  'crossed': <gensim.models.keyedvectors.Vocab at 0x28abdc9bec8>,
#  'neighbor': <gensim.models.keyedvectors.Vocab at 0x28abdc9bf08>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x28abdc9bf48>,
#  'ups': <gensim.models.keyedvectors.Vocab at 0x28abdc9bf88>,
#  'otherwise': <gensim.models.keyedvectors.Vocab at 0x28abdc9bfc8>,
#  'byebye': <gensim.models.keyedvectors.Vocab at 0x28abdc9f048>,
#  'skirt': <gensim.models.keyedvectors.Vocab at 0x28abdc9f088>,
#  'london': <gensim.models.keyedvectors.Vocab at 0x28abdc9f0c8>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x28abdc9f108>,
#  'miserable': <gensim.models.keyedvectors.Vocab at 0x28abdc9f148>,
#  'lawn': <gensim.models.keyedvectors.Vocab at 0x28abdc9f188>,
#  'conversation': <gensim.models.keyedvectors.Vocab at 0x28abdc9f1c8>,
#  'meal': <gensim.models.keyedvectors.Vocab at 0x28abdc9f208>,
#  'license': <gensim.models.keyedvectors.Vocab at 0x28abdc9f248>,
#  'beach': <gensim.models.keyedvectors.Vocab at 0x28abdc9f288>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x28abdc9f2c8>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x28abdc9f308>,
#  'hehe': <gensim.models.keyedvectors.Vocab at 0x28abdc9f348>,
#  'joining': <gensim.models.keyedvectors.Vocab at 0x28abdc9f388>,
#  'picture': <gensim.models.keyedvectors.Vocab at 0x28abdc9f3c8>,
#  'chocolate': <gensim.models.keyedvectors.Vocab at 0x28abdc9f408>,
#  'excitement': <gensim.models.keyedvectors.Vocab at 0x28abdc9f448>,
#  'eye': <gensim.models.keyedvectors.Vocab at 0x28abdc9f488>,
#  'showed': <gensim.models.keyedvectors.Vocab at 0x28abdc9f4c8>,
#  'president': <gensim.models.keyedvectors.Vocab at 0x28abdc9f508>,
#  'satisfied': <gensim.models.keyedvectors.Vocab at 0x28abdc9f548>,
#  'anymore': <gensim.models.keyedvectors.Vocab at 0x28abdc9f588>,
#  'grace': <gensim.models.keyedvectors.Vocab at 0x28abdc9f5c8>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x28abdc9f608>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x28abdc9f648>,
#  'dan': <gensim.models.keyedvectors.Vocab at 0x28abdc9f688>,
#  'won': <gensim.models.keyedvectors.Vocab at 0x28abdc9f6c8>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x28abdc9f708>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x28abdc9f748>,
#  'cafe': <gensim.models.keyedvectors.Vocab at 0x28abdc9f788>,
#  'goin': <gensim.models.keyedvectors.Vocab at 0x28abdc9f7c8>,
#  'knocked': <gensim.models.keyedvectors.Vocab at 0x28abdc9f808>,
#  'newspaper': <gensim.models.keyedvectors.Vocab at 0x28abdc9f848>,
#  'susan': <gensim.models.keyedvectors.Vocab at 0x28abdc9f888>,
#  'surely': <gensim.models.keyedvectors.Vocab at 0x28abdc9f8c8>,
#  'bike': <gensim.models.keyedvectors.Vocab at 0x28abdc9f908>,
#  'degree': <gensim.models.keyedvectors.Vocab at 0x28abdc9f948>,
#  'fever': <gensim.models.keyedvectors.Vocab at 0x28abdc9f988>,
#  'cheer': <gensim.models.keyedvectors.Vocab at 0x28abdc9f9c8>,
#  'photo': <gensim.models.keyedvectors.Vocab at 0x28abdc9fa08>,
#  'dm': <gensim.models.keyedvectors.Vocab at 0x28abdc9fa48>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x28abdc9fa88>,
#  'paper': <gensim.models.keyedvectors.Vocab at 0x28abdc9fac8>,
#  'worry': <gensim.models.keyedvectors.Vocab at 0x28abdc9fb08>,
#  'record': <gensim.models.keyedvectors.Vocab at 0x28abdc9fb48>,
#  'married': <gensim.models.keyedvectors.Vocab at 0x28abdc9fb88>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x28abdc9fbc8>,
#  'fellow': <gensim.models.keyedvectors.Vocab at 0x28abdc9fc08>,
#  'sir': <gensim.models.keyedvectors.Vocab at 0x28abdc9fc48>,
#  'heavy': <gensim.models.keyedvectors.Vocab at 0x28abdc9fc88>,
#  'frozen': <gensim.models.keyedvectors.Vocab at 0x28abdc9fcc8>,
#  'thief': <gensim.models.keyedvectors.Vocab at 0x28abdc9fd08>,
#  'broke': <gensim.models.keyedvectors.Vocab at 0x28abdc9fd48>,
#  'stole': <gensim.models.keyedvectors.Vocab at 0x28abdc9fd88>,
#  'ear': <gensim.models.keyedvectors.Vocab at 0x28abdc9fdc8>,
#  'match': <gensim.models.keyedvectors.Vocab at 0x28abdc9fe08>,
#  'exam': <gensim.models.keyedvectors.Vocab at 0x28abdc9fe48>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x28abdc9fe88>,
#  'illness': <gensim.models.keyedvectors.Vocab at 0x28abdc9fec8>,
#  'feelin': <gensim.models.keyedvectors.Vocab at 0x28abdc9ff08>,
#  'depressed': <gensim.models.keyedvectors.Vocab at 0x28abdc9ff48>,
#  'soo': <gensim.models.keyedvectors.Vocab at 0x28abdc9ff88>,
#  'damn': <gensim.models.keyedvectors.Vocab at 0x28abdc9ffc8>,
#  'fuck': <gensim.models.keyedvectors.Vocab at 0x28abdca2048>,
#  'shift': <gensim.models.keyedvectors.Vocab at 0x28abdca2088>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x28abdca20c8>,
#  'wondering': <gensim.models.keyedvectors.Vocab at 0x28abdca2108>,
#  'financial': <gensim.models.keyedvectors.Vocab at 0x28abdca2148>,
#  'account': <gensim.models.keyedvectors.Vocab at 0x28abdca2188>,
#  'grand': <gensim.models.keyedvectors.Vocab at 0x28abdca21c8>,
#  'wheres': <gensim.models.keyedvectors.Vocab at 0x28abdca2208>,
#  'rose': <gensim.models.keyedvectors.Vocab at 0x28abdca2248>,
#  'busy': <gensim.models.keyedvectors.Vocab at 0x28abdca2288>,
#  'ta': <gensim.models.keyedvectors.Vocab at 0x28abdca22c8>,
#  'nasty': <gensim.models.keyedvectors.Vocab at 0x28abdca2308>,
#  'jealous': <gensim.models.keyedvectors.Vocab at 0x28abdca2348>,
#  'invited': <gensim.models.keyedvectors.Vocab at 0x28abdca2388>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x28abdca23c8>,
#  'opened': <gensim.models.keyedvectors.Vocab at 0x28abdca2408>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x28abdca2448>,
#  ...}

# %%
# word_to_id = cleaned_emo.get_word_index()
# word_to_id = {k:(v+3) for k,v in word_to_id.items()}
# for i, w in enumerate(['clean_text']):
#     word_to_id[w] = i

# id_to_word = {v:k for k, v in word_to_id.items()}

X_train_pad.loc[:0]
# Out:
# ---------------------------------------------------------------
# AttributeError                Traceback (most recent call last)
# <ipython-input-295-fd066370d0bf> in <module>
#       6 # id_to_word = {v:k for k, v in word_to_id.items()}
#       7
# ----> 8 X_train_pad.loc[:0]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'loc'

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

X_train_pad = pad_sequences(X_train_token, dtype='float32', padding='post', value=-1000)
X_test_pad = pad_sequences(X_test_token, dtype='float32', padding='post', value=-1000)
# Out:
# ---------------------------------------------------------------
# ValueError                    Traceback (most recent call last)
# <ipython-input-283-17be2db73722> in <module>
#       1 from tensorflow.keras.preprocessing.sequence import pad_sequences
#       2
# ----> 3 X_train_pad = pad_sequences(X_train_token, dtype='float32', padding='post', value=-1000)
#       4 X_test_pad = pad_sequences(X_test_token, dtype='float32', padding='post', value=-1000)
#
# c:\users\al\.venvs\lewagon\lib\site-packages\tensorflow\python\keras\preprocessing\sequence.py in pad_sequences(sequences, maxlen, dtype, padding, truncating, value)
#     156   return sequence.pad_sequences(
#     157       sequences, maxlen=maxlen, dtype=dtype,
# --> 158       padding=padding, truncating=truncating, value=value)
#     159
#     160 keras_export(
#
# c:\users\al\.venvs\lewagon\lib\site-packages\keras_preprocessing\sequence.py in pad_sequences(sequences, maxlen, dtype, padding, truncating, value)
#      96
#      97         # check `trunc` has expected shape
# ---> 98         trunc = np.asarray(trunc, dtype=dtype)
#      99         if trunc.shape[1:] != sample_shape:
#     100             raise ValueError('Shape of sample %s of sequence at position %s '
#
# c:\users\al\.venvs\lewagon\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'can'

# %% [markdown]
# ## tensorflow version

# %%
pip install -q tqdm
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import io
import itertools
import numpy as np
import os
import re
import string
import tensorflow as tf
import tqdm

from tensorflow.keras import Model, Sequential
from tensorflow.keras.layers import Activation, Dense, Dot, Embedding, Flatten, GlobalAveragePooling1D, Reshape
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

# %% [markdown]
# # Try streamlit map

# %%
map_df = pd.read_csv('../raw_data/prediction.csv')
map_df.head()
# Out:
#                       place_id        lat       lng  \
# 0  ChIJiwVttYym2EcRUdFHMteOfCo  51.563524  0.070761
# 1  ChIJiwVttYym2EcRUdFHMteOfCo  51.563524  0.070761
# 2  ChIJiwVttYym2EcRUdFHMteOfCo  51.563524  0.070761
# 3  ChIJiwVttYym2EcRUdFHMteOfCo  51.563524  0.070761
# 4  ChIJiwVttYym2EcRUdFHMteOfCo  51.563524  0.070761
#
#                                               review
# 0  Nice budget hotel....room is clean and well ma...
# 1  This hotel is well managed with great staff on...
# 2  10 our of 10 lovely service, clean and homely....
# 3  Very Dirty, carpet never been cleaned, Curry s...
# 4  Even 1 star is too much for this terrible hote...

# %%
map_df = pd.read_csv('../raw_data/prediction.csv')
map_df.rename(columns={'lng':'lon'}, inplace=True)
data = pd.DataFrame([map_df['lat'], map_df['lon']])
data.head()
# Out:
#           0          1          2          3          4          5     \
# lat  51.563524  51.563524  51.563524  51.563524  51.563524  51.577553
# lon   0.070761   0.070761   0.070761   0.070761   0.070761   0.186761
#
#           6          7          8          9     ...       2035       2036  \
# lat  51.577553  51.577553  51.577553  51.577553  ...  51.506744  51.506744
# lon   0.186761   0.186761   0.186761   0.186761  ...  -0.124404  -0.124404
#
#           2037       2038       2039       2040       2041       2042  \
# lat  51.506744  51.506744  51.506744  51.502500  51.502500  51.502500
# lon  -0.124404  -0.124404  -0.124404  -0.118071  -0.118071  -0.118071
#
#           2043       2044
# lat  51.502500  51.502500
# lon  -0.118071  -0.118071
#
# [2 rows x 2045 columns]

# %%
# df.rename(columns={0 : 'Title_1', 1 : 'Title2'}, inplace=True)
rename(columns={'lng':'lon'}, inplace=True)

# %%
map_df = pd.read_csv('../raw_data/prediction.csv')
type(map_df)
# Out:
# pandas.core.frame.DataFrame

# %%
url_df = pd.read_csv("https://raw.githubusercontent.com/visgl/deck.gl-data/master/examples/3d-heatmap/heatmap-data.csv")
url_df.head()
# Out:
#         lng        lat
# 0 -0.198465  51.505538
# 1 -0.178838  51.491836
# 2 -0.205590  51.514910
# 3 -0.208327  51.514952
# 4 -0.206022  51.496572

# %%
import pydeck as pdk
MAPBOX_API_KEY = 'hYjanuWQ92oW2KK_Um_1mmNuR7jW14th3hst9jNO_sc'
# ArcLayer - work commute patterns (create dataframe with fake data)
# to change look of commute lines use arguments such as pitch, get_width, get_tilt, etc.

# data
data = 'https://raw.githubusercontent.com/groundhogday321/dataframe-datasets/master/fake_commute_data.csv'
commute_pattern = pd.read_csv(data)
print(commute_pattern.head(2))

# view (location, zoom level, etc.)
view = pdk.ViewState(latitude=32.800382, longitude=-97.040728, pitch=50, zoom=9)

# layer
# from home (orange) to work (purple)
arc_layer = pdk.Layer('ArcLayer',
                      data=commute_pattern,
                      get_source_position=['from_lon', 'from_lat'],
                      get_target_position=['to_lon', 'to_lat'],
                      get_width=5,
                      get_tilt=15,
                      # RGBA colors (red, green, blue, alpha)
                      get_source_color=[255, 165, 0, 80],
                      get_target_color=[128, 0, 128, 80])

# render map
# choose map style
# mapbox api key required for basemap tile
arc_layer_map = pdk.Deck(map_style='mapbox://styles/mapbox/light-v10',
                         layers=arc_layer,
                         initial_view_state=view,
                         mapbox_key=MAPBOX_API_KEY)

# display and save map (to_html(), show())
arc_layer_map.to_html('../raw_data/teststreamlit.html')
arc_layer_map.show()
# Out:
#     from_lat   from_lon     to_lat     to_lon
# 0  32.870715 -97.376346  32.769007 -96.812533
# 1  32.799592 -97.351823  32.822974 -96.801833
# DeckGLWidget(google_maps_key=None, json_input='{"initialViewState": {"latitude": 32.800382, "longitude": -97.0…

# %%
map_df = pd.read_csv('../raw_data/prediction.csv')
map_df.rename(columns={'lng':'lon'}, inplace=True)
data = pd.DataFrame([map_df['lat'], map_df['lon']])
data = data.T

data.head()
# Out:
#          lat       lon
# 0  51.563524  0.070761
# 1  51.563524  0.070761
# 2  51.563524  0.070761
# 3  51.563524  0.070761
# 4  51.563524  0.070761

# %%
df = pd.DataFrame(
   np.random.randn(1000, 2) / [50, 50] + [37.76, -122.4],
   columns=['lat', 'lon'])

df.head()
# Out:
#          lat         lon
# 0  37.800167 -122.399648
# 1  37.742658 -122.423957
# 2  37.761130 -122.376155
# 3  37.770429 -122.404000
# 4  37.756410 -122.385901
